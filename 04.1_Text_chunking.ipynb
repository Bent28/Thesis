# %% [markdown]
# <h1> Chunking BERT <h1>

# %% [markdown]
# # Conda update

# %%
conda update conda
# Out:
# done
# | lving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::hvplot==0.8.4=py311hecd8cb5_0
#   - defaults/osx-64::nltk==3.8.1=py311hecd8cb5_0
#   - defaults/osx-64::nbclassic==0.5.5=py311hecd8cb5_0
#   - defaults/osx-64::jupyter_server_fileid==0.9.0=py311hecd8cb5_0
#   - defaults/osx-64::imbalanced-learn==0.10.1=py311hecd8cb5_1
#   - defaults/osx-64::aext-core-server==4.1.0=py311hecd8cb5_0
#   - defaults/osx-64::typing-extensions==4.7.1=py311hecd8cb5_0
#   - defaults/osx-64::holoviews==1.17.0=py311hecd8cb5_0
#   - defaults/osx-64::anaconda-cloud-auth==0.7.2=py311hecd8cb5_0
#   - defaults/osx-64::jupyter_server==2.14.1=py311hecd8cb5_0
#   - defaults/osx-64::jupyterlab_server==2.27.3=py311hecd8cb5_0
#   - defaults/osx-64::aext-core==4.1.0=py311hecd8cb5_jl4_0
#   - defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::anaconda-client==1.13.0=py311hecd8cb5_0
#   - defaults/osx-64::aext-project-filebrowser-server==4.1.0=py311h07019b9_0
#   - defaults/osx-64::scrapy==2.8.0=py311hecd8cb5_0
#   - defaults/osx-64::anaconda-toolbox==4.1.0=py311hecd8cb5_0
#   - defaults/osx-64::sqlalchemy==2.0.37=py311hd53568b_0
#   - defaults/osx-64::pydantic-settings==2.6.1=py311hecd8cb5_0
#   - defaults/osx-64::pydantic==2.8.2=py311hecd8cb5_0
#   - defaults/osx-64::bokeh==3.2.1=py311h85bffb1_0
#   - defaults/osx-64::seaborn==0.12.2=py311hecd8cb5_0
#   - defaults/osx-64::jupyter-lsp==2.2.0=py311hecd8cb5_0
#   - defaults/noarch::sacremoses==0.0.43=pyhd3eb1b0_0
#   - defaults/osx-64::aext-panels-server==4.1.0=py311hecd8cb5_0
#   - defaults/osx-64::jupyter==1.0.0=py311hecd8cb5_8
#   - defaults/osx-64::scikit-learn==1.3.0=py311hdb55bb0_0
#   - defaults/osx-64::distributed==2023.6.0=py311hecd8cb5_0
#   - defaults/osx-64::notebook==7.3.2=py311hecd8cb5_0
#   - defaults/osx-64::twisted==22.10.0=py311h6c40b1e_0
#   - defaults/osx-64::intake==0.6.8=py311hecd8cb5_0
#   - defaults/osx-64::dask-core==2023.6.0=py311hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.6.4=py311hecd8cb5_0
#   - defaults/osx-64::typer==0.9.0=py311hecd8cb5_0
#   - defaults/osx-64::jupyterlab==4.3.4=py311hecd8cb5_0
#   - defaults/osx-64::panel==1.2.1=py311hecd8cb5_0
#   - defaults/osx-64::anaconda-cli-base==0.4.1=py311hecd8cb5_1
#   - defaults/osx-64::_anaconda_depends==2023.07=py311_1
#   - defaults/osx-64::alembic==1.13.3=py311hecd8cb5_0
#   - defaults/osx-64::anaconda-project==0.11.1=py311hecd8cb5_0
#   - defaults/osx-64::conda-repo-cli==1.0.41=py311hecd8cb5_0
#   - defaults/osx-64::scikit-image==0.20.0=py311hcec6c5f_0
#   - defaults/osx-64::anaconda-catalogs==0.2.0=py311hecd8cb5_0
#   - defaults/osx-64::statsmodels==0.14.0=py311hb3a5e46_0
#   - defaults/osx-64::aext-assistant==4.1.0=py311hecd8cb5_jl4_0
#   - defaults/osx-64::jupyter_server_ydoc==0.8.0=py311hecd8cb5_1
#   - defaults/osx-64::s3fs==2023.3.0=py311hecd8cb5_0
#   - defaults/noarch::aioitertools==0.7.1=pyhd3eb1b0_0
#   - defaults/osx-64::aiobotocore==2.4.2=py311hecd8cb5_0
#   - defaults/osx-64::aext-panels==4.1.0=py311hecd8cb5_0
#   - defaults/osx-64::aext-share-notebook==4.1.0=py311hecd8cb5_0
#   - defaults/osx-64::dask==2023.6.0=py311hecd8cb5_0
#   - defaults/osx-64::datashader==0.15.1=py311hecd8cb5_0
#   - defaults/osx-64::aext-share-notebook-server==4.1.0=py311hecd8cb5_0
#   - defaults/osx-64::aext-assistant-server==4.1.0=py311hecd8cb5_0
#   - defaults/osx-64::pydantic-core==2.20.1=py311hcc58cb1_0
#   - defaults/osx-64::xarray==2023.6.0=py311hecd8cb5_0
#   - defaults/osx-64::aext-shared==4.1.0=py311hecd8cb5_0
#   - defaults/osx-64::notebook-shim==0.2.2=py311hecd8cb5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 25.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.3.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/mike/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2025.03  | py311_openblas_0         100 KB
#     aiohappyeyeballs-2.4.4     |  py311hecd8cb5_0          28 KB
#     aiohttp-3.11.10            |  py311h46256e1_0         914 KB
#     alabaster-0.7.16           |  py311hecd8cb5_0          20 KB
#     altair-5.0.1               |  py311hecd8cb5_1         606 KB
#     anaconda-anon-usage-0.6.1  |py311hfb7c958_100          37 KB
#     anyio-4.6.2                |  py311hecd8cb5_0         253 KB
#     appscript-1.3.0            |  py311h46256e1_0         181 KB
#     argon2-cffi-bindings-21.2.0|  py311h46256e1_1          32 KB
#     arrow-1.3.0                |  py311hecd8cb5_0         187 KB
#     astroid-3.3.8              |  py311hecd8cb5_0         669 KB
#     astropy-7.0.0              |  py311h46256e1_0         9.6 MB
#     astropy-iers-data-0.2025.1.13.0.34.51|  py311hecd8cb5_0         1.7 MB
#     asyncssh-2.17.0            |  py311hecd8cb5_0         863 KB
#     autopep8-2.0.4             |     pyhd3eb1b0_0          44 KB
#     babel-2.16.0               |  py311hecd8cb5_0         6.8 MB
#     backports-1.1              |     pyhd3eb1b0_1           6 KB
#     bcrypt-3.2.0               |  py311h46256e1_2          41 KB
#     beautifulsoup4-4.12.3      |  py311hecd8cb5_0         280 KB
#     black-24.10.0              |  py311hecd8cb5_0         403 KB
#     bleach-6.2.0               |  py311hecd8cb5_0         368 KB
#     blinker-1.9.0              |  py311hecd8cb5_0          24 KB
#     boltons-24.1.0             |  py311hecd8cb5_0         503 KB
#     botocore-1.36.3            |  py311hecd8cb5_0         8.8 MB
#     bottleneck-1.4.2           |  py311h9b7fc35_0         153 KB
#     brotli-1.0.9               |       h46256e1_9          20 KB
#     brotli-bin-1.0.9           |       h46256e1_9          18 KB
#     brotli-python-1.0.9        |  py311h6d0c2b6_9         384 KB
#     bzip2-1.0.8                |       h6c40b1e_6         151 KB
#     c-ares-1.19.1              |       h6c40b1e_0         107 KB
#     c-blosc2-2.12.0            |       hcf5af9b_0         312 KB
#     ca-certificates-2025.2.25  |       hecd8cb5_0         131 KB
#     cachetools-5.5.1           |  py311hecd8cb5_0          36 KB
#     cffi-1.17.1                |  py311h9205ec4_1         299 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     click-8.1.7                |  py311hecd8cb5_0         223 KB
#     cloudpickle-3.0.0          |  py311hecd8cb5_0          42 KB
#     colorcet-3.1.0             |  py311hecd8cb5_0         614 KB
#     comm-0.2.1                 |  py311hecd8cb5_0          18 KB
#     conda-index-0.5.0          |  py311hecd8cb5_0         243 KB
#     constantly-23.10.4         |  py311hecd8cb5_0          32 KB
#     contourpy-1.3.1            |  py311h1962661_0         270 KB
#     cookiecutter-2.6.0         |  py311hecd8cb5_0         143 KB
#     cramjam-2.9.1              |  py311h3c392ed_0         1.5 MB
#     cssselect-1.2.0            |  py311hecd8cb5_0          50 KB
#     cytoolz-1.0.1              |  py311h46256e1_0         369 KB
#     debugpy-1.8.11             |  py311h6d0c2b6_0         2.6 MB
#     deprecated-1.2.13          |  py311hecd8cb5_0          18 KB
#     dill-0.3.8                 |  py311hecd8cb5_0         234 KB
#     filelock-3.13.1            |  py311hecd8cb5_0          25 KB
#     flake8-7.1.1               |  py311hecd8cb5_0         117 KB
#     flask-3.1.0                |  py311hecd8cb5_0         220 KB
#     fmt-9.1.0                  |       ha357a0b_1         187 KB
#     fonttools-4.55.3           |  py311h46256e1_0         2.9 MB
#     frozenlist-1.5.0           |  py311h46256e1_0          53 KB
#     fsspec-2024.12.0           |  py311hecd8cb5_0         397 KB
#     future-1.0.0               |  py311hecd8cb5_0         896 KB
#     gflags-2.2.2               |       hcec6c5f_1         116 KB
#     gitdb-4.0.7                |     pyhd3eb1b0_0          50 KB
#     gitpython-3.1.43           |  py311hecd8cb5_0         381 KB
#     glib-2.78.4                |       hcec6c5f_0         506 KB
#     glib-tools-2.78.4          |       hcec6c5f_0         104 KB
#     glog-0.5.0                 |       hcec6c5f_1          95 KB
#     gmp-6.3.0                  |       h6d0c2b6_0         581 KB
#     gmpy2-2.2.1                |  py311h2cec913_0         213 KB
#     greenlet-3.1.1             |  py311h6d0c2b6_0         240 KB
#     h5py-3.12.1                |  py311ha611a00_0         1.3 MB
#     hdf5-1.12.1                |       h2b2ad87_2         4.1 MB
#     idna-3.7                   |  py311hecd8cb5_0         133 KB
#     imageio-2.37.0             |  py311hecd8cb5_0         621 KB
#     importlib-metadata-8.5.0   |  py311hecd8cb5_0          55 KB
#     importlib_metadata-8.5.0   |       hd3eb1b0_0           9 KB
#     incremental-22.10.0        |     pyhd3eb1b0_0          18 KB
#     ipykernel-6.29.5           |  py311hecd8cb5_1         255 KB
#     ipython-8.30.0             |  py311hecd8cb5_0         1.4 MB
#     ipywidgets-7.8.1           |  py311hecd8cb5_0         231 KB
#     isort-5.13.2               |  py311hecd8cb5_1         272 KB
#     itemloaders-1.1.0          |  py311hecd8cb5_0          31 KB
#     itsdangerous-2.2.0         |  py311hecd8cb5_0          38 KB
#     jedi-0.19.2                |  py311hecd8cb5_0         1.2 MB
#     jellyfish-1.1.3            |  py311h047fda8_0         325 KB
#     jinja2-3.1.6               |  py311hecd8cb5_0         366 KB
#     jmespath-1.0.1             |  py311hecd8cb5_0          50 KB
#     joblib-1.4.2               |  py311hecd8cb5_0         532 KB
#     jpeg-9e                    |       h46256e1_3         253 KB
#     jq-1.7.1                   |       h46256e1_0         335 KB
#     json5-0.9.25               |  py311hecd8cb5_0          56 KB
#     jsonpatch-1.33             |  py311hecd8cb5_1          38 KB
#     jupyter_client-8.6.3       |  py311hecd8cb5_0         236 KB
#     jupyter_core-5.7.2         |  py311hecd8cb5_0          98 KB
#     jupyter_events-0.12.0      |  py311hecd8cb5_0          44 KB
#     jupyter_ydoc-0.2.5         |  py311hecd8cb5_0          18 KB
#     jupyterlab-variableinspector-3.1.0|  py311hecd8cb5_0          25 KB
#     jupyterlab_pygments-0.3.0  |  py311hecd8cb5_0          20 KB
#     jupyterlab_widgets-1.0.0   |     pyhd3eb1b0_1         109 KB
#     keyring-24.3.1             |  py311hecd8cb5_0          82 KB
#     kiwisolver-1.4.8           |  py311h6d0c2b6_0          60 KB
#     lazy_loader-0.4            |  py311hecd8cb5_0          25 KB
#     lcms2-2.16                 |       h4f63f0c_0         257 KB
#     lerc-4.0.0                 |       h6d0c2b6_0         272 KB
#     libbrotlicommon-1.0.9      |       h46256e1_9          68 KB
#     libbrotlidec-1.0.9         |       h46256e1_9          31 KB
#     libbrotlienc-1.0.9         |       h46256e1_9         300 KB
#     libdeflate-1.22            |       h46256e1_0          72 KB
#     libedit-3.1.20230828       |       h6c40b1e_0         152 KB
#     libffi-3.4.4               |       hecd8cb5_1         129 KB
#     libglib-2.78.4             |       h19e1a8f_0         2.7 MB
#     libiconv-1.16              |       h6c40b1e_3         720 KB
#     libllvm14-14.0.6           |       h26321d7_4        24.2 MB
#     libsolv-0.7.30             |       h2761308_1         442 KB
#     libtiff-4.5.1              |       h6fa9cd1_1         509 KB
#     libxml2-2.10.4             |       h930c0e2_0         666 KB
#     llvmlite-0.44.0            |  py311hfa5e528_1        21.8 MB
#     lz4-4.3.2                  |  py311h46256e1_1          36 KB
#     lz4-c-1.9.4                |       hcec6c5f_1         167 KB
#     markupsafe-3.0.2           |  py311h46256e1_0          27 KB
#     matplotlib-3.10.0          |  py311hecd8cb5_0           8 KB
#     matplotlib-base-3.10.0     |  py311h919b35b_0         8.3 MB
#     mistune-3.1.2              |  py311hecd8cb5_0         149 KB
#     more-itertools-10.3.0      |  py311hecd8cb5_0         150 KB
#     mpc-1.3.1                  |       h46256e1_0         123 KB
#     mpfr-4.2.1                 |       h46256e1_0         462 KB
#     multidict-6.1.0            |  py311h46256e1_0          55 KB
#     mypy-1.14.1                |  py311h46256e1_0        11.1 MB
#     mypy_extensions-1.0.0      |  py311hecd8cb5_0          14 KB
#     navigator-updater-0.5.1    |  py311hecd8cb5_0         2.3 MB
#     nbclient-0.10.2            |  py311hecd8cb5_0          55 KB
#     nbconvert-7.16.6           |  py311hecd8cb5_0           9 KB
#     nbconvert-core-7.16.6      |  py311hecd8cb5_0         524 KB
#     nbconvert-pandoc-7.16.6    |  py311hecd8cb5_0           9 KB
#     nbformat-5.10.4            |  py311hecd8cb5_0         160 KB
#     nest-asyncio-1.6.0         |  py311hecd8cb5_0          18 KB
#     networkx-3.4.2             |  py311hecd8cb5_0         3.1 MB
#     numba-0.61.0               |  py311h6d0c2b6_1         5.9 MB
#     numexpr-2.10.1             |  py311hc59c7be_0         196 KB
#     numpydoc-1.7.0             |  py311hecd8cb5_0         147 KB
#     openjpeg-2.5.2             |       hbf2204d_0         351 KB
#     openpyxl-3.1.5             |  py311h46256e1_1         691 KB
#     packaging-24.2             |  py311hecd8cb5_0         204 KB
#     pandas-2.2.3               |  py311h6d0c2b6_0        14.9 MB
#     pandoc-2.12                |       hecd8cb5_3        12.1 MB
#     param-2.2.0                |  py311hecd8cb5_0         272 KB
#     parsel-1.8.1               |  py311hecd8cb5_0          53 KB
#     parso-0.8.4                |  py311hecd8cb5_0         241 KB
#     partd-1.4.2                |  py311hecd8cb5_0          49 KB
#     patsy-1.0.1                |  py311hecd8cb5_0         360 KB
#     pcre2-10.42                |       h9b97e30_1         1.3 MB
#     pillow-11.1.0              |  py311h47bf62f_0         938 KB
#     pkginfo-1.11.2             |  py311hecd8cb5_0          70 KB
#     plotly-5.24.1              |  py311h85bffb1_1        10.3 MB
#     pluggy-1.5.0               |  py311hecd8cb5_0          48 KB
#     prometheus_client-0.21.0   |  py311hecd8cb5_0         127 KB
#     prompt-toolkit-3.0.43      |  py311hecd8cb5_0         735 KB
#     prompt_toolkit-3.0.43      |       hd3eb1b0_0           5 KB
#     propcache-0.2.0            |  py311h46256e1_0          46 KB
#     protobuf-3.20.3            |  py311hcec6c5f_0         337 KB
#     psutil-5.9.0               |  py311h46256e1_1         505 KB
#     py-cpuinfo-9.0.0           |  py311hecd8cb5_0          64 KB
#     pycodestyle-2.12.1         |  py311hecd8cb5_0          74 KB
#     pycosat-0.6.6              |  py311h46256e1_2          93 KB
#     pydeck-0.9.1               |  py311hecd8cb5_0         5.0 MB
#     pyerfa-2.0.1.5             |  py311h46256e1_0         372 KB
#     pyflakes-3.2.0             |  py311hecd8cb5_0         156 KB
#     pygithub-2.4.0             |  py311hecd8cb5_0         1.9 MB
#     pylint-3.3.3               |  py311hecd8cb5_0         1.3 MB
#     pylint-venv-3.0.3          |  py311hecd8cb5_0          14 KB
#     pynacl-1.5.0               |  py311h46256e1_1         1.2 MB
#     pyobjc-core-10.1           |  py311h46256e1_0         501 KB
#     pyobjc-framework-cocoa-10.1|  py311h9205ec4_0         396 KB
#     pyobjc-framework-coreservices-10.1|  py311h46256e1_0          67 KB
#     pyobjc-framework-fsevents-10.1|  py311hecd8cb5_0          16 KB
#     pyodbc-5.2.0               |  py311h6d0c2b6_0          69 KB
#     pyparsing-3.2.0            |  py311hecd8cb5_0         480 KB
#     pyqt-5.15.10               |  py311h6d0c2b6_1         4.3 MB
#     pyqt5-sip-12.13.0          |  py311h46256e1_1          78 KB
#     pyqtwebengine-5.15.10      |  py311h6d0c2b6_1         137 KB
#     pytables-3.10.1            |  py311h9cfd14f_0         1.7 MB
#     pytest-8.3.4               |  py311hecd8cb5_0         1.2 MB
#     python-dateutil-2.9.0post0 |  py311hecd8cb5_2         322 KB
#     python-fastjsonschema-2.20.0|  py311hecd8cb5_0         263 KB
#     python-json-logger-3.2.1   |  py311hecd8cb5_0          29 KB
#     python-libarchive-c-5.1    |     pyhd3eb1b0_0          50 KB
#     python-lmdb-1.6.2          |  py311h6d0c2b6_0         151 KB
#     python-lsp-black-2.0.0     |  py311hecd8cb5_0          18 KB
#     python-lsp-jsonrpc-1.1.2   |     pyhd3eb1b0_0          12 KB
#     python-lsp-server-1.12.0   |  py311h85bffb1_0         187 KB
#     python-snappy-0.7.3        |  py311hecd8cb5_0          21 KB
#     python-tzdata-2023.3       |     pyhd3eb1b0_0         140 KB
#     pytoolconfig-1.2.6         |  py311hecd8cb5_0          37 KB
#     pytz-2024.1                |  py311hecd8cb5_0         224 KB
#     pyuca-1.2                  |  py311hecd8cb5_1         730 KB
#     pyviz_comms-3.0.2          |  py311hecd8cb5_0          57 KB
#     pywavelets-1.8.0           |  py311h46256e1_0         3.6 MB
#     qdarkstyle-3.2.3           |     pyhd3eb1b0_0         615 KB
#     qt-webengine-5.15.9        |       h90a370e_7        52.0 MB
#     qtawesome-1.3.1            |  py311hecd8cb5_0         1.7 MB
#     qtconsole-5.6.1            |  py311hecd8cb5_0         274 KB
#     qtpy-2.4.1                 |  py311hecd8cb5_0         132 KB
#     queuelib-1.6.2             |  py311hecd8cb5_0          36 KB
#     regex-2024.11.6            |  py311h46256e1_0         404 KB
#     reproc-14.2.4              |       hcec6c5f_2          28 KB
#     reproc-cpp-14.2.4          |       hcec6c5f_2          20 KB
#     rope-1.12.0                |  py311hecd8cb5_0         591 KB
#     scipy-1.15.1               |  py311hedc7b93_0        25.2 MB
#     semver-3.0.2               |  py311hecd8cb5_1          45 KB
#     sip-6.7.12                 |  py311h6d0c2b6_1         593 KB
#     smmap-4.0.0                |     pyhd3eb1b0_0          23 KB
#     snappy-1.2.1               |       h6d0c2b6_0          41 KB
#     sniffio-1.3.0              |  py311hecd8cb5_0          18 KB
#     soupsieve-2.5              |  py311hecd8cb5_0          96 KB
#     sphinx-7.3.7               |  py311hecd8cb5_0         3.0 MB
#     sphinxcontrib-serializinghtml-1.1.10|  py311hecd8cb5_0          34 KB
#     spyder-6.0.3               |  py311hecd8cb5_0        10.6 MB
#     spyder-kernels-3.0.2       |  py311h85bffb1_0         382 KB
#     streamlit-1.42.0           |  py311hecd8cb5_0         8.7 MB
#     superqt-0.6.7              |  py311h85bffb1_0         214 KB
#     sympy-1.13.3               |  py311hecd8cb5_1        15.4 MB
#     tabulate-0.9.0             |  py311hecd8cb5_0          71 KB
#     tenacity-9.0.0             |  py311hecd8cb5_0          68 KB
#     textdistance-4.6.3         |  py311h85bffb1_0          76 KB
#     threadpoolctl-3.5.0        |  py311h85bffb1_0          50 KB
#     tifffile-2025.2.18         |  py311hecd8cb5_0         522 KB
#     tinycss2-1.4.0             |  py311hecd8cb5_0         113 KB
#     tldextract-5.1.2           |  py311hecd8cb5_0         126 KB
#     tomli-2.0.1                |  py311hecd8cb5_0          31 KB
#     tomlkit-0.13.2             |  py311hecd8cb5_0         115 KB
#     toolz-1.0.0                |  py311hecd8cb5_0         148 KB
#     tornado-6.4.2              |  py311h46256e1_0         869 KB
#     tqdm-4.67.1                |  py311h85bffb1_0         163 KB
#     traitlets-5.14.3           |  py311hecd8cb5_0         227 KB
#     truststore-0.10.0          |  py311hecd8cb5_0          49 KB
#     typing_extensions-4.12.2   |  py311hecd8cb5_0          83 KB
#     tzdata-2025a               |       h04d1e81_0         117 KB
#     ujson-5.10.0               |  py311h6d0c2b6_1         150 KB
#     unicodedata2-15.1.0        |  py311h46256e1_1         517 KB
#     unidecode-1.3.8            |  py311hecd8cb5_0         281 KB
#     urllib3-2.3.0              |  py311hecd8cb5_0         238 KB
#     utf8proc-2.6.1             |       h6c40b1e_1          92 KB
#     w3lib-2.1.2                |  py311hecd8cb5_0          45 KB
#     watchdog-4.0.2             |  py311h3333b6a_0         152 KB
#     werkzeug-3.1.3             |  py311hecd8cb5_0         431 KB
#     widgetsnbextension-3.6.6   |  py311hecd8cb5_0         673 KB
#     wrapt-1.17.0               |  py311h46256e1_0          59 KB
#     xlwings-0.32.1             |  py311hecd8cb5_0         989 KB
#     xz-5.6.4                   |       h46256e1_1         289 KB
#     y-py-0.6.2                 |  py311h1405f1f_2         592 KB
#     yapf-0.40.2                |  py311hecd8cb5_0         474 KB
#     yarl-1.18.0                |  py311h46256e1_0         148 KB
#     ypy-websocket-0.8.4        |  py311hecd8cb5_0          33 KB
#     zict-3.0.0                 |  py311hecd8cb5_0         121 KB
#     zipp-3.21.0                |  py311hecd8cb5_0          31 KB
#     zope.interface-7.1.1       |  py311h46256e1_0         409 KB
#     zstandard-0.23.0           |  py311h5bcdf72_1         456 KB
#     zstd-1.5.6                 |       h138b38a_0         612 KB
#     ------------------------------------------------------------
#                                            Total:       342.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   aiohappyeyeballs   pkgs/main/osx-64::aiohappyeyeballs-2.4.4-py311hecd8cb5_0
#   altair             pkgs/main/osx-64::altair-5.0.1-py311hecd8cb5_1
#   astropy-iers-data  pkgs/main/osx-64::astropy-iers-data-0.2025.1.13.0.34.51-py311hecd8cb5_0
#   asyncssh           pkgs/main/osx-64::asyncssh-2.17.0-py311hecd8cb5_0
#   blinker            pkgs/main/osx-64::blinker-1.9.0-py311hecd8cb5_0
#   bottleneck         pkgs/main/osx-64::bottleneck-1.4.2-py311h9b7fc35_0
#   brotli-python      pkgs/main/osx-64::brotli-python-1.0.9-py311h6d0c2b6_9
#   cachetools         pkgs/main/osx-64::cachetools-5.5.1-py311hecd8cb5_0
#   cramjam            pkgs/main/osx-64::cramjam-2.9.1-py311h3c392ed_0
#   deprecated         pkgs/main/osx-64::deprecated-1.2.13-py311hecd8cb5_0
#   fsspec             pkgs/main/osx-64::fsspec-2024.12.0-py311hecd8cb5_0
#   gitdb              pkgs/main/noarch::gitdb-4.0.7-pyhd3eb1b0_0
#   gitpython          pkgs/main/osx-64::gitpython-3.1.43-py311hecd8cb5_0
#   glib-tools         pkgs/main/osx-64::glib-tools-2.78.4-hcec6c5f_0
#   joblib             pkgs/main/osx-64::joblib-1.4.2-py311hecd8cb5_0
#   jupyterlab-variab~ pkgs/main/osx-64::jupyterlab-variableinspector-3.1.0-py311hecd8cb5_0
#   libglib            pkgs/main/osx-64::libglib-2.78.4-h19e1a8f_0
#   mypy               pkgs/main/osx-64::mypy-1.14.1-py311h46256e1_0
#   nbconvert-core     pkgs/main/osx-64::nbconvert-core-7.16.6-py311hecd8cb5_0
#   nbconvert-pandoc   pkgs/main/osx-64::nbconvert-pandoc-7.16.6-py311hecd8cb5_0
#   pandas             pkgs/main/osx-64::pandas-2.2.3-py311h6d0c2b6_0
#   pandoc             pkgs/main/osx-64::pandoc-2.12-hecd8cb5_3
#   propcache          pkgs/main/osx-64::propcache-0.2.0-py311h46256e1_0
#   protobuf           pkgs/main/osx-64::protobuf-3.20.3-py311hcec6c5f_0
#   pydeck             pkgs/main/osx-64::pydeck-0.9.1-py311hecd8cb5_0
#   pygithub           pkgs/main/osx-64::pygithub-2.4.0-py311hecd8cb5_0
#   pynacl             pkgs/main/osx-64::pynacl-1.5.0-py311h46256e1_1
#   python-tzdata      pkgs/main/noarch::python-tzdata-2023.3-pyhd3eb1b0_0
#   pyuca              pkgs/main/osx-64::pyuca-1.2-py311hecd8cb5_1
#   smmap              pkgs/main/noarch::smmap-4.0.0-pyhd3eb1b0_0
#   streamlit          pkgs/main/osx-64::streamlit-1.42.0-py311hecd8cb5_0
#   superqt            pkgs/main/osx-64::superqt-0.6.7-py311h85bffb1_0
#   tomli              pkgs/main/osx-64::tomli-2.0.1-py311hecd8cb5_0
#   typing_extensions  pkgs/main/osx-64::typing_extensions-4.12.2-py311hecd8cb5_0
#   unicodedata2       pkgs/main/osx-64::unicodedata2-15.1.0-py311h46256e1_1
#
# The following packages will be UPDATED:
#
#   _anaconda_depends                         2023.07-py311_1 --> 2025.03-py311_openblas_0
#   aiohttp                             3.8.3-py311h6c40b1e_0 --> 3.11.10-py311h46256e1_0
#   alabaster          pkgs/main/noarch::alabaster-0.7.12-py~ --> pkgs/main/osx-64::alabaster-0.7.16-py311hecd8cb5_0
#   anaconda-anon-usa~                0.5.0-py311hfb7c958_100 --> 0.6.1-py311hfb7c958_100
#   anyio                               3.5.0-py311hecd8cb5_0 --> 4.6.2-py311hecd8cb5_0
#   appscript                           1.1.2-py311h6c40b1e_0 --> 1.3.0-py311h46256e1_0
#   argon2-cffi-bindi~                 21.2.0-py311h6c40b1e_0 --> 21.2.0-py311h46256e1_1
#   arrow                               1.2.3-py311hecd8cb5_1 --> 1.3.0-py311hecd8cb5_0
#   astroid                            2.14.2-py311hecd8cb5_0 --> 3.3.8-py311hecd8cb5_0
#   astropy                               5.1-py311hb9e55a9_0 --> 7.0.0-py311h46256e1_0
#   autopep8                               1.6.0-pyhd3eb1b0_1 --> 2.0.4-pyhd3eb1b0_0
#   babel                              2.11.0-py311hecd8cb5_0 --> 2.16.0-py311hecd8cb5_0
#   backports                                1.1-pyhd3eb1b0_0 --> 1.1-pyhd3eb1b0_1
#   bcrypt                              3.2.0-py311h6c40b1e_1 --> 3.2.0-py311h46256e1_2
#   beautifulsoup4                     4.12.2-py311hecd8cb5_0 --> 4.12.3-py311hecd8cb5_0
#   black                              23.3.0-py311hecd8cb5_0 --> 24.10.0-py311hecd8cb5_0
#   bleach             pkgs/main/noarch::bleach-4.1.0-pyhd3e~ --> pkgs/main/osx-64::bleach-6.2.0-py311hecd8cb5_0
#   boltons                            23.0.0-py311hecd8cb5_0 --> 24.1.0-py311hecd8cb5_0
#   botocore                          1.27.59-py311hecd8cb5_0 --> 1.36.3-py311hecd8cb5_0
#   brotli                                   1.0.9-hca72f7f_7 --> 1.0.9-h46256e1_9
#   brotli-bin                               1.0.9-hca72f7f_7 --> 1.0.9-h46256e1_9
#   bzip2                                    1.0.8-h1de35cc_0 --> 1.0.8-h6c40b1e_6
#   c-ares                                  1.19.0-h6c40b1e_0 --> 1.19.1-h6c40b1e_0
#   c-blosc2                                 2.8.0-hcec6c5f_0 --> 2.12.0-hcf5af9b_0
#   ca-certificates                     2024.12.31-hecd8cb5_0 --> 2025.2.25-hecd8cb5_0
#   cffi                               1.15.1-py311h6c40b1e_3 --> 1.17.1-py311h9205ec4_1
#   charset-normalizer                     2.0.4-pyhd3eb1b0_0 --> 3.3.2-pyhd3eb1b0_0
#   click                               8.0.4-py311hecd8cb5_0 --> 8.1.7-py311hecd8cb5_0
#   cloudpickle                         2.2.1-py311hecd8cb5_0 --> 3.0.0-py311hecd8cb5_0
#   colorcet                            3.0.1-py311hecd8cb5_0 --> 3.1.0-py311hecd8cb5_0
#   comm                                0.1.2-py311hecd8cb5_0 --> 0.2.1-py311hecd8cb5_0
#   conda-index                         0.2.3-py311hecd8cb5_0 --> 0.5.0-py311hecd8cb5_0
#   constantly                         15.1.0-py311hecd8cb5_0 --> 23.10.4-py311hecd8cb5_0
#   contourpy                           1.0.5-py311ha357a0b_0 --> 1.3.1-py311h1962661_0
#   cookiecutter       pkgs/main/noarch::cookiecutter-1.7.3-~ --> pkgs/main/osx-64::cookiecutter-2.6.0-py311hecd8cb5_0
#   cssselect          pkgs/main/noarch::cssselect-1.1.0-pyh~ --> pkgs/main/osx-64::cssselect-1.2.0-py311hecd8cb5_0
#   cytoolz                            0.12.0-py311h6c40b1e_0 --> 1.0.1-py311h46256e1_0
#   debugpy                             1.6.7-py311hcec6c5f_0 --> 1.8.11-py311h6d0c2b6_0
#   dill                                0.3.6-py311hecd8cb5_0 --> 0.3.8-py311hecd8cb5_0
#   filelock                            3.9.0-py311hecd8cb5_0 --> 3.13.1-py311hecd8cb5_0
#   flake8                              6.0.0-py311hecd8cb5_0 --> 7.1.1-py311hecd8cb5_0
#   flask                               2.2.2-py311hecd8cb5_0 --> 3.1.0-py311hecd8cb5_0
#   fmt                                      9.1.0-ha357a0b_0 --> 9.1.0-ha357a0b_1
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-py~ --> pkgs/main/osx-64::fonttools-4.55.3-py311h46256e1_0
#   frozenlist                          1.3.3-py311h6c40b1e_0 --> 1.5.0-py311h46256e1_0
#   future                             0.18.3-py311hecd8cb5_0 --> 1.0.0-py311hecd8cb5_0
#   gflags                                   2.2.2-h0a44026_0 --> 2.2.2-hcec6c5f_1
#   glib                                    2.69.1-hfff2838_2 --> 2.78.4-hcec6c5f_0
#   glog                                     0.5.0-h23ab428_0 --> 0.5.0-hcec6c5f_1
#   gmp                                      6.2.1-he9d5cce_3 --> 6.3.0-h6d0c2b6_0
#   gmpy2                               2.1.2-py311h1c2e9e1_0 --> 2.2.1-py311h2cec913_0
#   greenlet                            2.0.1-py311hcec6c5f_0 --> 3.1.1-py311h6d0c2b6_0
#   h5py                                3.7.0-py311h4bbaca6_0 --> 3.12.1-py311ha611a00_0
#   hdf5                                    1.10.6-h10fe05b_1 --> 1.12.1-h2b2ad87_2
#   idna                                  3.4-py311hecd8cb5_0 --> 3.7-py311hecd8cb5_0
#   imageio                            2.31.1-py311hecd8cb5_0 --> 2.37.0-py311hecd8cb5_0
#   importlib-metadata                  6.0.0-py311hecd8cb5_0 --> 8.5.0-py311hecd8cb5_0
#   importlib_metadata                       6.0.0-hd3eb1b0_0 --> 8.5.0-hd3eb1b0_0
#   incremental                           21.3.0-pyhd3eb1b0_0 --> 22.10.0-pyhd3eb1b0_0
#   ipykernel                          6.19.2-py311h4975b63_0 --> 6.29.5-py311hecd8cb5_1
#   ipython                            8.12.0-py311hecd8cb5_0 --> 8.30.0-py311hecd8cb5_0
#   isort              pkgs/main/noarch::isort-5.9.3-pyhd3eb~ --> pkgs/main/osx-64::isort-5.13.2-py311hecd8cb5_1
#   itemloaders        pkgs/main/noarch::itemloaders-1.0.4-p~ --> pkgs/main/osx-64::itemloaders-1.1.0-py311hecd8cb5_0
#   itsdangerous       pkgs/main/noarch::itsdangerous-2.0.1-~ --> pkgs/main/osx-64::itsdangerous-2.2.0-py311hecd8cb5_0
#   jedi                               0.18.1-py311hecd8cb5_1 --> 0.19.2-py311hecd8cb5_0
#   jellyfish                           0.9.0-py311h6c40b1e_0 --> 1.1.3-py311h047fda8_0
#   jinja2                              3.1.2-py311hecd8cb5_0 --> 3.1.6-py311hecd8cb5_0
#   jmespath           pkgs/main/noarch::jmespath-0.10.0-pyh~ --> pkgs/main/osx-64::jmespath-1.0.1-py311hecd8cb5_0
#   jpeg                                        9e-h6c40b1e_1 --> 9e-h46256e1_3
#   jq                                      1.6-h9ed2024_1000 --> 1.7.1-h46256e1_0
#   json5              pkgs/main/noarch::json5-0.9.6-pyhd3eb~ --> pkgs/main/osx-64::json5-0.9.25-py311hecd8cb5_0
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd~ --> pkgs/main/osx-64::jsonpatch-1.33-py311hecd8cb5_1
#   jupyter_client                      7.4.9-py311hecd8cb5_0 --> 8.6.3-py311hecd8cb5_0
#   jupyter_core                        5.3.0-py311hecd8cb5_0 --> 5.7.2-py311hecd8cb5_0
#   jupyter_events                     0.10.0-py311hecd8cb5_0 --> 0.12.0-py311hecd8cb5_0
#   jupyter_ydoc                        0.2.4-py311hecd8cb5_0 --> 0.2.5-py311hecd8cb5_0
#   jupyterlab_pygmen~ pkgs/main/noarch::jupyterlab_pygments~ --> pkgs/main/osx-64::jupyterlab_pygments-0.3.0-py311hecd8cb5_0
#   keyring                           23.13.1-py311hecd8cb5_0 --> 24.3.1-py311hecd8cb5_0
#   kiwisolver                          1.4.4-py311hcec6c5f_0 --> 1.4.8-py311h6d0c2b6_0
#   lazy_loader                           0.2-py311hecd8cb5_0 --> 0.4-py311hecd8cb5_0
#   lcms2                                     2.12-hf1fd2bf_0 --> 2.16-h4f63f0c_0
#   lerc                                       3.0-he9d5cce_0 --> 4.0.0-h6d0c2b6_0
#   libbrotlicommon                          1.0.9-hca72f7f_7 --> 1.0.9-h46256e1_9
#   libbrotlidec                             1.0.9-hca72f7f_7 --> 1.0.9-h46256e1_9
#   libbrotlienc                             1.0.9-hca72f7f_7 --> 1.0.9-h46256e1_9
#   libdeflate                                1.17-hb664fd8_0 --> 1.22-h46256e1_0
#   libedit                           3.1.20221030-h6c40b1e_0 --> 3.1.20230828-h6c40b1e_0
#   libffi                                   3.4.4-hecd8cb5_0 --> 3.4.4-hecd8cb5_1
#   libiconv                                  1.16-hca72f7f_2 --> 1.16-h6c40b1e_3
#   libllvm14                               14.0.6-h91fad77_3 --> 14.0.6-h26321d7_4
#   libsolv                                 0.7.22-h8346a28_0 --> 0.7.30-h2761308_1
#   libtiff                                  4.5.0-hcec6c5f_2 --> 4.5.1-h6fa9cd1_1
#   libxml2                                 2.10.3-h930c0e2_0 --> 2.10.4-h930c0e2_0
#   llvmlite                           0.40.0-py311hfff2838_0 --> 0.44.0-py311hfa5e528_1
#   lz4                                 4.3.2-py311h6c40b1e_0 --> 4.3.2-py311h46256e1_1
#   lz4-c                                    1.9.4-hcec6c5f_0 --> 1.9.4-hcec6c5f_1
#   markupsafe                          2.1.1-py311h6c40b1e_0 --> 3.0.2-py311h46256e1_0
#   matplotlib                          3.7.1-py311hecd8cb5_1 --> 3.10.0-py311hecd8cb5_0
#   matplotlib-base                     3.7.1-py311h11e8b89_1 --> 3.10.0-py311h919b35b_0
#   mistune                             2.0.4-py311hecd8cb5_0 --> 3.1.2-py311hecd8cb5_0
#   more-itertools     pkgs/main/noarch::more-itertools-8.12~ --> pkgs/main/osx-64::more-itertools-10.3.0-py311hecd8cb5_0
#   mpc                                      1.1.0-h6ef4df4_1 --> 1.3.1-h46256e1_0
#   mpfr                                     4.0.2-h9066e36_1 --> 4.2.1-h46256e1_0
#   multidict                           6.0.2-py311h6c40b1e_0 --> 6.1.0-py311h46256e1_0
#   mypy_extensions                     0.4.3-py311hecd8cb5_1 --> 1.0.0-py311hecd8cb5_0
#   navigator-updater                   0.4.0-py311hecd8cb5_0 --> 0.5.1-py311hecd8cb5_0
#   nbclient                           0.5.13-py311hecd8cb5_0 --> 0.10.2-py311hecd8cb5_0
#   nbconvert                          7.16.4-py311hecd8cb5_0 --> 7.16.6-py311hecd8cb5_0
#   nbformat                            5.7.0-py311hecd8cb5_0 --> 5.10.4-py311hecd8cb5_0
#   nest-asyncio                        1.5.6-py311hecd8cb5_0 --> 1.6.0-py311hecd8cb5_0
#   networkx                              3.1-py311hecd8cb5_0 --> 3.4.2-py311hecd8cb5_0
#   numba                              0.57.0-py311hdb55bb0_0 --> 0.61.0-py311h6d0c2b6_1
#   numexpr                             2.8.4-py311hd0e4f0d_1 --> 2.10.1-py311hc59c7be_0
#   numpydoc                            1.5.0-py311hecd8cb5_0 --> 1.7.0-py311hecd8cb5_0
#   openjpeg                                 2.4.0-h66ea3da_0 --> 2.5.2-hbf2204d_0
#   openpyxl                           3.0.10-py311h6c40b1e_0 --> 3.1.5-py311h46256e1_1
#   packaging                            23.0-py311hecd8cb5_0 --> 24.2-py311hecd8cb5_0
#   param                              1.13.0-py311hecd8cb5_0 --> 2.2.0-py311hecd8cb5_0
#   parsel                              1.6.0-py311hecd8cb5_0 --> 1.8.1-py311hecd8cb5_0
#   parso              pkgs/main/noarch::parso-0.8.3-pyhd3eb~ --> pkgs/main/osx-64::parso-0.8.4-py311hecd8cb5_0
#   partd              pkgs/main/noarch::partd-1.2.0-pyhd3eb~ --> pkgs/main/osx-64::partd-1.4.2-py311hecd8cb5_0
#   patsy                               0.5.3-py311hecd8cb5_0 --> 1.0.1-py311hecd8cb5_0
#   pcre2                                    10.37-he7042d7_1 --> 10.42-h9b97e30_1
#   pillow                             11.0.0-py311h9c91434_0 --> 11.1.0-py311h47bf62f_0
#   pkginfo                             1.9.6-py311hecd8cb5_0 --> 1.11.2-py311hecd8cb5_0
#   plotly                              5.9.0-py311hecd8cb5_0 --> 5.24.1-py311h85bffb1_1
#   pluggy                              1.0.0-py311hecd8cb5_1 --> 1.5.0-py311hecd8cb5_0
#   prometheus_client                  0.14.1-py311hecd8cb5_0 --> 0.21.0-py311hecd8cb5_0
#   prompt-toolkit                     3.0.36-py311hecd8cb5_0 --> 3.0.43-py311hecd8cb5_0
#   prompt_toolkit                          3.0.36-hd3eb1b0_0 --> 3.0.43-hd3eb1b0_0
#   psutil                              5.9.0-py311h6c40b1e_0 --> 5.9.0-py311h46256e1_1
#   py-cpuinfo         pkgs/main/noarch::py-cpuinfo-8.0.0-py~ --> pkgs/main/osx-64::py-cpuinfo-9.0.0-py311hecd8cb5_0
#   pycodestyle                        2.10.0-py311hecd8cb5_0 --> 2.12.1-py311hecd8cb5_0
#   pycosat                             0.6.4-py311h6c40b1e_0 --> 0.6.6-py311h46256e1_2
#   pyerfa                              2.0.0-py311h6c40b1e_0 --> 2.0.1.5-py311h46256e1_0
#   pyflakes                            3.0.1-py311hecd8cb5_0 --> 3.2.0-py311hecd8cb5_0
#   pylint                             2.16.2-py311hecd8cb5_0 --> 3.3.3-py311hecd8cb5_0
#   pylint-venv                         2.3.0-py311hecd8cb5_0 --> 3.0.3-py311hecd8cb5_0
#   pyobjc-core                           9.0-py311h9205ec4_1 --> 10.1-py311h46256e1_0
#   pyobjc-framework-~                    9.0-py311h9205ec4_0 --> 10.1-py311h9205ec4_0
#   pyobjc-framework-~                    9.0-py311h46256e1_0 --> 10.1-py311h46256e1_0
#   pyobjc-framework-~                    9.0-py311hecd8cb5_0 --> 10.1-py311hecd8cb5_0
#   pyodbc                             4.0.34-py311hcec6c5f_0 --> 5.2.0-py311h6d0c2b6_0
#   pyparsing                           3.0.9-py311hecd8cb5_0 --> 3.2.0-py311hecd8cb5_0
#   pyqt                              5.15.10-py311hcec6c5f_0 --> 5.15.10-py311h6d0c2b6_1
#   pyqt5-sip                         12.13.0-py311h6c40b1e_0 --> 12.13.0-py311h46256e1_1
#   pyqtwebengine                     5.15.10-py311hcec6c5f_0 --> 5.15.10-py311h6d0c2b6_1
#   pytables                            3.8.0-py311hbdc8ef1_2 --> 3.10.1-py311h9cfd14f_0
#   pytest                              7.4.0-py311hecd8cb5_0 --> 8.3.4-py311hecd8cb5_0
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8~ --> pkgs/main/osx-64::python-dateutil-2.9.0post0-py311hecd8cb5_2
#   python-fastjsonsc~                 2.16.2-py311hecd8cb5_0 --> 2.20.0-py311hecd8cb5_0
#   python-json-logger                  2.0.7-py311hecd8cb5_0 --> 3.2.1-py311hecd8cb5_0
#   python-libarchive~                       2.9-pyhd3eb1b0_1 --> 5.1-pyhd3eb1b0_0
#   python-lmdb                         1.4.1-py311hcec6c5f_0 --> 1.6.2-py311h6d0c2b6_0
#   python-lsp-black                    1.2.1-py311hecd8cb5_0 --> 2.0.0-py311hecd8cb5_0
#   python-lsp-jsonrpc                     1.0.0-pyhd3eb1b0_0 --> 1.1.2-pyhd3eb1b0_0
#   python-lsp-server                   1.7.2-py311hecd8cb5_0 --> 1.12.0-py311h85bffb1_0
#   python-snappy                       0.6.1-py311hcec6c5f_0 --> 0.7.3-py311hecd8cb5_0
#   pytoolconfig                        1.2.5-py311hecd8cb5_1 --> 1.2.6-py311hecd8cb5_0
#   pytz                               2022.7-py311hecd8cb5_0 --> 2024.1-py311hecd8cb5_0
#   pyviz_comms                         2.3.0-py311hecd8cb5_0 --> 3.0.2-py311hecd8cb5_0
#   pywavelets                          1.4.1-py311h6c40b1e_0 --> 1.8.0-py311h46256e1_0
#   qdarkstyle                             3.0.2-pyhd3eb1b0_0 --> 3.2.3-pyhd3eb1b0_0
#   qt-webengine                            5.15.9-h90a370e_4 --> 5.15.9-h90a370e_7
#   qtawesome                           1.2.2-py311hecd8cb5_0 --> 1.3.1-py311hecd8cb5_0
#   qtconsole                           5.4.2-py311hecd8cb5_0 --> 5.6.1-py311hecd8cb5_0
#   qtpy                                2.2.0-py311hecd8cb5_0 --> 2.4.1-py311hecd8cb5_0
#   queuelib                            1.5.0-py311hecd8cb5_0 --> 1.6.2-py311hecd8cb5_0
#   regex                            2022.7.9-py311h6c40b1e_0 --> 2024.11.6-py311h46256e1_0
#   reproc                                  14.2.4-he9d5cce_1 --> 14.2.4-hcec6c5f_2
#   reproc-cpp                              14.2.4-he9d5cce_1 --> 14.2.4-hcec6c5f_2
#   rope                                1.7.0-py311hecd8cb5_0 --> 1.12.0-py311hecd8cb5_0
#   scipy                              1.10.1-py311h7695dc5_1 --> 1.15.1-py311hedc7b93_0
#   semver                              3.0.2-py311hecd8cb5_0 --> 3.0.2-py311hecd8cb5_1
#   sip                                6.7.12-py311hcec6c5f_0 --> 6.7.12-py311h6d0c2b6_1
#   snappy                                   1.1.9-he9d5cce_0 --> 1.2.1-h6d0c2b6_0
#   sniffio                             1.2.0-py311hecd8cb5_1 --> 1.3.0-py311hecd8cb5_0
#   soupsieve                             2.4-py311hecd8cb5_0 --> 2.5-py311hecd8cb5_0
#   sphinx                              5.0.2-py311hecd8cb5_0 --> 7.3.7-py311hecd8cb5_0
#   sphinxcontrib-ser~ pkgs/main/noarch::sphinxcontrib-seria~ --> pkgs/main/osx-64::sphinxcontrib-serializinghtml-1.1.10-py311hecd8cb5_0
#   spyder                              5.4.3-py311hecd8cb5_1 --> 6.0.3-py311hecd8cb5_0
#   spyder-kernels                      2.4.3-py311hecd8cb5_0 --> 3.0.2-py311h85bffb1_0
#   sqlite                                  3.41.2-h6c40b1e_0 --> 3.45.3-h6c40b1e_0
#   sympy                              1.11.1-py311hecd8cb5_0 --> 1.13.3-py311hecd8cb5_1
#   tabulate                           0.8.10-py311hecd8cb5_0 --> 0.9.0-py311hecd8cb5_0
#   tenacity                            8.2.2-py311hecd8cb5_0 --> 9.0.0-py311hecd8cb5_0
#   textdistance       pkgs/main/noarch::textdistance-4.2.1-~ --> pkgs/main/osx-64::textdistance-4.6.3-py311h85bffb1_0
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.2.0~ --> pkgs/main/osx-64::threadpoolctl-3.5.0-py311h85bffb1_0
#   tifffile           pkgs/main/noarch::tifffile-2021.7.2-p~ --> pkgs/main/osx-64::tifffile-2025.2.18-py311hecd8cb5_0
#   tinycss2                            1.2.1-py311hecd8cb5_0 --> 1.4.0-py311hecd8cb5_0
#   tk                                      8.6.12-h5d9f67b_0 --> 8.6.14-h4d00af3_0
#   tldextract         pkgs/main/noarch::tldextract-3.2.0-py~ --> pkgs/main/osx-64::tldextract-5.1.2-py311hecd8cb5_0
#   tomlkit                            0.11.1-py311hecd8cb5_0 --> 0.13.2-py311hecd8cb5_0
#   toolz                              0.12.0-py311hecd8cb5_0 --> 1.0.0-py311hecd8cb5_0
#   tornado                             6.3.2-py311h6c40b1e_0 --> 6.4.2-py311h46256e1_0
#   tqdm                               4.65.0-py311h85bffb1_0 --> 4.67.1-py311h85bffb1_0
#   traitlets                           5.7.1-py311hecd8cb5_0 --> 5.14.3-py311hecd8cb5_0
#   truststore                          0.8.0-py311hecd8cb5_0 --> 0.10.0-py311hecd8cb5_0
#   tzdata                                   2023c-h04d1e81_0 --> 2025a-h04d1e81_0
#   ujson                               5.4.0-py311hcec6c5f_0 --> 5.10.0-py311h6d0c2b6_1
#   unidecode          pkgs/main/noarch::unidecode-1.2.0-pyh~ --> pkgs/main/osx-64::unidecode-1.3.8-py311hecd8cb5_0
#   urllib3                           1.26.16-py311hecd8cb5_0 --> 2.3.0-py311hecd8cb5_0
#   utf8proc                                 2.6.1-h9ed2024_0 --> 2.6.1-h6c40b1e_1
#   w3lib              pkgs/main/noarch::w3lib-1.21.0-pyhd3e~ --> pkgs/main/osx-64::w3lib-2.1.2-py311hecd8cb5_0
#   watchdog                            4.0.1-py311h3333b6a_0 --> 4.0.2-py311h3333b6a_0
#   werkzeug                            2.2.3-py311hecd8cb5_0 --> 3.1.3-py311hecd8cb5_0
#   wrapt                              1.14.1-py311h6c40b1e_0 --> 1.17.0-py311h46256e1_0
#   xlwings                            0.29.1-py311hecd8cb5_0 --> 0.32.1-py311hecd8cb5_0
#   xz                                       5.4.2-h6c40b1e_0 --> 5.6.4-h46256e1_1
#   y-py                                0.5.9-py311h7242b5c_0 --> 0.6.2-py311h1405f1f_2
#   yapf               pkgs/main/noarch::yapf-0.31.0-pyhd3eb~ --> pkgs/main/osx-64::yapf-0.40.2-py311hecd8cb5_0
#   yarl                                1.8.1-py311h6c40b1e_0 --> 1.18.0-py311h46256e1_0
#   ypy-websocket                       0.8.2-py311hecd8cb5_0 --> 0.8.4-py311hecd8cb5_0
#   zict                                2.2.0-py311hecd8cb5_0 --> 3.0.0-py311hecd8cb5_0
#   zipp                               3.11.0-py311hecd8cb5_0 --> 3.21.0-py311hecd8cb5_0
#   zlib                                    1.2.13-h4dc903c_0 --> 1.2.13-h4b97444_1
#   zope.interface                      5.4.0-py311h6c40b1e_0 --> 7.1.1-py311h46256e1_0
#   zstandard                          0.19.0-py311h6c40b1e_0 --> 0.23.0-py311h5bcdf72_1
#   zstd                                     1.5.5-hc035e20_0 --> 1.5.6-h138b38a_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   jupyterlab_widgets pkgs/main/osx-64::jupyterlab_widgets-~ --> pkgs/main/noarch::jupyterlab_widgets-1.0.0-pyhd3eb1b0_1
#
# The following packages will be DOWNGRADED:
#
#   ipywidgets                          8.0.4-py311hecd8cb5_0 --> 7.8.1-py311hecd8cb5_0
#   widgetsnbextension                  4.0.5-py311hecd8cb5_0 --> 3.6.6-py311hecd8cb5_0
#
#
#
# Downloading and Extracting Packages:
# textdistance-4.6.3   | 76 KB     |                                       |   0%
# jpeg-9e              | 253 KB    |                                       |   0%
#
# scipy-1.15.1         | 25.2 MB   |                                       |   0%
#
#
# pandas-2.2.3         | 14.9 MB   |                                       |   0%
#
#
#
# c-ares-1.19.1        | 107 KB    |                                       |   0%
#
#
#
#
# xz-5.6.4             | 289 KB    |                                       |   0%
#
#
#
#
#
# imageio-2.37.0       | 621 KB    |                                       |   0%
#
#
#
#
#
#
# ipywidgets-7.8.1     | 231 KB    |                                       |   0%
#
#
#
#
#
#
#
# sphinxcontrib-serial | 34 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# glog-0.5.0           | 95 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# cramjam-2.9.1        | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# future-1.0.0         | 896 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# tomlkit-0.13.2       | 115 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# param-2.2.0          | 272 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 151 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yapf-0.40.2          | 474 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.42          | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# more-itertools-10.3. | 150 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nest-asyncio-1.6.0   | 18 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# frozenlist-1.5.0     | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.10.2      | 55 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.6           | 612 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.3 | 236 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# c-ares-1.19.1        | 107 KB    | #####5                                |  15%
#
#
# textdistance-4.6.3   | 76 KB     | #######8                              |  21%
#
# scipy-1.15.1         | 25.2 MB   |                                       |   0%
# jpeg-9e              | 253 KB    | ##3                                   |   6%
#
#
#
#
# xz-5.6.4             | 289 KB    | ##                                    |   6%
#
#
#
# c-ares-1.19.1        | 107 KB    | ##################################### | 100%
#
#
# textdistance-4.6.3   | 76 KB     | ##################################### | 100%
#
#
#
#
#
# imageio-2.37.0       | 621 KB    | 9                                     |   3%
#
# scipy-1.15.1         | 25.2 MB   | 3                                     |   1%
#
#
# pandas-2.2.3         | 14.9 MB   | ##2                                   |   6%
#
#
#
#
#
#
# ipywidgets-7.8.1     | 231 KB    | ##5                                   |   7%
# jpeg-9e              | 253 KB    | ##################################### | 100%
# jpeg-9e              | 253 KB    | ##################################### | 100%
#
# scipy-1.15.1         | 25.2 MB   | 7                                     |   2%
#
#
#
#
#
# imageio-2.37.0       | 621 KB    | #######6                              |  21%
#
#
#
#
# xz-5.6.4             | 289 KB    | ##################################### | 100%
#
#
#
#
# xz-5.6.4             | 289 KB    | ##################################### | 100%
#
# scipy-1.15.1         | 25.2 MB   | #1                                    |   3%
#
#
# pandas-2.2.3         | 14.9 MB   | ###1                                  |   9%
#
#
#
#
#
# imageio-2.37.0       | 621 KB    | ##################################3   |  93%
#
#
#
#
#
#
#
# sphinxcontrib-serial | 34 KB     | #################3                    |  47%
#
#
#
#
#
#
#
#
# glog-0.5.0           | 95 KB     | ######2                               |  17%
#
#
#
#
#
#
# ipywidgets-7.8.1     | 231 KB    | ##################################### | 100%
#
#
#
#
#
#
# ipywidgets-7.8.1     | 231 KB    | ##################################### | 100%
#
#
# pandas-2.2.3         | 14.9 MB   | #####5                                |  15%
#
# scipy-1.15.1         | 25.2 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
# cramjam-2.9.1        | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
# glog-0.5.0           | 95 KB     | ##################################### | 100%
#
#
# ...
#
#
#
#
#
#
#
# sphinxcontrib-serial | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# sphinxcontrib-serial | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# future-1.0.0         | 896 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# tomlkit-0.13.2       | 115 KB    | #####1                                |  14%
#
#
# pandas-2.2.3         | 14.9 MB   | ######9                               |  19%
#
# scipy-1.15.1         | 25.2 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
# cramjam-2.9.1        | 1.5 MB    | #######9                              |  21%
#
#
#
#
#
#
#
#
#
#
# future-1.0.0         | 896 KB    | #######9                              |  21%
#
# scipy-1.15.1         | 25.2 MB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
# cramjam-2.9.1        | 1.5 MB    | ######################5               |  61%
#
#
#
#
#
#
#
#
#
#
# future-1.0.0         | 896 KB    | ############5                         |  34%
#
#
#
#
#
#
#
#
#
#
#
# tomlkit-0.13.2       | 115 KB    | #########################7            |  70%
#
#
# pandas-2.2.3         | 14.9 MB   | #########                             |  25%
#
#
#
#
#
#
#
#
#
#
#
# tomlkit-0.13.2       | 115 KB    | ##################################### | 100%
#
# scipy-1.15.1         | 25.2 MB   | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
# cramjam-2.9.1        | 1.5 MB    | ##############################5       |  82%
#
#
#
#
#
#
#
#
#
#
# future-1.0.0         | 896 KB    | #####################8                |  59%
#
#
# pandas-2.2.3         | 14.9 MB   | ###########3                          |  31%
#
# scipy-1.15.1         | 25.2 MB   | ####2                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
# param-2.2.0          | 272 KB    | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
# cramjam-2.9.1        | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# future-1.0.0         | 896 KB    | ##############################4       |  82%
#
# scipy-1.15.1         | 25.2 MB   | ####6                                 |  13%
#
#
# pandas-2.2.3         | 14.9 MB   | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
# param-2.2.0          | 272 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# param-2.2.0          | 272 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 151 KB    | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yapf-0.40.2          | 474 KB    | #2                                    |   3%
#
# scipy-1.15.1         | 25.2 MB   | #####2                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 151 KB    | ##################################### | 100%
#
#
# pandas-2.2.3         | 14.9 MB   | ##############2                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.42          | 1.3 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yapf-0.40.2          | 474 KB    | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# more-itertools-10.3. | 150 KB    | ###9                                  |  11%
#
# scipy-1.15.1         | 25.2 MB   | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.42          | 1.3 MB    | ######5                               |  18%
#
# scipy-1.15.1         | 25.2 MB   | ######4                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nest-asyncio-1.6.0   | 18 KB     | #################################5    |  91%
#
#
# pandas-2.2.3         | 14.9 MB   | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# frozenlist-1.5.0     | 53 KB     | ###########2                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.42          | 1.3 MB    | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# more-itertools-10.3. | 150 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.10.2      | 55 KB     | ##########7                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# more-itertools-10.3. | 150 KB    | ##################################### | 100%
#
# scipy-1.15.1         | 25.2 MB   | #######1                              |  19%
#
#
# pandas-2.2.3         | 14.9 MB   | ################7                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nest-asyncio-1.6.0   | 18 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nest-asyncio-1.6.0   | 18 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.42          | 1.3 MB    | #################                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.3 | 236 KB    | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# frozenlist-1.5.0     | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# frozenlist-1.5.0     | 53 KB     | ##################################### | 100%
#
# scipy-1.15.1         | 25.2 MB   | #######7                              |  21%
#
#
# pandas-2.2.3         | 14.9 MB   | #################8                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.42          | 1.3 MB    | #####################8                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.10.2      | 55 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nbclient-0.10.2      | 55 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.6           | 612 KB    | 9                                     |   3%
#
# scipy-1.15.1         | 25.2 MB   | ########3                             |  23%
#
#
# pandas-2.2.3         | 14.9 MB   | ##################9                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.42          | 1.3 MB    | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.6           | 612 KB    | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# yapf-0.40.2          | 474 KB    | ##################################### | 100%
#
# scipy-1.15.1         | 25.2 MB   | ########9                             |  24%
#
#
# pandas-2.2.3         | 14.9 MB   | ####################1                 |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.42          | 1.3 MB    | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.6           | 612 KB    | ##############################9       |  84%
#
# scipy-1.15.1         | 25.2 MB   | #########4                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.3 | 236 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.3 | 236 KB    | ##################################### | 100%
#
#
# pandas-2.2.3         | 14.9 MB   | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
# future-1.0.0         | 896 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# future-1.0.0         | 896 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.6           | 612 KB    | ##################################### | 100%
#
# scipy-1.15.1         | 25.2 MB   | ##########                            |  27%
#
#
# pandas-2.2.3         | 14.9 MB   | ######################2               |  60%
#
# scipy-1.15.1         | 25.2 MB   | ##########7                           |  29%
#
#
# pandas-2.2.3         | 14.9 MB   | #######################2              |  63%
#
# scipy-1.15.1         | 25.2 MB   | ###########3                          |  31%
#
#
# pandas-2.2.3         | 14.9 MB   | ########################4             |  66%
#
# scipy-1.15.1         | 25.2 MB   | ###########9                          |  32%
#
#
# pandas-2.2.3         | 14.9 MB   | #########################4            |  69%
#
# scipy-1.15.1         | 25.2 MB   | ############9                         |  35%
#
#
# pandas-2.2.3         | 14.9 MB   | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.42          | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pcre2-10.42          | 1.3 MB    | ##################################### | 100%
#
# scipy-1.15.1         | 25.2 MB   | #############6                        |  37%
#
#
# pandas-2.2.3         | 14.9 MB   | ############################1         |  76%
#
# scipy-1.15.1         | 25.2 MB   | ##############3                       |  39%
#
#
# pandas-2.2.3         | 14.9 MB   | #############################3        |  79%
#
# scipy-1.15.1         | 25.2 MB   | ##############9                       |  40%
#
#
# pandas-2.2.3         | 14.9 MB   | ##############################4       |  82%
#
# scipy-1.15.1         | 25.2 MB   | ###############5                      |  42%
#
#
# pandas-2.2.3         | 14.9 MB   | ###############################6      |  86%
#
# scipy-1.15.1         | 25.2 MB   | ################1                     |  44%
#
#
# pandas-2.2.3         | 14.9 MB   | ################################7     |  89%
#
# scipy-1.15.1         | 25.2 MB   | ################7                     |  45%
#
#
# pandas-2.2.3         | 14.9 MB   | #################################8    |  92%
#
# scipy-1.15.1         | 25.2 MB   | #################3                    |  47%
#
#
# pandas-2.2.3         | 14.9 MB   | ##################################9   |  94%
#
# scipy-1.15.1         | 25.2 MB   | #################9                    |  49%
#
#
# pandas-2.2.3         | 14.9 MB   | ###################################9  |  97%
#
# scipy-1.15.1         | 25.2 MB   | ##################5                   |  50%
#
#
# pandas-2.2.3         | 14.9 MB   | ####################################9 | 100%
#
# scipy-1.15.1         | 25.2 MB   | ###################                   |  52%
#
# scipy-1.15.1         | 25.2 MB   | ####################                  |  54%
#
# scipy-1.15.1         | 25.2 MB   | ####################7                 |  56%
#
# scipy-1.15.1         | 25.2 MB   | #####################4                |  58%
#
# scipy-1.15.1         | 25.2 MB   | ######################1               |  60%
#
# scipy-1.15.1         | 25.2 MB   | ######################9               |  62%
#
# scipy-1.15.1         | 25.2 MB   | #######################7              |  64%
#
# scipy-1.15.1         | 25.2 MB   | ########################4             |  66%
#
# scipy-1.15.1         | 25.2 MB   | #########################4            |  69%
#
# scipy-1.15.1         | 25.2 MB   | ##########################2           |  71%
#
# scipy-1.15.1         | 25.2 MB   | ###########################1          |  73%
#
# scipy-1.15.1         | 25.2 MB   | ###########################9          |  75%
#
# scipy-1.15.1         | 25.2 MB   | ############################7         |  78%
#
# scipy-1.15.1         | 25.2 MB   | #############################5        |  80%
#
# scipy-1.15.1         | 25.2 MB   | ##############################6       |  83%
#
# scipy-1.15.1         | 25.2 MB   | ###############################5      |  85%
#
# scipy-1.15.1         | 25.2 MB   | #################################3    |  90%
#
# scipy-1.15.1         | 25.2 MB   | ##################################4   |  93%
#
# scipy-1.15.1         | 25.2 MB   | ###################################5  |  96%
#
# scipy-1.15.1         | 25.2 MB   | ####################################5 |  99%
#
#
# pandas-2.2.3         | 14.9 MB   | ##################################### | 100%
#
# scipy-1.15.1         | 25.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# donearing transaction: |
# donefying transaction: -
# doneuting transaction: /
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Installing packages

# %%
conda create -n scispacy-env python=3.11
# Out:
# Collecting package metadatadone
# doneing environment: /
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.9.0
#   latest version: 25.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.3.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/mike/anaconda3/envs/scispacy-env
#
#   added / updated specs:
#     - python=3.11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-3.0.16             |       h184c1cd_0         4.6 MB
#     pip-25.0                   |  py311hecd8cb5_0         2.9 MB
#     python-3.11.11             |       h4d6d9e5_0        15.7 MB
#     setuptools-75.8.0          |  py311hecd8cb5_0         2.2 MB
#     wheel-0.45.1               |  py311hecd8cb5_0         156 KB
#     ------------------------------------------------------------
#                                            Total:        25.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              pkgs/main/osx-64::bzip2-1.0.8-h6c40b1e_6
#   ca-certificates    pkgs/main/osx-64::ca-certificates-2025.2.25-hecd8cb5_0
#   libffi             pkgs/main/osx-64::libffi-3.4.4-hecd8cb5_1
#   ncurses            pkgs/main/osx-64::ncurses-6.4-hcec6c5f_0
#   openssl            pkgs/main/osx-64::openssl-3.0.16-h184c1cd_0
#   pip                pkgs/main/osx-64::pip-25.0-py311hecd8cb5_0
#   python             pkgs/main/osx-64::python-3.11.11-h4d6d9e5_0
#   readline           pkgs/main/osx-64::readline-8.2-hca72f7f_0
#   setuptools         pkgs/main/osx-64::setuptools-75.8.0-py311hecd8cb5_0
#   sqlite             pkgs/main/osx-64::sqlite-3.45.3-h6c40b1e_0
#   tk                 pkgs/main/osx-64::tk-8.6.14-h4d00af3_0
#   tzdata             pkgs/main/noarch::tzdata-2025a-h04d1e81_0
#   wheel              pkgs/main/osx-64::wheel-0.45.1-py311hecd8cb5_0
#   xz                 pkgs/main/osx-64::xz-5.6.4-h46256e1_1
#   zlib               pkgs/main/osx-64::zlib-1.2.13-h4b97444_1
#
#
# ^Coceed ([y]/n)?
#
# CondaSystemExit:
# Operation aborted.  Exiting.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scispacy
# Out:
# Requirement already satisfied: scispacy in ./anaconda3/lib/python3.11/site-packages (0.5.5)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in ./anaconda3/lib/python3.11/site-packages (from scispacy) (3.7.5)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.11/site-packages (from scispacy) (1.15.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from scispacy) (2.32.3)
# Requirement already satisfied: conllu in ./anaconda3/lib/python3.11/site-packages (from scispacy) (6.0.0)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.11/site-packages (from scispacy) (1.24.3)
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.11/site-packages (from scispacy) (1.4.2)
# Requirement already satisfied: scikit-learn>=0.20.3 in ./anaconda3/lib/python3.11/site-packages (from scispacy) (1.3.0)
# Requirement already satisfied: pysbd in ./anaconda3/lib/python3.11/site-packages (from scispacy) (0.3.4)
# Requirement already satisfied: nmslib-metabrainz==2.1.3 in ./anaconda3/lib/python3.11/site-packages (from scispacy) (2.1.3)
# Requirement already satisfied: pybind11>=2.2.3 in ./anaconda3/lib/python3.11/site-packages (from nmslib-metabrainz==2.1.3->scispacy) (2.13.6)
# Requirement already satisfied: psutil in ./anaconda3/lib/python3.11/site-packages (from nmslib-metabrainz==2.1.3->scispacy) (5.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.3->scispacy) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (4.67.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.8.2)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.1.6)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in ./anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (4.12.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->scispacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz (14.8 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.8.0,>=3.7.4 in ./anaconda3/lib/python3.11/site-packages (from en-core-sci-sm==0.5.4) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.8.2)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.1.6)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.24.3)
# Requirement already satisfied: language-data>=1.2 in ./anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import spacy

from scispacy.abbreviation import AbbreviationDetector

nlp = spacy.load("en_core_sci_sm")
# Out:
# /Users/mike/anaconda3/lib/python3.11/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %% [markdown]
# # Tokenization and chunking

# %%
# folder path
folder_path = "Theses_clean_data/final_patent_text.csv"

# %%
df = pd.read_csv(folder_path)

# %%
df.head()
# Out:
#   ApplicationNumber                                             Titles  \
# 0     US20220083465  system and method for tissue intervention via ...
# 1     US20180497284  treatment of a disease of the gastrointestinal...
# 2     US20190467784  treatment of a disease of the gastrointestinal...
# 3     US20170465360  treatment of a disease of the gastrointestinal...
# 4     US20210295221  apparatus and methods for use with image-guide...
#
#                                            Abstracts  \
# 0  one embodiment is directed to a minimally inva...
# 1  this disclosure features methods and compositi...
# 2  this disclosure features methods and compositi...
# 3  this disclosure features methods and compositi...
# 4  a procedure is performed with respect to a ske...
#
#                                               Claims  \
# 0   . a minimally invasive system for treating a ...
# 1   . a method of treating a disease of the gastr...
# 2   . a method of treating a disease of the gastr...
# 3   . a method of treating a disease of the gastr...
# 4   . a method for performing a procedure with re...
#
#                                                 IPCs  \
# 0                         ['A61B34/10', 'A61B34/20']
# 1  ['A61K31/7105', 'A61M31/00', 'C12N15/11', 'C12...
# 2  ['A61B1/04', 'A61B1/273', 'A61B5/00', 'A61K31/...
# 3  ['A61B5/00', 'A61B5/01', 'A61B5/07', 'A61B5/14...
# 4  ['A61B34/10', 'A61B34/30', 'A61B90/00', 'G06T7...
#
#                                                 CPCs  ProbablePatentAssignee  \
# 0  ['A61B2034/107', 'A61B2034/2051', 'A61B2034/20...      PETAL SURGICAL INC
# 1  ['A61B1/04', 'A61B5/06', 'A61B5/062', 'A61B5/0...  BIORA THERAPEUTICS INC
# 2  ['A61B1/041', 'A61B1/273', 'A61B5/0071', 'A61B...  BIORA THERAPEUTICS INC
# 3  ['A61B1/041', 'A61B2010/0061', 'A61B5/0075', '...  BIORA THERAPEUTICS INC
# 4  ['A61B2034/105', 'A61B2034/107', 'A61B2034/204...        VUZE MEDICAL LTD
#
#   EarliestPriorityDate  claim_length  abstract_length  Year
# 0           2021-12-16         13540              178  2021
# 1           2017-03-30         12792               24  2017
# 2           2016-12-14         12711               17  2016
# 3           2016-12-14         12694               17  2016
# 4           2018-11-22         12632              139  2018

# %%
sample_df = df[['ApplicationNumber','Claims', 'ProbablePatentAssignee','EarliestPriorityDate']].sample(n=1, random_state=100).dropna()

# %%
sample_df
# Out:
#       ApplicationNumber                                             Claims  \
# 43776     US20230142093   . an apparatus, comprising: an intravascular ...
#
#       ProbablePatentAssignee EarliestPriorityDate
# 43776    PHILIPS KONINKLL NV           2016-11-11

# %%
print(sample_df['Claims'].iloc[0])
# Out:
#  . an apparatus, comprising: an intravascular ultrasound (ivus) imaging device comprising: a catheter configured to be positioned within a blood vessel and comprising a proximal portion and a distal portion; an ultrasound transducer array coupled to the distal portion and comprising a rolled configuration, at least one integrated circuit chip coupled to the distal portion and configured to: control the ultrasound transducer array to emit ultrasound energy and receive ultrasound echoes associated with the ultrasound energy; and perform a first processing of ultrasound echo signals representative of the ultrasound echoes; a signal processor coupled to the proximal portion and configured to: receive the ultrasound echo signals after the first processing has been performed; and perform a second processing of ultrasound echo signals; a transceiver coupled to the proximal portion and configured to receive the ultrasound echo signals after the second processing has been performed; and an antenna coupled to the proximal portion and configured to wirelessly transmit the ultrasound echo signals . the apparatus of claim , wherein the antenna is configured to wirelessly receive an instruction signal from a computer remote from the ivus imaging device, wherein the signal processor is configured to: generate a control signal based on the instruction signal; and transmit the control signal to the at least one integrated circuit chip to control the ultrasound transducer array . the apparatus of claim , wherein, to generate the control signal, the signal processor is configured to perform at least one of demodulation or decoding of the instruction signal to recover the control signal . the apparatus of claim , wherein, in response to the control signal, the at least one integrated circuit chip is configured to at least one of: in a transmit mode, select a first transducer element of the ultrasound transducer array to emit the ultrasound energy; and trigger the transducer element to emit the ultrasound energy; or in a receive mode, select a second transducer element of the ultrasound transducer array to receive the ultrasound echoes . the apparatus of claim , further comprising the computer, wherein the computer is configured to: receive the ultrasound echo signals wirelessly transmitted by the antenna; and output, to a monitor configured for communication with the computer, a cross-sectional ivus image based on the ultrasound echo signals . the apparatus of claim , wherein the at least one integrated circuit chip comprises an application specific integrated circuit (asic . the apparatus of claim , wherein the at least one integrated circuit chip comprises a plurality of integrated circuit chips, wherein the plurality of integrated circuit chips comprises the rolled configuration . the apparatus of claim , wherein the first processing comprises a multiplexing of the ultrasound echo signals . the apparatus of claim , wherein the second processing comprises at least one of a filtering, an amplifying, an aggregating, or a compressing of the ultrasound echo signals . the apparatus of claim , wherein the transceiver is configured to perform a third processing of the ultrasound echo signals . the apparatus of claim , wherein the third processing comprises at least one of framing, encoding, scrambling, or modulation . the apparatus of claim , wherein the antenna is configured to receive the ultrasound echo signals after the third processing has been performed . the apparatus of claim , further comprising a cable extending between the distal portion and the proximal portion, wherein the cable is configured to carry the ultrasound echo signals from the at least one integrated circuit chip to the signal processor . the apparatus of claim , further comprising a power source coupled to the proximal portion, wherein the power source is configured to provide power to at least one of the signal processor, the transceiver, or the ultrasound transducer array .  ...

# %% [markdown]
# # Chunking & Tokenization

# %%
def chunk_and_tokenize(df, text_column, app_number_column="ApplicationNumber", model="en_core_sci_sm", chunk_size=300):
    nlp = spacy.load(model)

    new_rows = []  

    for index, row in df.iterrows():
        text = row[text_column]
        app_number = row[app_number_column]
        doc = nlp(text)

        # Tokenization & Chunking
        words = [token.text for token in doc if not token.is_punct and not token.is_space]
        num_chunks = (len(words) // chunk_size) + (1 if len(words) % chunk_size > 0 else 0)  # Count chunks

        for chunk_id, i in enumerate(range(0, len(words), chunk_size), start=1):
            chunk = " ".join(words[i:i + chunk_size])
            new_rows.append({
                "original_index": index,
                "ApplicationNumber": app_number,
                "chunk_id": chunk_id,
                "num_chunks": num_chunks,
                "chunk": chunk,
            })

    return pd.DataFrame(new_rows)

# %%
test_chunked = chunk_and_tokenize(sample_df, text_column="Claims")

# %%
test_chunked.head()
# Out:
#    original_index ApplicationNumber  chunk_id  num_chunks  \
# 0           43776     US20230142093         1           3
# 1           43776     US20230142093         2           3
# 2           43776     US20230142093         3           3
#
#                                                chunk
# 0  an apparatus comprising an intravascular ultra...
# 1  element to emit the ultrasound energy or in a ...
# 2  the apparatus of claim further comprising a ha...

# %%
chunked_df = chunk_and_tokenize(df, text_column="Claims")

# %%
# save df to csv
chunked_df.to_csv('chunked_df.csv', index=False)

# %%
print(f"Number of unique Application no's: {len(chunked_df.ApplicationNumber.unique())}")
# Out:
# Number of unique Application no's: 51626

# %%
chunked_df.head()
# Out:
#    original_index ApplicationNumber  chunk_id  num_chunks  \
# 0               0     US20220083465         1          43
# 1               0     US20220083465         2          43
# 2               0     US20220083465         3          43
# 3               0     US20220083465         4          43
# 4               0     US20220083465         5          43
#
#                                                chunk
# 0  a minimally invasive system for treating a tar...
# 1  load sensor a joint torque sensor a strain gau...
# 2  system of claim wherein the hifu treatment tra...
# 3  in part by an acoustic fountain reaction assoc...
# 4  data the system of claim further comprising a ...

# %%
chunked_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219715 entries, 0 to 219714
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   original_index     219715 non-null  int64
#  1   ApplicationNumber  219715 non-null  object
#  2   chunk_id           219715 non-null  int64
#  3   num_chunks         219715 non-null  int64
#  4   chunk              219715 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 8.4+ MB
