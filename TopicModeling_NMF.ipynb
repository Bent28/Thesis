# %% [markdown]
# <h1>NMF<h1>

# %%
# folder path
folder_path = "Theses_clean_data/final_patent_text.csv"

# %% [markdown]
# # Installing packages

# %%
# !pip install pyldavis
# Out:
# Requirement already satisfied: pyldavis in ./anaconda3/lib/python3.11/site-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (1.24.3)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (1.13.1)
# Requirement already satisfied: pandas>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (1.4.2)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (3.1.6)
# Requirement already satisfied: numexpr in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (2.10.1)
# Requirement already satisfied: funcy in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (1.3.0)
# Requirement already satisfied: gensim in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (4.3.3)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->pyldavis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->pyldavis) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->pyldavis) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.0->pyldavis) (3.5.0)
# Requirement already satisfied: smart-open>=1.8.1 in ./anaconda3/lib/python3.11/site-packages (from gensim->pyldavis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->pyldavis) (3.0.2)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyldavis) (1.16.0)

# %%
pip install scispacy
# Out:
# Requirement already satisfied: scispacy in ./anaconda3/lib/python3.11/site-packages (0.5.5)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in ./anaconda3/lib/python3.11/site-packages (from scispacy) (3.7.5)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.11/site-packages (from scispacy) (1.13.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from scispacy) (2.32.3)
# Requirement already satisfied: conllu in ./anaconda3/lib/python3.11/site-packages (from scispacy) (6.0.0)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.11/site-packages (from scispacy) (1.24.3)
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.11/site-packages (from scispacy) (1.4.2)
# Requirement already satisfied: scikit-learn>=0.20.3 in ./anaconda3/lib/python3.11/site-packages (from scispacy) (1.3.0)
# Requirement already satisfied: pysbd in ./anaconda3/lib/python3.11/site-packages (from scispacy) (0.3.4)
# Requirement already satisfied: nmslib-metabrainz==2.1.3 in ./anaconda3/lib/python3.11/site-packages (from scispacy) (2.1.3)
# Requirement already satisfied: pybind11>=2.2.3 in ./anaconda3/lib/python3.11/site-packages (from nmslib-metabrainz==2.1.3->scispacy) (2.13.6)
# Requirement already satisfied: psutil in ./anaconda3/lib/python3.11/site-packages (from nmslib-metabrainz==2.1.3->scispacy) (5.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.3->scispacy) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (4.67.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.8.2)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.1.6)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in ./anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (4.12.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->scispacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->scispacy) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz (14.8 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.8.0,>=3.7.4 in ./anaconda3/lib/python3.11/site-packages (from en-core-sci-sm==0.5.4) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.8.2)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.1.6)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.24.3)
# Requirement already satisfied: language-data>=1.2 in ./anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.4->en-core-sci-sm==0.5.4) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pyLDAvis gensim
# Out:
# Requirement already satisfied: pyLDAvis in ./anaconda3/lib/python3.11/site-packages (3.4.1)
# Requirement already satisfied: gensim in ./anaconda3/lib/python3.11/site-packages (4.3.3)
# Requirement already satisfied: numpy>=1.24.2 in ./anaconda3/lib/python3.11/site-packages (from pyLDAvis) (1.24.3)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.11/site-packages (from pyLDAvis) (1.13.1)
# Requirement already satisfied: pandas>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from pyLDAvis) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in ./anaconda3/lib/python3.11/site-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from pyLDAvis) (3.1.6)
# Requirement already satisfied: numexpr in ./anaconda3/lib/python3.11/site-packages (from pyLDAvis) (2.10.1)
# Requirement already satisfied: funcy in ./anaconda3/lib/python3.11/site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from pyLDAvis) (1.3.0)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.11/site-packages (from pyLDAvis) (68.0.0)
# Requirement already satisfied: smart-open>=1.8.1 in ./anaconda3/lib/python3.11/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->pyLDAvis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->pyLDAvis) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->pyLDAvis) (3.0.2)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade joblib
# Out:
# Requirement already satisfied: joblib in ./anaconda3/lib/python3.11/site-packages (1.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyldavis
# Out:
# Requirement already satisfied: pyldavis in ./anaconda3/lib/python3.11/site-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (1.24.3)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (1.13.1)
# Requirement already satisfied: pandas>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (1.4.2)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (3.1.6)
# Requirement already satisfied: numexpr in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (2.10.1)
# Requirement already satisfied: funcy in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (1.3.0)
# Requirement already satisfied: gensim in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (4.3.3)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.11/site-packages (from pyldavis) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->pyldavis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->pyldavis) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->pyldavis) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.0->pyldavis) (3.5.0)
# Requirement already satisfied: smart-open>=1.8.1 in ./anaconda3/lib/python3.11/site-packages (from gensim->pyldavis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->pyldavis) (3.0.2)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyldavis) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip install SpaCy
! python -m spacy download en
# Out:
# Requirement already satisfied: SpaCy in ./anaconda3/lib/python3.11/site-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (2.8.2)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (3.1.6)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in ./anaconda3/lib/python3.11/site-packages (from SpaCy) (1.24.3)
# Requirement already satisfied: language-data>=1.2 in ./anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->SpaCy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->SpaCy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->SpaCy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->SpaCy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->SpaCy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->SpaCy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->SpaCy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->SpaCy) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->SpaCy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->SpaCy) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->SpaCy) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->SpaCy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->SpaCy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->SpaCy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->SpaCy) (1.2.1)
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 10.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in ./anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.6)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in ./anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: language-data>=1.2 in ./anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import pandas as pd
import random
import numpy as np
import re
import gensim
import gensim.corpora as corpora
from gensim.models.ldamodel import LdaModel
from gensim.corpora import Dictionary
from gensim.models import LdaMulticore, Phrases
from gensim.models.phrases import Phraser
from gensim.models import CoherenceModel
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import spacy
from gensim.models import LdaMulticore, CoherenceModel
from tqdm import tqdm
import pyLDAvis
import pyLDAvis.gensim
import pyLDAvis.gensim_models as gensimvis
import matplotlib.pyplot as plt
from pprint import pprint
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import scienceplots
import tqdm
plt.style.use(['science','no-latex'])
plt.rcParams["figure.figsize"] = (6, 5)
sns.color_palette("muted")

# Download NLTK resources
nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package stopwords to /Users/mike/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/mike/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/mike/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import umap
import matplotlib.pyplot as plt

# %%
from gensim.models.nmf import Nmf

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# # Adding custom stopwords

# %%
stopwords_path = 'USPTO_stopwords_en.txt'

# %%
uspto_stopwords = open('USPTO_stopwords_en.txt',"r")
print(uspto_stopwords.read())
# Out:
# a
# accordance
# according
# all
# also
# an
# and
# another
# are
# as
# at
# be
# because
# been
# being
# by
# claim
# comprises
# corresponding
# could
# described
# desired
# do
# does
# each
# embodiment
# fig
# figs
# for
# from
# further
# generally
# had
# has
# have
# having
# herein
# however
# if
# in
# into
# invention
# is
# it
# its
# means
# not
# now
# of
# on
# onto
# or
# other
# particularly
# preferably
# preferred
# present
# provide
# provided
# provides
# relatively
# respectively
# said
# should
# since
# some
# such
# suitable
# than
# that
# the
# their
# then
# there
# thereby
# therefore
# thereof
# thereto
# these
# they
# this
# those
# thus
# to
# use
# various
# was
# were
# what
# when
# where
# whereby
# wherein
# which
# while
# who
# will
# with
# would

# %%
stop_words = set(stopwords.words('english'))

# %%
print(stop_words)
# Out:
# {'ve', "she's", 'very', 'if', "you're", 'do', 'shouldn', 'those', 'been', "he'll", 'against', 'into', "they've", 'does', "don't", "you'd", 'be', 'nor', 'm', 'then', "haven't", 'once', 'these', "you've", "it'll", 'i', "it'd", "i'm", 'at', "needn't", 'being', 'her', 'while', "doesn't", 'yours', "should've", 'and', 'there', 'here', 'after', 'doesn', 'not', 'having', "shan't", "hadn't", 'had', 'so', 'under', 'again', "isn't", 're', 'will', 'other', 'where', 'now', 't', "i've", 'herself', 'with', 'just', 'that', 'only', 'mightn', "it's", 'before', 'ma', 'between', 'its', 'shan', 'whom', 'off', 'any', 'further', 'your', 's', "you'll", 'below', 'my', "she'd", 'over', 'didn', 'yourselves', 'o', 'for', "hasn't", 'hadn', 'which', 'some', "he's", 'him', 'were', "won't", "we'll", 'll', 'who', "we're", 'are', 'through', 'myself', 'wouldn', "mustn't", 'the', 'themselves', 'aren', 'weren', 'mustn', 'own', 'was', 'hers', 'but', 'when', 'is', 'doing', "we've", 'this', 'because', 'same', 'they', 'ain', 'how', 'hasn', 'why', 'no', 'our', 'up', 'a', "couldn't", 'did', 'has', 'it', 'theirs', "we'd", "weren't", 'won', 'have', 'about', 'don', 'needn', 'during', 'his', "aren't", 'their', 'she', 'wasn', 'couldn', 'should', 'too', 'haven', 'isn', "shouldn't", 'more', 'than', 'itself', "he'd", 'such', "they're", "wouldn't", 'of', 'until', 'you', 'd', 'as', "mightn't", 'all', 'from', "that'll", "she'll", 'himself', 'yourself', 'an', 'what', 'ourselves', 'am', 'down', 'each', 'both', 'we', 'out', "they'll", "they'd", 'by', 'can', 'ours', 'above', 'on', 'them', 'he', 'or', "i'll", "wasn't", "i'd", "didn't", 'to', 'me', 'most', 'y', 'in', 'few'}

# %%
# stopwords to add: one, first, second, comprising, least, method, end

# %%
number_words = [
            "one", "two", "three", "four", "five", "six", "seven", "eight", "nine", "ten",
            "first", "second", "third", "fourth", "fifth", "sixth", "seventh", "eighth", "ninth", "tenth",
            "eleventh", "twelfth", "thirteenth", "fourteenth", "fifteenth", "sixteenth", "seventeenth", "eighteenth", "nineteenth", "twenty",]

# %%
extra_stopwords = ["comprising", "least", "method", "end", "set"]

# %%
df = pd.read_csv(folder_path)

# %%
#extending nltk corpus stopwords
uspto_stopwords = set()
with open("USPTO_stopwords_en.txt", "r", encoding="utf-8") as file:
    uspto_stopwords = {line.strip() for line in file if line.strip()}

extended_stopwords = stop_words.union(extra_stopwords, number_words, uspto_stopwords)
print(list(extended_stopwords)[:])
# Out:
# ['sixth', 've', "she's", 'very', 'do', 'those', 'fifth', 'against', 'into', 'does', 'desired', "you'd", 'ninth', 'm', 'then', "haven't", 'once', "it'd", 'at', 'second', 'while', "doesn't", 'and', 'not', 'end', 'having', "hadn't", 'thirteenth', 're', 'provided', 'other', 'where', 'now', 'first', 'with', 'just', 'five', 'only', "it's", 'before', 'onto', 'shan', 'respectively', 'off', 'any', 'further', 's', 'my', 'over', 'o', "hasn't", 'hadn', 'one', 'some', "he's", 'him', 'tenth', 'll', 'since', "we're", 'provides', 'preferably', 'myself', 'four', 'could', 'aren', 'weren', 'own', 'thereby', 'two', 'but', 'doing', "we've", 'this', 'various', 'they', 'same', 'thus', 'how', 'no', 'up', 'particularly', 'a', 'did', "weren't", 'theirs', 'have', 'sixteenth', 'three', 'eleventh', 'his', 'seven', 'their', 'couldn', 'should', 'too', 'haven', 'described', 'than', 'itself', "they're", 'said', 'until', 'you', 'ten', "mightn't", "that'll", "she'll", 'himself', 'fourth', 'am', 'both', 'out', "they'll", 'corresponding', 'by', 'can', 'them', 'he', 'or', 'therefore', "i'll", "wasn't", "i'd", 'most', 'y', 'few', "you're", 'if', 'shouldn', 'means', 'claim', 'been', "he'll", "they've", 'thereof', "don't", 'be', 'nor', "you've", 'these', "it'll", 'twenty', 'i', "i'm", 'nineteenth', 'fourteenth', "needn't", 'being', 'her', 'least', 'yours', "should've", 'comprises', 'there', 'here', 'after', 'doesn', "shan't", 'had', 'so', 'under', 'again', "isn't", 'whereby', 'will', 't', "i've", 'herself', 'that', 'mightn', 'eight', 'fig', 'ma', 'between', 'its', 'whom', 'six', 'nine', 'your', "you'll", 'below', 'eighth', "she'd", 'didn', 'yourselves', 'for', 'accordance', 'which', 'also', 'were', "won't", "we'll", 'who', 'fifteenth', 'according', 'are', 'through', 'provide', 'wouldn', "mustn't", 'embodiment', 'the', 'themselves', 'thereto', 'mustn', 'was', 'seventeenth', 'another', 'hers', 'when', 'is', 'because', 'wherein', 'ain', 'hasn', 'why', 'our', 'has', "couldn't", 'it', "we'd", 'would', 'won', 'invention', 'about', 'don', 'needn', 'during', "aren't", 'she', 'wasn', 'figs', 'isn', "shouldn't", 'generally', 'more', 'preferred', 'set', 'such', "he'd", "wouldn't", 'herein', 'suitable', 'of', 'd', 'as', 'all', 'from', 'yourself', 'an', 'what', 'ourselves', 'comprising', 'twelfth', 'down', 'each', 'method', 'relatively', 'we', 'use', "they'd", 'third', 'present', 'ours', 'above', 'on', 'seventh', 'however', "didn't", 'eighteenth', 'to', 'me', 'in']

# %%
print(extended_stopwords)
# Out:
# {'sixth', 've', "she's", 'very', 'do', 'those', 'fifth', 'against', 'into', 'does', 'desired', "you'd", 'ninth', 'm', 'then', "haven't", 'once', "it'd", 'at', 'second', 'while', "doesn't", 'and', 'not', 'end', 'having', "hadn't", 'thirteenth', 're', 'provided', 'other', 'where', 'now', 'first', 'with', 'just', 'five', 'only', "it's", 'before', 'onto', 'shan', 'respectively', 'off', 'any', 'further', 's', 'my', 'over', 'o', "hasn't", 'hadn', 'one', 'some', "he's", 'him', 'tenth', 'll', 'since', "we're", 'provides', 'preferably', 'myself', 'four', 'could', 'aren', 'weren', 'own', 'thereby', 'two', 'but', 'doing', "we've", 'this', 'various', 'they', 'same', 'thus', 'how', 'no', 'up', 'particularly', 'a', 'did', "weren't", 'theirs', 'have', 'sixteenth', 'three', 'eleventh', 'his', 'seven', 'their', 'couldn', 'should', 'too', 'haven', 'described', 'than', 'itself', "they're", 'said', 'until', 'you', 'ten', "mightn't", "that'll", "she'll", 'himself', 'fourth', 'am', 'both', 'out', "they'll", 'corresponding', 'by', 'can', 'them', 'he', 'or', 'therefore', "i'll", "wasn't", "i'd", 'most', 'y', 'few', "you're", 'if', 'shouldn', 'means', 'claim', 'been', "he'll", "they've", 'thereof', "don't", 'be', 'nor', "you've", 'these', "it'll", 'twenty', 'i', "i'm", 'nineteenth', 'fourteenth', "needn't", 'being', 'her', 'least', 'yours', "should've", 'comprises', 'there', 'here', 'after', 'doesn', "shan't", 'had', 'so', 'under', 'again', "isn't", 'whereby', 'will', 't', "i've", 'herself', 'that', 'mightn', 'eight', 'fig', 'ma', 'between', 'its', 'whom', 'six', 'nine', 'your', "you'll", 'below', 'eighth', "she'd", 'didn', 'yourselves', 'for', 'accordance', 'which', 'also', 'were', "won't", "we'll", 'who', 'fifteenth', 'according', 'are', 'through', 'provide', 'wouldn', "mustn't", 'embodiment', 'the', 'themselves', 'thereto', 'mustn', 'was', 'seventeenth', 'another', 'hers', 'when', 'is', 'because', 'wherein', 'ain', 'hasn', 'why', 'our', 'has', "couldn't", 'it', "we'd", 'would', 'won', 'invention', 'about', 'don', 'needn', 'during', "aren't", 'she', 'wasn', 'figs', 'isn', "shouldn't", 'generally', 'more', 'preferred', 'set', 'such', "he'd", "wouldn't", 'herein', 'suitable', 'of', 'd', 'as', 'all', 'from', 'yourself', 'an', 'what', 'ourselves', 'comprising', 'twelfth', 'down', 'each', 'method', 'relatively', 'we', 'use', "they'd", 'third', 'present', 'ours', 'above', 'on', 'seventh', 'however', "didn't", 'eighteenth', 'to', 'me', 'in'}

# %%
print(f"Extended Stopwords: {len(extended_stopwords)} words")
print(f"NLTK Stopwords: {len(stop_words)} words")
# Out:
# Extended Stopwords: 274 words
# NLTK Stopwords: 198 words

# %%
columns = 8
stop = list(extended_stopwords)
rows = (len(stop) + columns - 1) // columns
table_data = [stop[i * columns : (i + 1) * columns] for i in range(rows)]

df_stop_words = pd.DataFrame(table_data)
print(df_stop_words.to_string(index=False, header=False))
# Out:
#     sixth           ve         she's       very        do      those      fifth     against
#      into         does       desired      you'd     ninth          m       then     haven't
#      once         it'd            at     second     while    doesn't        and         not
#       end       having        hadn't thirteenth        re   provided      other       where
#       now        first          with       just      five       only       it's      before
#      onto         shan  respectively        off       any    further          s          my
#      over            o        hasn't       hadn       one       some       he's         him
#     tenth           ll         since      we're  provides preferably     myself        four
#     could         aren         weren        own   thereby        two        but       doing
#     we've         this       various       they      same       thus        how          no
#        up particularly             a        did   weren't     theirs       have   sixteenth
#     three     eleventh           his      seven     their     couldn     should         too
#     haven    described          than     itself   they're       said      until         you
#       ten     mightn't       that'll     she'll   himself     fourth         am        both
#       out      they'll corresponding         by       can       them         he          or
# therefore         i'll        wasn't        i'd      most          y        few      you're
#        if      shouldn         means      claim      been      he'll    they've     thereof
#     don't           be           nor     you've     these      it'll     twenty           i
#       i'm   nineteenth    fourteenth    needn't     being        her      least       yours
# should've    comprises         there       here     after      doesn     shan't         had
#        so        under         again      isn't   whereby       will          t        i've
#   herself         that        mightn      eight       fig         ma    between         its
#      whom          six          nine       your    you'll      below     eighth       she'd
#      didn   yourselves           for accordance     which       also       were       won't
#     we'll          who     fifteenth  according       are    through    provide      wouldn
#   mustn't   embodiment           the themselves   thereto      mustn        was seventeenth
#   another         hers          when         is   because    wherein        ain        hasn
#       why          our           has   couldn't        it       we'd      would         won
# invention        about           don      needn    during     aren't        she        wasn
#      figs          isn     shouldn't  generally      more  preferred        set        such
#      he'd     wouldn't        herein   suitable        of          d         as         all
#      from     yourself            an       what ourselves comprising    twelfth        down
#      each       method    relatively         we       use     they'd      third     present
#      ours        above            on    seventh   however     didn't eighteenth          to
#        me           in          None       None      None       None       None        None

# %% [markdown]
# # Def preprocessing functions

# %%
df = df['Claims']
#sample_df = df['Claims'].sample(n=1000, random_state=42).dropna().tolist()

# %%
#def tokenization using gensim
def tokenize_text(text):
    return gensim.utils.simple_preprocess(text, deacc=True)

# %%
# tokenize & remove stopwords
def tokenize(texts, extended_stopwords):
    return [[word for word in tokenize_text(text) if word not in extended_stopwords] for text in texts]

# %%
#Creating n-grams
def create_ngrams(texts, min_count=5, threshold=100):
    bigram_phrases = gensim.models.Phrases(texts, min_count=min_count, threshold=threshold)
    trigram_phrases = gensim.models.Phrases(bigram_phrases[texts], threshold=threshold)
    
    bigram = gensim.models.phrases.Phraser(bigram_phrases)
    trigram = gensim.models.phrases.Phraser(trigram_phrases)
    
    bigrams = [bigram[doc] for doc in texts]
    trigrams = [trigram[bigram[doc]] for doc in bigrams]
    
    return trigrams

# %%
def lemmatize_texts(texts, allowed_postags, extended_stopwords):
    nlp = spacy.load("en_core_sci_sm", disable=["parser", "ner"])
    allowed_postags_set = set(allowed_postags)
    
    lemmatized_texts = []
    for doc in nlp.pipe([" ".join(text) for text in texts], batch_size=500):
        lemmatized_texts.append(
            [token.lemma_ for token in doc if token.pos_ in allowed_postags_set and token.lemma_ not in extended_stopwords]
        )
    
    return lemmatized_texts

# %%
def preprocess_texts(texts, extended_stopwords):    
    # Preprocess texts
    tokenized_texts = tokenize(texts,extended_stopwords)

    # Create bigrams and trigrams
    data_bigrams_trigrams = create_ngrams(tokenized_texts, min_count=5, threshold=100)

    # Lemmatize texts 
    allowed_postags = ["NOUN", "ADJ", "VERB", "ADV"] 
    lemmatized_texts = lemmatize_texts(data_bigrams_trigrams, allowed_postags, extended_stopwords)

    return lemmatized_texts  

if __name__ == "__preprocess_texts__":
    pass

# %%
cleaned_texts = preprocess_texts(df, extended_stopwords)

cleaned_texts_as_strings = [' '.join(text) for text in cleaned_texts]

cleaned_df = pd.DataFrame(cleaned_texts_as_strings, columns=["cleaned_text"])

cleaned_df.to_csv('cleaned_texts.csv', index=False)
# Out:
# /Users/mike/anaconda3/lib/python3.11/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51626 entries, 0 to 51625
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cleaned_text  51626 non-null  object
# dtypes: object(1)
# memory usage: 403.5+ KB

# %% [markdown]
# # **NMF Topic modelling**

# %% [markdown]
# ## Calc optimal number of topics using Coherence Score

# %%
extended_stopwords = list(extended_stopwords)

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([" ".join(text) for text in cleaned_texts])
feature_names = vectorizer.get_feature_names_out()
dictionary = Dictionary(cleaned_texts)

# %%
coherence_scores = []
for num in range(20, 36, 2):
    nmf = NMF(n_components=num, max_iter=1000, random_state=42)
    W = nmf.fit_transform(tfidf_matrix) 
    H = nmf.components_  

    topics = []
    for topic_idx in range(H.shape[0]):
        top_words = [feature_names[i] for i in H[topic_idx].argsort()[-10:]] 
        topics.append(top_words)

    cm = CoherenceModel(topics=topics, texts=cleaned_texts, dictionary=dictionary, coherence='c_v')
    coherence_score = cm.get_coherence()
    
    coherence_scores.append(coherence_score)
    print(f"Coherence Score for {num} topics: {coherence_score}")

# Plot coherence scores
plt.figure(figsize=(8, 6))
plt.plot(range(20, 36, 2), coherence_scores, marker='o', linestyle='-', color='b')
plt.title('Coherence Scores for Different Numbers of Topics')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score')
plt.xticks(range(20, 36, 2))
plt.grid(True)
plt.show()
# Out:
# Coherence Score for 20 topics: 0.5949796014598159
# Coherence Score for 22 topics: 0.6026215141629702
# Coherence Score for 24 topics: 0.6093900458368241
# Coherence Score for 26 topics: 0.6043308463890665
# Coherence Score for 28 topics: 0.6127656023986352
# Coherence Score for 30 topics: 0.5847661407363987
# Coherence Score for 32 topics: 0.6090093551248903
# Coherence Score for 34 topics: 0.6169666021409427

# %% [markdown]
# ## Running NMF model on optimal topic no

# %%
#tfidf vector
tfidf_vectorizer = TfidfVectorizer(
    min_df=3,                 
    max_df=0.85,              
    max_features=10000,       
    ngram_range=(1, 3),      
)

tfidf_matrix = tfidf_vectorizer.fit_transform([" ".join(text) for text in cleaned_texts])
tfidf_fn = tfidf_vectorizer.get_feature_names_out()

# NMF model
num_topics = 24  
nmf = NMF(
    n_components=num_topics,  
    init='nndsvd',            
    max_iter=1000,             
    random_state=42            
)

nmf.fit(tfidf_matrix)
# Out:
# NMF(init='nndsvd', max_iter=1000, n_components=24, random_state=42)

# %%
#extracting topics & words
n_top_words = 10
feature_names = tfidf_fn

for topic_idx, topic in enumerate(nmf.components_):
    print(f"Topic #{topic_idx + 1}:")
    top_words_idx = topic.argsort()[-n_top_words:][::-1] 
    top_words = [feature_names[i] for i in top_words_idx]
    print(" ".join(top_words))
    print()
# Out:
# Topic #1:
# image display region processing imaging medical image image processing image datum object pixel
#
# Topic #2:
# assembly shaft drive housing effector jaw gear handle motor distal
#
# Topic #3:
# light light source source wavelength illumination emit light emit light guide illumination light endoscope
#
# Topic #4:
# ultrasound ultrasound image probe transducer ultrasound probe ultrasound transducer ultrasound imaging imaging ultrasound system ultrasound imaging system
#
# Topic #5:
# surgical instrument surgical instrument surgical system surgical procedure procedure surgical device system effector jaw
#
# Topic #6:
# datum image datum generate system datum include data datum generate module time datum datum
#
# Topic #7:
# medical medical device medical image medical instrument information medical imaging instrument medical system apparatus medical information
#
# Topic #8:
# signal unit circuit frequency control apparatus value output configure voltage
#
# Topic #9:
# member elongate member elongate jaw tubular member tubular jaw member member configure member include support
#
# Topic #10:
# arm robotic robotic arm joint robot system robotic system control surgical robotic robotic surgical
#
# Topic #11:
# electrode tissue ablation energy electrical treatment target plurality electrode target tissue impedance
#
# Topic #12:
# portion endoscope body surface distal side section insertion direction proximal
#
# Topic #13:
# needle biopsy guide tissue cannula needle guide suture sample biopsy needle tip
#
# Topic #14:
# optical fiber optical fiber lens optical system laser beam system core optical axis
#
# Topic #15:
# element layer transducer piezoelectric substrate material array surface acoustic transducer element
#
# Topic #16:
# ultrasonic probe transducer ultrasonic transducer wave ultrasonic probe ultrasonic wave ultrasonic image ultrasonic diagnostic acoustic
#
# Topic #17:
# patient user information model computer system treatment plurality health machine
#
# Topic #18:
# tool surgical tool surgical surgical system system treatment tool virtual procedure robotic surgical tool surgical
#
# Topic #19:
# device medical device user control configure display imaging device body device configure communication
#
# Topic #20:
# catheter distal lumen balloon proximal sheath tip wire elongate guidewire
#
# Topic #21:
# bone implant model guide surface virtual cut point joint anatomical
#
# Topic #22:
# blood vessel blood vessel flow blood flow pressure fluid value region velocity
#
# Topic #23:
# tube fluid channel outer distal inner lumen proximal outer tube suction
#
# Topic #24:
# sensor system magnetic field magnetic field electromagnetic position frame location radiation

# %%
n_top_words = 10
feature_names = tfidf_vectorizer.get_feature_names_out()

# Plot the top words for each topic
for topic_idx, topic in enumerate(nmf.components_):
    top_words_idx = topic.argsort()[-n_top_words:][::-1]
    top_words = [feature_names[i] for i in top_words_idx]

    plt.figure(figsize=(10, 6))
    plt.barh(top_words, topic[top_words_idx], color='skyblue')
    plt.title(f"Topic {topic_idx + 1}")
    plt.xlabel('Word Importance')
    plt.ylabel('Words')
    plt.show()

# %%
umap_model = umap.UMAP(n_components=2, random_state=42)
topic_umap = umap_model.fit_transform(nmf.components_)

plt.figure(figsize=(10, 6))
plt.scatter(topic_umap[:, 0], topic_umap[:, 1], c='green', edgecolors='k')
for i, txt in enumerate(range(num_topics)):
    plt.annotate(f"Topic {txt + 1}", (topic_umap[i, 0], topic_umap[i, 1]), fontsize=12)
plt.title("NMF Topic 2D distribution(UMAP)")
plt.xlabel("UMAP Dim1")
plt.ylabel("UMAP Dim2")
plt.show()
# Out:
# /Users/mike/anaconda3/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
