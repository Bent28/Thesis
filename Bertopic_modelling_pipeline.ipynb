# %% [markdown]
# # **Installing Packages**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# File path
file_path = "/content/drive/MyDrive/Theses/chunked_df.csv"

# %%
# !pip install -U numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Collecting numpy
#   Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.0 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 65.3 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.4 which is incompatible.
# Successfully installed numpy-2.2.4

# %%
# !pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.2.4)

# %%
pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.0.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.50.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.30.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.2.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)
# Downloading sentence_transformers-4.0.2-py3-none-any.whl (340 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.6/340.6 kB 10.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 23.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 35.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.4.1
#     Uninstalling sentence-transformers-3.4.1:
#       Successfully uninstalled sentence-transformers-3.4.1
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 sentence-transformers-4.0.2

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (3.4.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.5.7)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.14.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.51.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.1.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.13.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.1.31)
# Downloading bertopic-0.17.0-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 60.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bertopic
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bertopic-0.17.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install --upgrade bertopic
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.11/dist-packages (0.17.0)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.0.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.5.7)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.14.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.50.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.30.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.13.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.1.31)

# %%
# !pip install bertopic transformers torch
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.11/dist-packages (0.17.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.0.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.5.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.14.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.1.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)

# %%
# !pip install git+https://github.com/colaberry/ctfidf.git
# Out:
# Collecting git+https://github.com/colaberry/ctfidf.git
#   Cloning https://github.com/colaberry/ctfidf.git to /tmp/pip-req-build-53x5cnzv
#   Running command git clone --filter=blob:none --quiet https://github.com/colaberry/ctfidf.git /tmp/pip-req-build-53x5cnzv
#   fatal: could not read Username for 'https://github.com': No such device or address
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/colaberry/ctfidf.git /tmp/pip-req-build-53x5cnzv did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/colaberry/ctfidf.git /tmp/pip-req-build-53x5cnzv did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np
from bertopic import BERTopic
import torch
from sentence_transformers import SentenceTransformer
import re
import random

# %%
from umap import UMAP
from sklearn.decomposition import PCA
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import hdbscan
from hdbscan import HDBSCAN
# %matplotlib inline

# %%
import pickle
from bertopic import BERTopic
from bertopic.dimensionality import BaseDimensionalityReduction
from bertopic.representation import KeyBERTInspired, PartOfSpeech
from bertopic.cluster import BaseCluster
from bertopic.vectorizers import ClassTfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %%
from bertopic.vectorizers import ClassTfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # **Bertopic**

# %% [markdown]
# ## **Creating Embeddings**

# %%
df = pd.read_csv(file_path)

# %%
chunk_texts = df["chunk"].tolist()

# %%
sentence_model = SentenceTransformer('AI-Growth-Lab/PatentSBERTa')
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.88k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/671 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/440 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# creating embeddings
embeddings = sentence_model.encode(chunk_texts, convert_to_numpy=True, show_progress_bar=True)
assert len(embeddings) == len(df)
df["embedding"] = list(embeddings)

#saving embeddings
np.save('/content/drive/MyDrive/Theses/embedded_chunks', embeddings)
df.to_pickle('/content/drive/MyDrive/Theses/chunked_df_with_embeddings.pkl')
# Out:
# Batches:   0%|          | 0/6867 [00:00<?, ?it/s]

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219715 entries, 0 to 219714
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   original_index     219715 non-null  int64
#  1   ApplicationNumber  219715 non-null  object
#  2   chunk_id           219715 non-null  int64
#  3   num_chunks         219715 non-null  int64
#  4   chunk              219715 non-null  object
#  5   embedding          219715 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 10.1+ MB
#    original_index ApplicationNumber  chunk_id  num_chunks  \
# 0               0     US20220083465         1          43
# 1               0     US20220083465         2          43
# 2               0     US20220083465         3          43
# 3               0     US20220083465         4          43
# 4               0     US20220083465         5          43
#
#                                                chunk  \
# 0  a minimally invasive system for treating a tar...
# 1  load sensor a joint torque sensor a strain gau...
# 2  system of claim wherein the hifu treatment tra...
# 3  in part by an acoustic fountain reaction assoc...
# 4  data the system of claim further comprising a ...
#
#                                            embedding
# 0  [0.102507465, -0.4690934, -0.16641176, -0.1034...
# 1  [5.1148196e-05, -0.2560497, -0.21868536, -0.10...
# 2  [-0.095717534, -0.15502435, -0.14605981, -0.13...
# 3  [0.07438903, -0.2188163, -0.16725114, -0.08933...
# 4  [0.03889325, 0.11438014, -0.18144202, 0.072535...

# %%
print(f"Number of unique Application no's: {len(df.ApplicationNumber.unique())}")
# Out:
# Number of unique Application no's: 51626

# %% [markdown]
# ## **Dimension reduction**

# %%
embeddings = np.load('/content/drive/MyDrive/Theses/embedded_chunks.npy')

# %%
print(embeddings.shape)
# Out:
# (219715, 768)

# %%
df = pickle.load(open('/content/drive/MyDrive/Theses/chunked_df_with_embeddings.pkl', 'rb'))

# %%
#rescaling embeddings for convergence issues as best suggested approach
#https://maartengr.github.io/BERTopic/getting_started/tips_and_tricks/tips_and_tricks.html#speed-up-umap
def rescale(x, inplace=False):
    if not inplace:
        x = np.array(x, copy=True)
    x /= np.std(x[:, 0]) * 10000
    return x

# %%
#dim reduction using pca
rescaled_embeddings = rescale(embeddings)

# PCA 50 dim
pca_50 = PCA(n_components=50)
pca_embeddings_50 = pca_50.fit_transform(rescaled_embeddings)
with open('pca_model_50.pkl', 'wb') as pca_output_50:
    pickle.dump(pca_50, pca_output_50, protocol=pickle.HIGHEST_PROTOCOL)

# PCA 100 dim
pca_100 = PCA(n_components=100)
pca_embeddings_100 = pca_100.fit_transform(rescaled_embeddings)
with open('pca_model_100.pkl', 'wb') as pca_output_100:
    pickle.dump(pca_100, pca_output_100, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# UMAP 50 dim
umap_model_50 = UMAP(n_neighbors=30, n_components=2, min_dist=0.0, metric='cosine')
umap_embeddings_50 = umap_model_50.fit_transform(pca_embeddings_50)

with open("umap_model_50.pkl", "wb") as umap_output_50:
    pickle.dump(umap_model_50, umap_output_50, protocol=pickle.HIGHEST_PROTOCOL)

np.save('/content/drive/MyDrive/Theses/umap_embeddings_50.npy', umap_embeddings_50)

# UMAP 100 dim
umap_model_100 = UMAP(n_neighbors=30, n_components=2, min_dist=0.0, metric='cosine')
umap_embeddings_100 = umap_model_100.fit_transform(pca_embeddings_100)

with open("umap_model_100.pkl", "wb") as umap_output_100:
    pickle.dump(umap_model_100, umap_output_100, protocol=pickle.HIGHEST_PROTOCOL)

np.save('/content/drive/MyDrive/Theses/umap_embeddings_100.npy', umap_embeddings_100)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# UMAP 50 dim
axes[0].scatter(umap_embeddings_50[:, 0], umap_embeddings_50[:, 1], s=1, alpha=0.5)
axes[0].set_title('UMAP Embeddings (50 Dimensions PCA)')
axes[0].set_xlabel('UMAP Dimension 1')
axes[0].set_ylabel('UMAP Dimension 2')

# UMAP 100 dim
axes[1].scatter(umap_embeddings_100[:, 0], umap_embeddings_100[:, 1], s=1, alpha=0.5)
axes[1].set_title('UMAP Embeddings (100 Dimensions PCA)')
axes[1].set_xlabel('UMAP Dimension 1')
axes[1].set_ylabel('UMAP Dimension 2')
plt.tight_layout()
plt.show()

# %%
# UMAP 50 dim
umap_model_50_3d = UMAP(n_neighbors=30, n_components=3, min_dist=0.0, metric='cosine')
umap_embeddings_50_3d = umap_model_50_3d.fit_transform(pca_embeddings_50)

with open("umap_model_50_3d.pkl", "wb") as umap_output_50_3d:
    pickle.dump(umap_model_50_3d, umap_output_50_3d, protocol=pickle.HIGHEST_PROTOCOL)

np.save('/content/drive/MyDrive/Theses/umap_embeddings_50_3d.npy', umap_embeddings_50_3d)

# %% [markdown]
# ## **Clustering** (HDBSCAN)

# %%
final_umap_embeddings = np.load('/content/drive/MyDrive/Theses/umap_embeddings_50_3d.npy')
final_umap_embeddings.shape
# Out:
# (219715, 3)

# %%
df = pickle.load(open('/content/drive/MyDrive/Theses/chunked_df_with_embeddings.pkl', 'rb'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219715 entries, 0 to 219714
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   original_index     219715 non-null  int64
#  1   ApplicationNumber  219715 non-null  object
#  2   chunk_id           219715 non-null  int64
#  3   num_chunks         219715 non-null  int64
#  4   chunk              219715 non-null  object
#  5   embedding          219715 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 10.1+ MB

# %%
df['chunk'] = df['chunk'].astype(str)

# %%
df.head()
# Out:
#    original_index ApplicationNumber  chunk_id  num_chunks  \
# 0               0     US20220083465         1          43
# 1               0     US20220083465         2          43
# 2               0     US20220083465         3          43
# 3               0     US20220083465         4          43
# 4               0     US20220083465         5          43
#
#                                                chunk  \
# 0  a minimally invasive system for treating a tar...
# 1  load sensor a joint torque sensor a strain gau...
# 2  system of claim wherein the hifu treatment tra...
# 3  in part by an acoustic fountain reaction assoc...
# 4  data the system of claim further comprising a ...
#
#                                            embedding
# 0  [0.102507465, -0.4690934, -0.16641176, -0.1034...
# 1  [5.1148196e-05, -0.2560497, -0.21868536, -0.10...
# 2  [-0.095717534, -0.15502435, -0.14605981, -0.13...
# 3  [0.07438903, -0.2188163, -0.16725114, -0.08933...
# 4  [0.03889325, 0.11438014, -0.18144202, 0.072535...

# %%
print(f"Number of rows in dataframe: {df.shape[0]}")
print(f"Number of rows in UMAP embeddings: {final_umap_embeddings.shape[0]}")
# Out:
# Number of rows in dataframe: 219715
# Number of rows in UMAP embeddings: 219715

# %%
hdbscan_model_25 = hdbscan.HDBSCAN(min_cluster_size=25, cluster_selection_method='eom',metric='euclidean',algorithm='best',prediction_data=True)
hdbscan_labels_25 = hdbscan_model_25.fit_predict(final_umap_embeddings)

with open('hdbscan_model_25.pkl', 'wb') as hdbscan_file_25:
    pickle.dump(hdbscan_model_25, hdbscan_file_25, protocol=pickle.HIGHEST_PROTOCOL)

# %%
hdbscan_model_60 = hdbscan.HDBSCAN(min_cluster_size=60, cluster_selection_method='eom',metric='euclidean',algorithm='best',prediction_data=True)
hdbscan_labels_60 = hdbscan_model_60.fit_predict(final_umap_embeddings)

with open('hdbscan_model_60.pkl', 'wb') as hdbscan_file_60:
    pickle.dump(hdbscan_model_60, hdbscan_file_60, protocol=pickle.HIGHEST_PROTOCOL)

# %%
hdbscan_model_100 = hdbscan.HDBSCAN(min_cluster_size=100, cluster_selection_method='eom',metric='euclidean',algorithm='best',prediction_data=True)
hdbscan_labels_100 = hdbscan_model_100.fit_predict(final_umap_embeddings)

with open('hdbscan_model_100.pkl', 'wb') as hdbscan_file_100:
    pickle.dump(hdbscan_model_100, hdbscan_file_100, protocol=pickle.HIGHEST_PROTOCOL)

# %%
df['hdbscan_cluster_25'] = hdbscan_labels_25
df[df['hdbscan_cluster_25'] != -1]
df['hdbscan_cluster_60'] = hdbscan_labels_60
df[df['hdbscan_cluster_60'] != -1]
df['hdbscan_cluster_100'] = hdbscan_labels_100
df[df['hdbscan_cluster_100'] != -1]
df.to_pickle('/content/drive/MyDrive/Theses/df.pkl')

# %%
df_loaded = pd.read_pickle('/content/drive/MyDrive/Theses/df.pkl')

# %%
df = pd.DataFrame(df)
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6738eca0a1c1> in <cell line: 0>()
# ----> 1 df = pd.DataFrame(df)
#       2 df.info()
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#    original_index ApplicationNumber  chunk_id  num_chunks  \
# 0               0     US20220083465         1          43
# 1               0     US20220083465         2          43
# 2               0     US20220083465         3          43
# 3               0     US20220083465         4          43
# 4               0     US20220083465         5          43
#
#                                                chunk  \
# 0  a minimally invasive system for treating a tar...
# 1  load sensor a joint torque sensor a strain gau...
# 2  system of claim wherein the hifu treatment tra...
# 3  in part by an acoustic fountain reaction assoc...
# 4  data the system of claim further comprising a ...
#
#                                            embedding  hdbscan_cluster_25  \
# 0  [0.102507465, -0.4690934, -0.16641176, -0.1034...                  -1
# 1  [5.1148196e-05, -0.2560497, -0.21868536, -0.10...                  -1
# 2  [-0.095717534, -0.15502435, -0.14605981, -0.13...                  -1
# 3  [0.07438903, -0.2188163, -0.16725114, -0.08933...                  -1
# 4  [0.03889325, 0.11438014, -0.18144202, 0.072535...                  -1
#
#    hdbscan_cluster_60  hdbscan_cluster_100
# 0                  10                    2
# 1                  -1                   -1
# 2                  10                    2
# 3                  10                    2
# 4                  -1                   -1

# %%
# plot hdbscan
def remove_outliers(embeddings, labels):
    mask = labels != -1
    return embeddings[mask], labels[mask]

umap_25, labels_25_no_noise = remove_outliers(final_umap_embeddings, hdbscan_labels_25)
umap_60, labels_60_no_noise = remove_outliers(final_umap_embeddings, hdbscan_labels_60)
umap_100, labels_100_no_noise = remove_outliers(final_umap_embeddings, hdbscan_labels_100)

# subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
plt.suptitle('Clustering on dif min_cluster_size')

axes[0].scatter(umap_25[:, 0], umap_25[:, 1], c=labels_25_no_noise, cmap='Spectral', s=5)
axes[0].set_title('HDBSCAN (min_cluster_size=25)')

axes[1].scatter(umap_60[:, 0], umap_60[:, 1], c=labels_60_no_noise, cmap='Spectral', s=5)
axes[1].set_title('HDBSCAN (min_cluster_size=60)')

axes[2].scatter(umap_100[:, 0], umap_100[:, 1], c=labels_100_no_noise, cmap='Spectral', s=5)
axes[2].set_title('HDBSCAN (min_cluster_size=100)')

for ax in axes:
    ax.set_xlabel('UMAP 1')
    ax.set_ylabel('UMAP 2')

plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

def plot_3d(embeddings, labels, title="3D UMAP"):
    mask = labels != -1
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(embeddings[mask, 0], embeddings[mask, 1], embeddings[mask, 2],
               c=labels[mask], cmap='Spectral', s=5)
    ax.set_title(title)
    plt.show()

plot_3d(final_umap_embeddings, hdbscan_labels_100, title="HDBSCAN (min_cluster=100) on 3D UMAP")

# %%
from sklearn.metrics import silhouette_score

# %%
# calc silhouette core
silhouette_avg_25 = silhouette_score(umap_25, labels_25_no_noise)
print(f"Silhouette Score (min_cluster_size=25): {silhouette_avg_25}")

silhouette_avg_60 = silhouette_score(umap_60, labels_60_no_noise)
print(f"Silhouette Score (min_cluster_size=60): {silhouette_avg_60}")

silhouette_avg_100 = silhouette_score(umap_100, labels_100_no_noise)
print(f"Silhouette Score (min_cluster_size=100): {silhouette_avg_100}")
# Out:
# Silhouette Score (min_cluster_size=25): 0.29919207096099854
# Silhouette Score (min_cluster_size=60): 0.14651930332183838
# Silhouette Score (min_cluster_size=100): 0.3807320296764374

# %%
def plot_cluster_distribution(df, cluster_col, min_cluster_size=15):
    df_no_outliers = df[df[cluster_col] != -1]

    print(f'Number of topics for min_cluster_size={min_cluster_size}: {len(df_no_outliers[cluster_col].unique())}')
    print(f'Amount of noise (outliers): {len(df) - len(df_no_outliers)}')
    print(f'Top cluster size: {df_no_outliers[cluster_col].value_counts().head(1).iloc[0]}')

    top_clusters = df_no_outliers[cluster_col].value_counts().head(20)
    ax = sns.barplot(x=top_clusters.values, y=top_clusters.index, orient='h', order=top_clusters.index)
    ax.set_ylabel('Topic number')
    ax.set_xlabel('Count')
    ax.set_title(f'Top 20 Largest Topics for min_cluster_size={min_cluster_size}')
    plt.rcParams.update({'font.size': 7})
    ax.bar_label(ax.containers[0])
    plt.rcParams.update({'font.size': 10})
    plt.show()

plot_cluster_distribution(df, 'hdbscan_cluster_25', min_cluster_size=25)
plot_cluster_distribution(df, 'hdbscan_cluster_60', min_cluster_size=60)
plot_cluster_distribution(df, 'hdbscan_cluster_100', min_cluster_size=100)
# Out:
# Number of topics for min_cluster_size=25: 375
# Amount of noise (outliers): 134341
# Top cluster size: 12612
# Number of topics for min_cluster_size=60: 85
# Amount of noise (outliers): 101289
# Top cluster size: 30717
# Number of topics for min_cluster_size=100: 53
# Amount of noise (outliers): 104909
# Top cluster size: 23363

# %%
with open('hdbscan_model_100.pkl', 'rb') as inp:
    hdbscan_model = pickle.load(inp)

# %%
# df cluster
cluster_df = pd.DataFrame({
    'ApplicationNumber': df['ApplicationNumber'],
    'chunk': df['chunk'],
    'chunk_id': df['chunk_id'],
    'cluster_label': hdbscan_model_100.labels_
})
cluster_df_no_outliers = cluster_df[cluster_df['cluster_label'] != -1]

cluster_labels = cluster_df_no_outliers['cluster_label'].unique()

docu_ls = []
for label in cluster_labels:
    temp_df = cluster_df_no_outliers[cluster_df_no_outliers['cluster_label'] == label]
    document = ''.join(temp_df['chunk'].to_list())
    docu_ls.append(document)

cluster_document_df = pd.DataFrame({'cluster': cluster_labels, 'cluster_document': docu_ls})

print(cluster_document_df.shape)
# Out:
# (53, 2)

# %% [markdown]
# Add custom stopwords

# %%
Extended_Stopwords = pd.read_csv("/content/drive/MyDrive/Theses/extended_stopwords").to_numpy().flatten().tolist()

# %%
count_vectorizer = CountVectorizer(stop_words=Extended_Stopwords, min_df=2, ngram_range=(1, 3)).fit(cluster_document_df.cluster_document)
count = count_vectorizer.transform(cluster_document_df.cluster_document)
words = count_vectorizer.get_feature_names_out() ; print('Vectorizer done')
ctfidf_transformer = ClassTfidfTransformer(reduce_frequent_words=True)
ctfidf_matrix = ctfidf_transformer.fit_transform(count).toarray()
print("c-TF-IDF done")

# top 10 words per cluster
words_per_class = {
    cluster: [words[i] for i in ctfidf_matrix[idx].argsort()[-10:]]
    for idx, cluster in enumerate(cluster_document_df.cluster)
}

# save clus
df_words_per_class = pd.DataFrame.from_dict(words_per_class, orient='index', columns=[f'Word_{i+1}' for i in range(10)])
df_words_per_class.to_csv('/content/drive/MyDrive/Theses/ctfidf_100.csv')

print("Saved top words per cluster to CSV")
# Out:
# Vectorizer done
# c-TF-IDF done
# Saved top words per cluster to CSV

# %%
df_words_per_class.head()
# Out:
#                       Word_1              Word_2            Word_3  \
# 2                      array  ultrasound imaging              wave
# 11                     tumor            compound                ch
# 29          wavelength range               nm nm  excitation light
# 22  respect subjectapos body  ray imaging device      tool respect
# 10                 andor ion               smoke      ion mobility
#
#                   Word_4            Word_5            Word_6  \
# 2               acoustic  ultrasound probe  ultrasound image
# 11                  cell            cancer             agent
# 29            excitation             light        wavelength
# 22             ray image        ray images  location portion
# 10  aerosol smoke vapour      smoke vapour     aerosol smoke
#
#                    Word_7           Word_8       Word_9       Word_10
# 2                   probe       transducer   ultrasonic    ultrasound
# 11                  cells          percent         acid   composition
# 29                 tissue  peak wavelength  reflectance            nm
# 22  location portion tool              ray     skeletal  portion tool
# 10                 vapour          aerosol   ion source           ion

# %%
r_umap_embeddings = np.load('/content/drive/MyDrive/Theses/umap_embeddings_50_3d.npy')

# %%
df = pd.read_pickle('/content/drive/MyDrive/Theses/df.pkl')
df
# Out:
#         original_index ApplicationNumber  chunk_id  num_chunks  \
# 0                    0     US20220083465         1          43
# 1                    0     US20220083465         2          43
# 2                    0     US20220083465         3          43
# 3                    0     US20220083465         4          43
# 4                    0     US20220083465         5          43
# ...                ...               ...       ...         ...
# 219710           51621     US20210527046         1           1
# 219711           51622     US20240826061         1           1
# 219712           51623     US20210328898         1           1
# 219713           51624     US20200913236         1           1
# 219714           51625     US20240413363         1           1
#
#                                                     chunk  \
# 0       a minimally invasive system for treating a tar...
# 1       load sensor a joint torque sensor a strain gau...
# 2       system of claim wherein the hifu treatment tra...
# 3       in part by an acoustic fountain reaction assoc...
# 4       data the system of claim further comprising a ...
# ...                                                   ...
# 219710  a dental tool comprising a dental bur having a...
# 219711  a device comprising a diffractive optics senso...
# 219712  an apparatus for electronically producing at l...
# 219713  an integrated value based care return on inves...
# 219714  a surgical robot system as substantially shown...
#
#                                                 embedding  hdbscan_cluster_25  \
# 0       [0.102507465, -0.4690934, -0.16641176, -0.1034...                  -1
# 1       [5.1148196e-05, -0.2560497, -0.21868536, -0.10...                  -1
# 2       [-0.095717534, -0.15502435, -0.14605981, -0.13...                  -1
# 3       [0.07438903, -0.2188163, -0.16725114, -0.08933...                  -1
# 4       [0.03889325, 0.11438014, -0.18144202, 0.072535...                  -1
# ...                                                   ...                 ...
# 219710  [0.20198575, -0.54403746, -0.17521329, -0.2867...                  -1
# 219711  [-0.13728589, -0.725161, -0.2967089, -0.197800...                 294
# 219712  [-0.05236339, -0.28899363, -0.12927833, -0.392...                  -1
# 219713  [-0.10989852, -0.3885529, -0.3383775, 0.009414...                  -1
# 219714  [0.20027116, -0.48158565, -0.31080633, -0.3169...                  -1
#
#         hdbscan_cluster_60  hdbscan_cluster_100
# 0                       10                    2
# 1                       -1                   -1
# 2                       10                    2
# 3                       10                    2
# 4                       -1                   -1
# ...                    ...                  ...
# 219710                  -1                   -1
# 219711                  77                   -1
# 219712                  -1                   -1
# 219713                  -1                   -1
# 219714                  76                   49
#
# [219715 rows x 9 columns]

# %%
model_chunks = df['chunk'].astype(str).tolist()
print(len(model_chunks))
# Out:
# 219715

# %% [markdown]
# # Vizualize topics

# %%
details_df = pd.read_csv('/content/drive/MyDrive/Theses/final_patent_text.csv', usecols=['ApplicationNumber', 'ProbablePatentAssignee', 'Year'])
details_df
# Out:
#       ApplicationNumber  ProbablePatentAssignee  Year
# 0         US20220083465      PETAL SURGICAL INC  2021
# 1         US20180497284  BIORA THERAPEUTICS INC  2017
# 2         US20190467784  BIORA THERAPEUTICS INC  2016
# 3         US20170465360  BIORA THERAPEUTICS INC  2016
# 4         US20210295221        VUZE MEDICAL LTD  2018
# ...                 ...                     ...   ...
# 51621     US20210527046       DENTLYTEC GPL LTD  2015
# 51622     US20240826061  BIORA THERAPEUTICS INC  2016
# 51623     US20210328898    SMART REPORTING GMBH  2015
# 51624     US20200913236     MY MEDICAL HUB CORP  2019
# 51625     US20240413363      GLOBUS MEDICAL INC  2016
#
# [51626 rows x 3 columns]

# %%
df = pd.read_pickle('/content/drive/MyDrive/Theses/df.pkl')
df
# Out:
#         original_index ApplicationNumber  chunk_id  num_chunks  \
# 0                    0     US20220083465         1          43
# 1                    0     US20220083465         2          43
# 2                    0     US20220083465         3          43
# 3                    0     US20220083465         4          43
# 4                    0     US20220083465         5          43
# ...                ...               ...       ...         ...
# 219710           51621     US20210527046         1           1
# 219711           51622     US20240826061         1           1
# 219712           51623     US20210328898         1           1
# 219713           51624     US20200913236         1           1
# 219714           51625     US20240413363         1           1
#
#                                                     chunk  \
# 0       a minimally invasive system for treating a tar...
# 1       load sensor a joint torque sensor a strain gau...
# 2       system of claim wherein the hifu treatment tra...
# 3       in part by an acoustic fountain reaction assoc...
# 4       data the system of claim further comprising a ...
# ...                                                   ...
# 219710  a dental tool comprising a dental bur having a...
# 219711  a device comprising a diffractive optics senso...
# 219712  an apparatus for electronically producing at l...
# 219713  an integrated value based care return on inves...
# 219714  a surgical robot system as substantially shown...
#
#                                                 embedding  hdbscan_cluster_25  \
# 0       [0.102507465, -0.4690934, -0.16641176, -0.1034...                  -1
# 1       [5.1148196e-05, -0.2560497, -0.21868536, -0.10...                  -1
# 2       [-0.095717534, -0.15502435, -0.14605981, -0.13...                  -1
# 3       [0.07438903, -0.2188163, -0.16725114, -0.08933...                  -1
# 4       [0.03889325, 0.11438014, -0.18144202, 0.072535...                  -1
# ...                                                   ...                 ...
# 219710  [0.20198575, -0.54403746, -0.17521329, -0.2867...                  -1
# 219711  [-0.13728589, -0.725161, -0.2967089, -0.197800...                 294
# 219712  [-0.05236339, -0.28899363, -0.12927833, -0.392...                  -1
# 219713  [-0.10989852, -0.3885529, -0.3383775, 0.009414...                  -1
# 219714  [0.20027116, -0.48158565, -0.31080633, -0.3169...                  -1
#
#         hdbscan_cluster_60  hdbscan_cluster_100
# 0                       10                    2
# 1                       -1                   -1
# 2                       10                    2
# 3                       10                    2
# 4                       -1                   -1
# ...                    ...                  ...
# 219710                  -1                   -1
# 219711                  77                   -1
# 219712                  -1                   -1
# 219713                  -1                   -1
# 219714                  76                   49
#
# [219715 rows x 9 columns]

# %%
df = df.merge(details_df[['ApplicationNumber', 'Year', 'ProbablePatentAssignee']], on='ApplicationNumber', how='left')

# %%
df
# Out:
#         original_index ApplicationNumber  chunk_id  num_chunks  \
# 0                    0     US20220083465         1          43
# 1                    0     US20220083465         2          43
# 2                    0     US20220083465         3          43
# 3                    0     US20220083465         4          43
# 4                    0     US20220083465         5          43
# ...                ...               ...       ...         ...
# 219710           51621     US20210527046         1           1
# 219711           51622     US20240826061         1           1
# 219712           51623     US20210328898         1           1
# 219713           51624     US20200913236         1           1
# 219714           51625     US20240413363         1           1
#
#                                                     chunk  \
# 0       a minimally invasive system for treating a tar...
# 1       load sensor a joint torque sensor a strain gau...
# 2       system of claim wherein the hifu treatment tra...
# 3       in part by an acoustic fountain reaction assoc...
# 4       data the system of claim further comprising a ...
# ...                                                   ...
# 219710  a dental tool comprising a dental bur having a...
# 219711  a device comprising a diffractive optics senso...
# 219712  an apparatus for electronically producing at l...
# 219713  an integrated value based care return on inves...
# 219714  a surgical robot system as substantially shown...
#
#                                                 embedding  hdbscan_cluster_25  \
# 0       [0.102507465, -0.4690934, -0.16641176, -0.1034...                  -1
# 1       [5.1148196e-05, -0.2560497, -0.21868536, -0.10...                  -1
# 2       [-0.095717534, -0.15502435, -0.14605981, -0.13...                  -1
# 3       [0.07438903, -0.2188163, -0.16725114, -0.08933...                  -1
# 4       [0.03889325, 0.11438014, -0.18144202, 0.072535...                  -1
# ...                                                   ...                 ...
# 219710  [0.20198575, -0.54403746, -0.17521329, -0.2867...                  -1
# 219711  [-0.13728589, -0.725161, -0.2967089, -0.197800...                 294
# 219712  [-0.05236339, -0.28899363, -0.12927833, -0.392...                  -1
# 219713  [-0.10989852, -0.3885529, -0.3383775, 0.009414...                  -1
# 219714  [0.20027116, -0.48158565, -0.31080633, -0.3169...                  -1
#
#         hdbscan_cluster_60  hdbscan_cluster_100  Year_x  Year_y  \
# 0                       10                    2    2021    2021
# 1                       -1                   -1    2021    2021
# 2                       10                    2    2021    2021
# 3                       10                    2    2021    2021
# 4                       -1                   -1    2021    2021
# ...                    ...                  ...     ...     ...
# 219710                  -1                   -1    2015    2015
# 219711                  77                   -1    2016    2016
# 219712                  -1                   -1    2015    2015
# 219713                  -1                   -1    2019    2019
# 219714                  76                   49    2016    2016
#
#         ProbablePatentAssignee
# 0           PETAL SURGICAL INC
# 1           PETAL SURGICAL INC
# 2           PETAL SURGICAL INC
# 3           PETAL SURGICAL INC
# 4           PETAL SURGICAL INC
# ...                        ...
# 219710       DENTLYTEC GPL LTD
# 219711  BIORA THERAPEUTICS INC
# 219712    SMART REPORTING GMBH
# 219713     MY MEDICAL HUB CORP
# 219714      GLOBUS MEDICAL INC
#
# [219715 rows x 12 columns]

# %%
r_umap_embeddings = np.load('/content/drive/MyDrive/Theses/umap_embeddings_50_3d.npy')

# %%
model_chunks = df['chunk'].astype(str).tolist()

# %%
Extended_Stopwords = pd.read_csv("/content/drive/MyDrive/Theses/extended_stopwords").to_numpy().flatten().tolist()

# %%
empty_reduction_model = BaseDimensionalityReduction()
empty_cluster_model = BaseCluster()

# %%
vectorizer_model = CountVectorizer(
    stop_words=Extended_Stopwords,
    min_df=2,
    ngram_range=(1, 3)
)

# %%
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# %%
keybert_model = KeyBERTInspired()
pos_model = PartOfSpeech("en_core_web_sm")
representation_model = {
    "KeyBERT": keybert_model,
    "POS": pos_model
}

# %%
#pipeline
topic_model = BERTopic(
    umap_model=empty_reduction_model,
    hdbscan_model=empty_cluster_model,
    vectorizer_model=vectorizer_model,
    ctfidf_model=ctfidf_model,
    representation_model=representation_model,
    top_n_words=10,
    verbose=True
)

topics, probabilities = topic_model.fit_transform(model_chunks,y= df['hdbscan_cluster_100'])

topic_model.fit_transform

topic_model.visualize_topics()
# Out:
# 2025-04-14 13:29:57,825 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/6867 [00:00<?, ?it/s]
# 2025-04-14 13:40:41,701 - BERTopic - Embedding - Completed ✓
# 2025-04-14 13:40:41,703 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-04-14 13:40:41,705 - BERTopic - Dimensionality - Completed ✓
# 2025-04-14 13:40:42,746 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-04-14 13:40:42,771 - BERTopic - Cluster - Completed ✓
# 2025-04-14 13:40:42,813 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-04-14 13:44:17,999 - BERTopic - Representation - Completed ✓
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6305a300-4b9c-42af-82f3-b3765c377f30" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6305a300-4b9c-42af-82f3-b3765c377f30")) {                    Plotly.newPlot(                        "6305a300-4b9c-42af-82f3-b3765c377f30",                        [{"customdata":[[0,"ultrasound | ultrasonic | transducer | ultrasound image | probe",23363],[1,"user | health | patient | data | healthcare",18648],[2,"jaw | shaft | drive | staple | pulley",10358],[3,"fluid | lumen | catheter | valve | needle",9211],[4,"robotic | arm | robotic arm | robot | manipulator",5864],[5,"training | images | medical image | learning | neural",4709],[6,"reality | virtual | augmented | augmented reality | anatomical",3772],[7,"endoscope | endoscope system | light | illumination light | illumination",3042],[8,"endoscope | bending | insertion | operation | portion",2739],[9,"composition | acid | percent | agent | cells",2595],[10,"bone | implant | femoral | knee | joint",2418],[11,"plaque | coronary | vessel | blood | vascular",2342],[12,"dental | tooth | teeth | intraoral | oral",2290],[13,"processing apparatus | medical image | image processing | processing | medical image processing",1788],[14,"cardiac | ecg | heart | arrhythmia | computing systems",1496],[15,"image pickup | pickup | endoscope | board | surface",1459],[16,"canceled | adjusting mechanism | analytic signal | yaw adjusting mechanism | yaw adjusting",1445],[17,"magnetic | magnetic field | field | coil | coils",1434],[18,"surgical | surgical procedure | surgical hub | procedure | hub",1374],[19,"ablation | energy | electrodes | electrode | temperature",1332],[20,"light | fluorescence | wavelength | wavelength band | light source",1319],[21,"interface control module | mappingimagingrecording | mappingimagingrecording system | interface control | plus minus plus",1163],[22,"driving | driving mechanism | mechanism claimed | driving mechanism claimed | element driving",1145],[23,"nontransitory | medium | nontransitory computer | nontransitory computer readable | readable medium",1137],[24,"guide | bone | cutting guide | cutting | patientspecific",812],[25,"lens | optical system | denotes | lt | conditional",710],[26,"collection | sample | sample collection | sampling | swab",584],[27,"electromagnetic radiation | electromagnetic | radiation | exposure | pixel array",559],[28,"adjusted image | eye | adjusted | visual acuity | given pixel",545],[29,"fiber | optical fiber | optical | cladding | core",520],[30,"light | optical | beam | fiber | wavelength",430],[31,"voltage | circuit | transistor | amplifier | node",331],[32,"heart | pacing | electrogram | cardiac | map",321],[33,"bite block | bite | dental | tongue | mouth",318],[34,"nm | peak wavelength | reflectance | tissue | wavelength",314],[35,"conductor | electrosurgical | electrosurgical instrument | dielectric | conductive",244],[36,"ue | broadcast | service | detection components | downlink",241],[37,"audio | featurebased | featurebased voice data | featurebased voice | voice data",239],[38,"clamp arm | ultrasonic blade | ultrasonic surgical | ultrasonic surgical instrument | clamp",200],[39,"surgical module | module | energy module | electrosurgical | module surgical module",186],[40,"medical information | information processing apparatus | information processing | medical information processing | processing apparatus",177],[41,"luminal network | luminal | branch | portion luminal network | portion luminal",173],[42,"steerable catheter | catheter | steerable | steerable catheter assembly | flexible guide tube",161],[43,"cleaning member | cleaning | coupling element | cleaning apparatus | engaging structure",149],[44,"alternately displa ...

# %%
topic_model.get_topic_info()
# Out:
#     Topic   Count                                               Name  \
# 0      -1  104909                     -1_light_sensor_device_optical
# 1       0   23363  0_ultrasound_ultrasonic_transducer_ultrasound ...
# 2       1   18648                         1_user_health_patient_data
# 3       2   10358                           2_jaw_shaft_drive_staple
# 4       3    9211                       3_fluid_lumen_catheter_valve
# 5       4    5864                    4_robotic_arm_robotic arm_robot
# 6       5    4709           5_training_images_medical image_learning
# 7       6    3772      6_reality_virtual_augmented_augmented reality
# 8       7    3042  7_endoscope_endoscope system_light_illuminatio...
# 9       8    2739            8_endoscope_bending_insertion_operation
# 10      9    2595                   9_composition_acid_percent_agent
# 11     10    2418                       10_bone_implant_femoral_knee
# 12     11    2342                    11_plaque_coronary_vessel_blood
# 13     12    2290                    12_dental_tooth_teeth_intraoral
# 14     13    1788  13_processing apparatus_medical image_image pr...
# 15     14    1496                    14_cardiac_ecg_heart_arrhythmia
# 16     15    1459             15_image pickup_pickup_endoscope_board
# 17     16    1445  16_canceled_adjusting mechanism_analytic signa...
# 18     17    1434              17_magnetic_magnetic field_field_coil
# 19     18    1374  18_surgical_surgical procedure_surgical hub_pr...
# 20     19    1332            19_ablation_energy_electrodes_electrode
# 21     20    1319   20_light_fluorescence_wavelength_wavelength band
# 22     21    1163  21_interface control module_mappingimagingreco...
# 23     22    1145  22_driving_driving mechanism_mechanism claimed...
# 24     23    1137  23_nontransitory_medium_nontransitory computer...
# 25     24     812                24_guide_bone_cutting guide_cutting
# 26     25     710                  25_lens_optical system_denotes_lt
# 27     26     584    26_collection_sample_sample collection_sampling
# 28     27     559  27_electromagnetic radiation_electromagnetic_r...
# 29     28     545       28_adjusted image_eye_adjusted_visual acuity
# 30     29     520            29_fiber_optical fiber_optical_cladding
# 31     30     430                        30_light_optical_beam_fiber
# 32     31     331            31_voltage_circuit_transistor_amplifier
# 33     32     321                32_heart_pacing_electrogram_cardiac
# 34     33     318                   33_bite block_bite_dental_tongue
# 35     34     314           34_nm_peak wavelength_reflectance_tissue
# 36     35     244  35_conductor_electrosurgical_electrosurgical i...
# 37     36     241       36_ue_broadcast_service_detection components
# 38     37     239  37_audio_featurebased_featurebased voice data_...
# 39     38     200  38_clamp arm_ultrasonic blade_ultrasonic surgi...
# 40     39     186  39_surgical module_module_energy module_electr...
# 41     40     177  40_medical information_information processing ...
# 42     41     173  41_luminal network_luminal_branch_portion lumi...
# 43     42     161  42_steerable catheter_catheter_steerable_steer...
# 44     43     149  43_cleaning member_cleaning_coupling element_c...
# 45     44     148  44_alternately displaying_false color_onmoving...
# 46     45     144               45_endoscope_cannula_handle_cordless
# 47     46     136                   46_ion_ion source_aerosol_vapour
# 48     47     134   47_cyber_sensor observation_concise_analytically
# 49     48     125  48_skeletal portion_portion tool_skeletal_loca...
# 50     49     119  49_flexible tube_flexible tube insertion_stiff...
# 51     50     117  50_prong_guide needle_coil electrode_andor tissue
# 52     51     114  51_iol_intraocular lens_intraocular_postoperative
# 53     52     112  52_signalling_signalling units_measured points...
#
#                                        Representation  \
# 0   [light, sensor, device, optical, surgical, por...
# 1   [ultrasound, ultrasonic, transducer, ultrasoun...
# 2   [user, health, patient, data, healthcare, asso...
# 3   [jaw, shaft, drive, staple, pulley, member, ef...
# 4   [fluid, lumen, catheter, valve, needle, distal...
# 5   [robotic, arm, robotic arm, robot, manipulator...
# 6   [training, images, medical image, learning, ne...
# 7   [reality, virtual, augmented, augmented realit...
# 8   [endoscope, endoscope system, light, illuminat...
# 9   [endoscope, bending, insertion, operation, por...
# 10  [composition, acid, percent, agent, cells, can...
# 11  [bone, implant, femoral, knee, joint, femur, s...
# 12  [plaque, coronary, vessel, blood, vascular, bl...
# 13  [dental, tooth, teeth, intraoral, oral, arch, ...
# 14  [processing apparatus, medical image, image pr...
# 15  [cardiac, ecg, heart, arrhythmia, computing sy...
# 16  [image pickup, pickup, endoscope, board, surfa...
# 17  [canceled, adjusting mechanism, analytic signa...
# 18  [magnetic, magnetic field, field, coil, coils,...
# 19  [surgical, surgical procedure, surgical hub, p...
# 20  [ablation, energy, electrodes, electrode, temp...
# 21  [light, fluorescence, wavelength, wavelength b...
# 22  [interface control module, mappingimagingrecor...
# 23  [driving, driving mechanism, mechanism claimed...
# 24  [nontransitory, medium, nontransitory computer...
# 25  [guide, bone, cutting guide, cutting, patients...
# 26  [lens, optical system, denotes, lt, conditiona...
# 27  [collection, sample, sample collection, sampli...
# 28  [electromagnetic radiation, electromagnetic, r...
# 29  [adjusted image, eye, adjusted, visual acuity,...
# 30  [fiber, optical fiber, optical, cladding, core...
# 31  [light, optical, beam, fiber, wavelength, sour...
# 32  [voltage, circuit, transistor, amplifier, node...
# 33  [heart, pacing, electrogram, cardiac, map, ele...
# 34  [bite block, bite, dental, tongue, mouth, retr...
# 35  [nm, peak wavelength, reflectance, tissue, wav...
# 36  [conductor, electrosurgical, electrosurgical i...
# 37  [ue, broadcast, service, detection components,...
# 38  [audio, featurebased, featurebased voice data,...
# 39  [clamp arm, ultrasonic blade, ultrasonic surgi...
# 40  [surgical module, module, energy module, elect...
# 41  [medical information, information processing a...
# 42  [luminal network, luminal, branch, portion lum...
# 43  [steerable catheter, catheter, steerable, stee...
# 44  [cleaning member, cleaning, coupling element, ...
# 45  [alternately displaying, false color, onmoving...
# 46  [endoscope, cannula, handle, cordless, reusabl...
# 47  [ion, ion source, aerosol, vapour, aerosol smo...
# 48  [cyber, sensor observation, concise, analytica...
# 49  [skeletal portion, portion tool, skeletal, loc...
# 50  [flexible tube, flexible tube insertion, stiff...
# 51  [prong, guide needle, coil electrode, andor ti...
# 52  [iol, intraocular lens, intraocular, postopera...
# 53  [signalling, signalling units, measured points...
#
#                                               KeyBERT  \
# 0   [imaging, image data, sensor, tracking, device...
# 1   [ultrasound diagnostic apparatus, ultrasound s...
# 2   [patient data, machine learning, computing dev...
# 3   [surgical tool, surgical instrument, shaft ass...
# 4   [catheter, insufflation, medical device, cathe...
# 5   [surgical robotic system, robotic surgical sys...
# 6   [medical image data, training image, medical i...
# 7   [augmented reality device, augmented reality s...
# 8   [image endoscope system, information endoscope...
# 9   [part endoscope, endoscope insertion, endoscop...
# 10  [formulation, pharmaceutical, compound, pharma...
# 11  [femoral component, knee joint, femoral implan...
# 12  [angiographic, angiography image, coronary art...
# 13  [dental impression, model dental, image dental...
# 14  [image processing apparatus, information medic...
# 15  [ecg signals data, ecg signals, ecg data, ecg ...
# 16  [image pickup apparatus, image pickup unit, im...
# 17  [signal analytic, mechanism detects, signal an...
# 18  [magnetic capsule, mri, magnetic tracking, mag...
# 19  [surgical computing system, surgical computing...
# 20  [ablation device, ablation electrode, ablation...
# 21  [light imaging, imaging system, imaging device...
# 22  [catheter control, operation transducers, inte...
# 23  [optical element driving, optical member drivi...
# 24  [procedure nontransitory computer, readable me...
# 25  [orthopaedic surgical instrument, patientspeci...
# 26  [endoscope objective optical, objective lens, ...
# 27  [sample preservation, sample preservation reag...
# 28  [plurality exposure frames, radiation sensed, ...
# 29  [virtual image, visual acuity, vision, percept...
# 30  [distal optical fiber, fiber optics, fiber opt...
# 31  [light optical, illumination source, source li...
# 32  [operational amplifier, amplifier circuit, dif...
# 33  [electrogram signals, electrophysiological map...
# 34  [dental device, mandibular piece, portion mout...
# 35  [wavelength tissue, peak wavelength tissue, bi...
# 36  [electrosurgical instrument, electrosurgical a...
# 37  [radio resource control, data transmission, br...
# 38  [voice data associated, featurebased voice dat...
# 39  [ultrasonic surgical instrument, ultrasonic su...
# 40  [modular surgical system, modular surgical, sy...
# 41  [medical information processing, medical infor...
# 42  [model luminal network, within luminal, portio...
# 43  [steerable guide catheter, steerable catheter ...
# 44  [endoscope cleaning device, apparatus cleaning...
# 45  [image program code, image color values, image...
# 46  [cordless endoscope, endoscope system, endosco...
# 47  [ion source, spectrometry andor ion, spectrome...
# 48  [sensor observations, features sensor, utilizi...
# 49  [skeletal portion xray, skeletal portion view,...
# 50  [apparatus flexible tube, insertion apparatus ...
# 51  [subcutaneously implantable device, subcutaneo...
# 52  [preoperative measurements eye, ophthalmologic...
# 53  [anatomic passageways, passageways patient, pa...
#
#                                                   POS  \
# 0   [light, sensor, device, optical, surgical, por...
# 1   [ultrasound, ultrasonic, transducer, probe, ac...
# 2   [user, health, patient, data, healthcare, info...
# 3   [jaw, shaft, drive, staple, pulley, member, ef...
# 4   [fluid, lumen, catheter, valve, needle, distal...
# 5   [robotic, arm, robotic arm, robot, manipulator...
# 6   [training, images, medical image, learning, ne...
# 7   [reality, virtual, augmented, augmented realit...
# 8   [endoscope, light, illumination, endoscopic, o...
# 9   [endoscope, bending, insertion, operation, por...
# 10  [composition, acid, percent, agent, cells, can...
# 11  [bone, implant, femoral, knee, joint, femur, s...
# 12  [plaque, coronary, vessel, blood, vascular, fl...
# 13  [dental, tooth, teeth, intraoral, oral, arch, ...
# 14  [medical image, processing, image, information...
# 15  [cardiac, ecg, heart, arrhythmia, pressure, wa...
# 16  [pickup, endoscope, board, surface, substrate,...
# 17  [analytic signal, analytic, judgement, login, ...
# 18  [magnetic, magnetic field, field, coil, coils,...
# 19  [surgical, surgical procedure, surgical hub, p...
# 20  [ablation, energy, electrodes, electrode, temp...
# 21  [light, fluorescence, wavelength, light source...
# 22  [mappingimagingrecording, cloth, tennis, opera...
# 23  [driving, optical element, movable portion, mo...
# 24  [medium, readable medium, readable, computer, ...
# 25  [guide, bone, cutting, tibial, resection, tibi...
# 26  [lens, optical system, denotes, conditional, c...
# 27  [collection, sample, sampling, swab, collector...
# 28  [electromagnetic radiation, electromagnetic, r...
# 29  [adjusted image, eye, adjusted, visual acuity,...
# 30  [fiber, optical fiber, optical, cladding, core...
# 31  [light, optical, beam, fiber, wavelength, sour...
# 32  [voltage, circuit, transistor, amplifier, node...
# 33  [heart, pacing, electrogram, cardiac, map, act...
# 34  [bite, dental, tongue, mouth, retractor, mirro...
# 35  [nm, reflectance, tissue, wavelength, excitati...
# 36  [conductor, electrosurgical, electrosurgical i...
# 37  [ue, broadcast, service, downlink, codebook, p...
# 38  [audio, acoustic domain, augmentations, sound,...
# 39  [ultrasonic blade, clamp, waveguide, ultrasoni...
# 40  [surgical module, module, electrosurgical, ene...
# 41  [medical information, information, medical exa...
# 42  [luminal network, luminal, branch, network, lo...
# 43  [steerable catheter, catheter, steerable, foll...
# 44  [cleaning, chassis, vivo endoscope, unrestrict...
# 45  [false color, partial data, false, color, stat...
# 46  [endoscope, cannula, handle, cordless, reusabl...
# 47  [ion, aerosol, vapour, smoke, mobility, ionisa...
# 48  [cyber, concise, rich, observations, determina...
# 49  [skeletal portion, skeletal, locational elemen...
# 50  [flexible tube, stiffness, flexible, insertion...
# 51  [prong, outer coil, electrode, inner coil, coi...
# 52  [iol, intraocular lens, intraocular, postopera...
# 53  [measured points, fundus, navigational instruc...
#
#                                   Representative_Docs
# 0   [a medical system comprising a sensor configur...
# 1   [reference region that correspond to each colo...
# 2   [of claim wherein the machine learning model i...
# 3   [cartridge a surgical instrument comprising an...
# 4   [for the output of cryogen and a lumen extendi...
# 5   [the position of the second robotic and contro...
# 6   [the second image with the estimated segmentat...
# 7   [display screen aligned with one of the anatom...
# 8   [an endoscope system comprising a light source...
# 9   [side of the operating part and is inserted in...
# 10  [a compound of formula i or a salt thereof vie...
# 11  [data comprises at least a coronal mechanical ...
# 12  [value between about and hounsfield units the ...
# 13  [of the user based on at least a starting posi...
# 14  [to acquire the related image information and ...
# 15  [ecg sensors is positioned in on an abdomen of...
# 16  [plane the third principal plane being dispose...
# 17  [speckle exceeds a predetermined distance with...
# 18  [a method for imaging in surgical procedures c...
# 19  [a surgical system configured to improve surgi...
# 20  [neck or a submentum the device of claim where...
# 21  [a medical observation system comprising a lig...
# 22  [user of a manually-operated catheter control ...
# 23  [the driving portion comprises a first driving...
# 24  [a non-transitory computer readable medium con...
# 25  [onto an anterior surface of the proximal end ...
# 26  [an endoscope objective optical system compris...
# 27  [a method of collecting and preserving a biolo...
# 28  [a color image frame depicting the scene to in...
# 29  [a device operable to dynamically adjust user ...
# 30  [with the core wire and the mirror is spaced a...
# 31  [image dataset within the overlapping region t...
# 32  [a circuit for removing a large differential v...
# 33  [a system configured to detect a location of a...
# 34  [a mandibular repositioning device comprising ...
# 35  [a method in a nervous tissue imaging system t...
# 36  [an electrosurgical apparatus for delivering r...
# 37  [sub-range of mbms service ids the server of c...
# 38  [beams configured to receive audio encounter i...
# 39  [an ultrasonic surgical instrument comprising ...
# 40  [a modular surgical system comprising a header...
# 41  [a medical information processing apparatus co...
# 42  [wherein the control circuit further has store...
# 43  [a steerable guide catheter comprising a flexi...
# 44  [away from contact with the imaging element wh...
# 45  [spect image a magnetic resonance imaging mm i...
# 46  [receiving images at the display unit taken wi...
# 47  [wherein said second device comprises an ambie...
# 48  [universal health metrics monitors assign appr...
# 49  [apparatus for performing a procedure using a ...
# 50  [about a central axis the flexible tube sectio...
# 51  [a subcutaneously implantable device comprisin...
# 52  [a non-transitory machine-readable medium comp...
# 53  [canceled a method of continuously registering...

# %%
topic_model = BERTopic.load("/content/drive/MyDrive/Theses/BERT_v1")

# %%
df_info = topic_model.get_document_info(model_chunks)

# %%
df_info['ApplicationNumber'] = df['ApplicationNumber'].values

# %%
df_info['Year'] = df['Year'].values

# %%
df_info['ProbablePatentAssignee'] = df['ProbablePatentAssignee'].values

# %%
df_info
# Out:
#                                                  Document  Topic  \
# 0       a minimally invasive system for treating a tar...      0
# 1       load sensor a joint torque sensor a strain gau...     -1
# 2       system of claim wherein the hifu treatment tra...      0
# 3       in part by an acoustic fountain reaction assoc...      0
# 4       data the system of claim further comprising a ...     -1
# ...                                                   ...    ...
# 219710  a dental tool comprising a dental bur having a...     -1
# 219711  a device comprising a diffractive optics senso...     -1
# 219712  an apparatus for electronically producing at l...     -1
# 219713  an integrated value based care return on inves...     -1
# 219714  a surgical robot system as substantially shown...      4
#
#                                                      Name  \
# 0       0_ultrasound_ultrasonic_transducer_ultrasound ...
# 1                          -1_light_sensor_device_optical
# 2       0_ultrasound_ultrasonic_transducer_ultrasound ...
# 3       0_ultrasound_ultrasonic_transducer_ultrasound ...
# 4                          -1_light_sensor_device_optical
# ...                                                   ...
# 219710                     -1_light_sensor_device_optical
# 219711                     -1_light_sensor_device_optical
# 219712                     -1_light_sensor_device_optical
# 219713                     -1_light_sensor_device_optical
# 219714                    4_robotic_arm_robotic arm_robot
#
#                                            Representation  \
# 0       [ultrasound, ultrasonic, transducer, ultrasoun...
# 1       [light, sensor, device, optical, surgical, por...
# 2       [ultrasound, ultrasonic, transducer, ultrasoun...
# 3       [ultrasound, ultrasonic, transducer, ultrasoun...
# 4       [light, sensor, device, optical, surgical, por...
# ...                                                   ...
# 219710  [light, sensor, device, optical, surgical, por...
# 219711  [light, sensor, device, optical, surgical, por...
# 219712  [light, sensor, device, optical, surgical, por...
# 219713  [light, sensor, device, optical, surgical, por...
# 219714  [robotic, arm, robotic arm, robot, manipulator...
#
#                                                   KeyBERT  \
# 0       [ultrasound diagnostic apparatus, ultrasound s...
# 1       [imaging, image data, sensor, tracking, device...
# 2       [ultrasound diagnostic apparatus, ultrasound s...
# 3       [ultrasound diagnostic apparatus, ultrasound s...
# 4       [imaging, image data, sensor, tracking, device...
# ...                                                   ...
# 219710  [imaging, image data, sensor, tracking, device...
# 219711  [imaging, image data, sensor, tracking, device...
# 219712  [imaging, image data, sensor, tracking, device...
# 219713  [imaging, image data, sensor, tracking, device...
# 219714  [surgical robotic system, robotic surgical sys...
#
#                                                       POS  \
# 0       [ultrasound, ultrasonic, transducer, probe, ac...
# 1       [light, sensor, device, optical, surgical, por...
# 2       [ultrasound, ultrasonic, transducer, probe, ac...
# 3       [ultrasound, ultrasonic, transducer, probe, ac...
# 4       [light, sensor, device, optical, surgical, por...
# ...                                                   ...
# 219710  [light, sensor, device, optical, surgical, por...
# 219711  [light, sensor, device, optical, surgical, por...
# 219712  [light, sensor, device, optical, surgical, por...
# 219713  [light, sensor, device, optical, surgical, por...
# 219714  [robotic, arm, robotic arm, robot, manipulator...
#
#                                       Representative_Docs  \
# 0       [reference region that correspond to each colo...
# 1       [a medical system comprising a sensor configur...
# 2       [reference region that correspond to each colo...
# 3       [reference region that correspond to each colo...
# 4       [a medical system comprising a sensor configur...
# ...                                                   ...
# 219710  [a medical system comprising a sensor configur...
# 219711  [a medical system comprising a sensor configur...
# 219712  [a medical system comprising a sensor configur...
# 219713  [a medical system comprising a sensor configur...
# 219714  [the position of the second robotic and contro...
#
#                                               Top_n_words  \
# 0       ultrasound - ultrasonic - transducer - ultraso...
# 1       light - sensor - device - optical - surgical -...
# 2       ultrasound - ultrasonic - transducer - ultraso...
# 3       ultrasound - ultrasonic - transducer - ultraso...
# 4       light - sensor - device - optical - surgical -...
# ...                                                   ...
# 219710  light - sensor - device - optical - surgical -...
# 219711  light - sensor - device - optical - surgical -...
# 219712  light - sensor - device - optical - surgical -...
# 219713  light - sensor - device - optical - surgical -...
# 219714  robotic - arm - robotic arm - robot - manipula...
#
#         Representative_document ApplicationNumber  Year  \
# 0                         False     US20220083465  2021
# 1                         False     US20220083465  2021
# 2                         False     US20220083465  2021
# 3                         False     US20220083465  2021
# 4                         False     US20220083465  2021
# ...                         ...               ...   ...
# 219710                    False     US20210527046  2015
# 219711                    False     US20240826061  2016
# 219712                    False     US20210328898  2015
# 219713                    False     US20200913236  2019
# 219714                    False     US20240413363  2016
#
#         ProbablePatentAssignee
# 0           PETAL SURGICAL INC
# 1           PETAL SURGICAL INC
# 2           PETAL SURGICAL INC
# 3           PETAL SURGICAL INC
# 4           PETAL SURGICAL INC
# ...                        ...
# 219710       DENTLYTEC GPL LTD
# 219711  BIORA THERAPEUTICS INC
# 219712    SMART REPORTING GMBH
# 219713     MY MEDICAL HUB CORP
# 219714      GLOBUS MEDICAL INC
#
# [219715 rows x 12 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['Representation', 'KeyBERT', 'POS', 'Representative_Docs'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_info['Topic'].plot(kind='hist', bins=20, title='Topic')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_info['Year'].plot(kind='hist', bins=20, title='Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_info.groupby('Representative_document').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_info.plot(kind='scatter', x='Topic', y='Year', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Topic']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df_info.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Representative_document')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Representative_document', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Topic')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Year']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Year'}, axis=1)
#               .sort_values('Year', ascending=True))
#   xs = counted['Year']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df_info.sort_values('Year', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Representative_document')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Representative_document', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_info['Topic'].plot(kind='line', figsize=(8, 4), title='Topic')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_info['Year'].plot(kind='line', figsize=(8, 4), title='Year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_info['Representative_document'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_info, x='Topic', y='Representative_document', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df_info['Representative_document'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df_info, x='Year', y='Representative_document', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.to_csv("/content/drive/MyDrive/Theses/topic_df.csv", index=False)

# %%
topic_model.get_topic(1, full=True)
# Out:
# {'Main': [('user', np.float64(0.22245823627773176)),
#   ('health', np.float64(0.2180351317131198)),
#   ('patient', np.float64(0.20068460256954956)),
#   ('data', np.float64(0.19317106843384693)),
#   ('healthcare', np.float64(0.1843420841627908)),
#   ('associated', np.float64(0.18400667192138087)),
#   ('information', np.float64(0.17942411136184638)),
#   ('clinical', np.float64(0.17615502578674497)),
#   ('record', np.float64(0.1755526191382778)),
#   ('server', np.float64(0.1695485668491495))],
#  'KeyBERT': [('patient data', np.float32(0.47758198)),
#   ('machine learning', np.float32(0.4614889)),
#   ('computing device', np.float32(0.43372914)),
#   ('computing', np.float32(0.42813578)),
#   ('medical data', np.float32(0.42019108)),
#   ('database', np.float32(0.38242635)),
#   ('application', np.float32(0.3655525)),
#   ('program', np.float32(0.36138424)),
#   ('computerimplemented', np.float32(0.35510692)),
#   ('data', np.float32(0.34611547))],
#  'POS': [('user', np.float64(0.22245823627773176)),
#   ('health', np.float64(0.2180351317131198)),
#   ('patient', np.float64(0.20068460256954956)),
#   ('data', np.float64(0.19317106843384693)),
#   ('healthcare', np.float64(0.1843420841627908)),
#   ('information', np.float64(0.17942411136184638)),
#   ('clinical', np.float64(0.17615502578674497)),
#   ('record', np.float64(0.1755526191382778)),
#   ('server', np.float64(0.1695485668491495)),
#   ('computing', np.float64(0.16549931238484317))]}

# %%
# diversity
top_n = 10
topics_words = [
    [word for word, _ in topic_model.get_topic(topic)[:top_n]]
    for topic in topic_model.get_topics() if topic_model.get_topic(topic)
]

all_words = [word for topic in topics_words for word in topic]
unique_words = set(all_words)

diversity = len(unique_words) / len(all_words)
print(f"Topic Diversity: {diversity:.4f}")
# Out:
# Topic Diversity: 0.8926

# %%
from itertools import combinations

# %%
df_words_per_class = pd.read_csv('/content/drive/MyDrive/Theses/ctfidf_100.csv', index_col=0)
topic_words = df_words_per_class.values.tolist()
documents = cluster_document_df.cluster_document.tolist()

# manual coherence fnc
def manual_coherence_score_for_topic(topic_words, documents):
    topic_coherence_scores = []
    total_docs = len(documents)

    for topic in topic_words:
        word_pairs = list(combinations(topic, 2))
        pair_scores = []

        for w1, w2 in word_pairs:
            count = sum(1 for doc in documents if w1 in doc and w2 in doc)
            normalized_score = count / total_docs
            pair_scores.append(normalized_score)

        topic_score = sum(pair_scores) / len(pair_scores) if pair_scores else 0
        topic_coherence_scores.append(topic_score)

    return topic_coherence_scores

#individual coherence
topic_scores = manual_coherence_score_for_topic(topic_words, documents)
normalized_topic_scores = [min(1, max(0, score)) for score in topic_scores]

# avg coherence
overall_coherence = sum(normalized_topic_scores) / len(normalized_topic_scores) if normalized_topic_scores else 0

#print coherence
for i, score in enumerate(normalized_topic_scores):
    print(f"Topic {i+1} Normalized Coherence Score = {score:.4f}")

print(f"Overall Normalized Coherence Score = {overall_coherence:.4f}")
# Out:
# Topic 1 Normalized Coherence Score = 0.5392
# Topic 2 Normalized Coherence Score = 0.5229
# Topic 3 Normalized Coherence Score = 0.3145
# Topic 4 Normalized Coherence Score = 0.0704
# Topic 5 Normalized Coherence Score = 0.0704
# Topic 6 Normalized Coherence Score = 0.6453
# Topic 7 Normalized Coherence Score = 0.0180
# Topic 8 Normalized Coherence Score = 0.5019
# Topic 9 Normalized Coherence Score = 0.3442
# Topic 10 Normalized Coherence Score = 0.6683
# Topic 11 Normalized Coherence Score = 0.0356
# Topic 12 Normalized Coherence Score = 0.5354
# Topic 13 Normalized Coherence Score = 0.4046
# Topic 14 Normalized Coherence Score = 0.0621
# Topic 15 Normalized Coherence Score = 0.6184
# Topic 16 Normalized Coherence Score = 0.6117
# Topic 17 Normalized Coherence Score = 0.2881
# Topic 18 Normalized Coherence Score = 0.3975
# Topic 19 Normalized Coherence Score = 0.2751
# Topic 20 Normalized Coherence Score = 0.5799
# Topic 21 Normalized Coherence Score = 0.5790
# Topic 22 Normalized Coherence Score = 0.4927
# Topic 23 Normalized Coherence Score = 0.2826
# Topic 24 Normalized Coherence Score = 0.6285
# Topic 25 Normalized Coherence Score = 0.3514
# Topic 26 Normalized Coherence Score = 0.3036
# Topic 27 Normalized Coherence Score = 0.3342
# Topic 28 Normalized Coherence Score = 0.2281
# Topic 29 Normalized Coherence Score = 0.4486
# Topic 30 Normalized Coherence Score = 0.3090
# Topic 31 Normalized Coherence Score = 0.2184
# Topic 32 Normalized Coherence Score = 0.2008
# Topic 33 Normalized Coherence Score = 0.2017
# Topic 34 Normalized Coherence Score = 0.1245
# Topic 35 Normalized Coherence Score = 0.4289
# Topic 36 Normalized Coherence Score = 0.0398
# Topic 37 Normalized Coherence Score = 0.1727
# Topic 38 Normalized Coherence Score = 0.0055
# Topic 39 Normalized Coherence Score = 0.0851
# Topic 40 Normalized Coherence Score = 0.2134
# Topic 41 Normalized Coherence Score = 0.0298
# Topic 42 Normalized Coherence Score = 0.1925
# Topic 43 Normalized Coherence Score = 0.1966
# Topic 44 Normalized Coherence Score = 0.1514
# Topic 45 Normalized Coherence Score = 0.0646
# Topic 46 Normalized Coherence Score = 0.5740
# Topic 47 Normalized Coherence Score = 0.0969
# Topic 48 Normalized Coherence Score = 0.0306
# Topic 49 Normalized Coherence Score = 0.3778
# Topic 50 Normalized Coherence Score = 0.2184
# Topic 51 Normalized Coherence Score = 0.1266
# Topic 52 Normalized Coherence Score = 0.2298
# Topic 53 Normalized Coherence Score = 0.1027
# Overall Normalized Coherence Score = 0.2933

# %%
df_words_per_class = pd.read_csv('/content/drive/MyDrive/Theses/ctfidf_100.csv', index_col=0)
df_words_per_class.head()
# Out:
#                       Word_1              Word_2            Word_3  \
# 2                      array  ultrasound imaging              wave
# 11                     tumor            compound                ch
# 29          wavelength range               nm nm  excitation light
# 22  respect subjectapos body  ray imaging device      tool respect
# 10                 andor ion               smoke      ion mobility
#
#                   Word_4            Word_5            Word_6  \
# 2               acoustic  ultrasound probe  ultrasound image
# 11                  cell            cancer             agent
# 29            excitation             light        wavelength
# 22             ray image        ray images  location portion
# 10  aerosol smoke vapour      smoke vapour     aerosol smoke
#
#                    Word_7           Word_8       Word_9       Word_10
# 2                   probe       transducer   ultrasonic    ultrasound
# 11                  cells          percent         acid   composition
# 29                 tissue  peak wavelength  reflectance            nm
# 22  location portion tool              ray     skeletal  portion tool
# 10                 vapour          aerosol   ion source           ion

# %%
hierachy_fig = topic_model.visualize_hierarchy()
hierachy_fig.write_html("/content/drive/MyDrive/Theses/hierachy.html")

# %%
hierachy_fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="15f6764b-a83b-4d79-bcb4-493296c73163" class="plotly-graph-div" style="height:995px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15f6764b-a83b-4d79-bcb4-493296c73163")) {                    Plotly.newPlot(                        "15f6764b-a83b-4d79-bcb4-493296c73163",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9782608808626645,0.9782608808626645,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9100148170451501,0.9100148170451501,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.6517112687694254,0.6517112687694254,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.6942954429574368,0.6942954429574368,0.6517112687694254],"xaxis":"x","y":[-65.0,-65.0,-80.0,-80.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.6942954429574368,0.8684360859280468,0.8684360859280468,0.0],"xaxis":"x","y":[-72.5,-72.5,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8858003541565366,0.8858003541565366,0.8684360859280468],"xaxis":"x","y":[-55.0,-55.0,-83.75,-83.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.8858003541565366,0.9098601490450416,0.9098601490450416,0.0],"xaxis":"x","y":[-69.375,-69.375,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9148483308433106,0.9148483308433106,0.9098601490450416],"xaxis":"x","y":[-45.0,-45.0,-87.1875,-87.1875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9148483308433106,0.9292624964332646,0.9292624964332646,0.0],"xaxis":"x","y":[-66.09375,-66.09375,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9100148170451501,0.9419099481261904,0.9419099481261904,0.9292624964332646],"xaxis":"x","y":[-30.0,-30.0,-90.546875,-90.546875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9782608808626645,1.013020017354009,1.013020017354009,0.9419099481261904],"xaxis":"x","y":[-10.0,-10.0,-60.2734375,-60.2734375],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.7883741354238962,0.7883741354238962,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.8421126789699716,0.8421126789699716,0.7883741354238962],"xaxis":"x","y":[-125.0,-125.0,-140.0,-140.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.8609070071321931,0.8609070071321931,0.0],"xaxis":"x","y":[-155.0,-155.0,-165.0,-165.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.8421126789699716,0.8862561292308161,0.8862561292308161,0.8609070071321931],"xaxis":"x","y":[-132.5,-132.5,-160.0,-160.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.013020017354009,1.154200631618322,1.154200631618322,0.8862561292308161],"xaxis":"x","y":[-35.13671875,-35.13671875,-146.25,-146.25],"yaxis":"y","type":"scatter"},{"hoverinfo ...

# %%
distance_map = topic_model.visualize_topics()
distance_map.write_html("/content/drive/MyDrive/Theses/topics.html")

# %%
distance_map
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5082aeb9-0b4f-40a8-a61a-c72947ccd184" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5082aeb9-0b4f-40a8-a61a-c72947ccd184")) {                    Plotly.newPlot(                        "5082aeb9-0b4f-40a8-a61a-c72947ccd184",                        [{"customdata":[[0,"ultrasound | ultrasonic | transducer | ultrasound image | probe",23363],[1,"user | health | patient | data | healthcare",18648],[2,"jaw | shaft | drive | staple | pulley",10358],[3,"fluid | lumen | catheter | valve | needle",9211],[4,"robotic | arm | robotic arm | robot | manipulator",5864],[5,"training | images | medical image | learning | neural",4709],[6,"reality | virtual | augmented | augmented reality | anatomical",3772],[7,"endoscope | endoscope system | light | illumination light | illumination",3042],[8,"endoscope | bending | insertion | operation | portion",2739],[9,"composition | acid | percent | agent | cells",2595],[10,"bone | implant | femoral | knee | joint",2418],[11,"plaque | coronary | vessel | blood | vascular",2342],[12,"dental | tooth | teeth | intraoral | oral",2290],[13,"processing apparatus | medical image | image processing | processing | medical image processing",1788],[14,"cardiac | ecg | heart | arrhythmia | computing systems",1496],[15,"image pickup | pickup | endoscope | board | surface",1459],[16,"canceled | adjusting mechanism | analytic signal | yaw adjusting mechanism | yaw adjusting",1445],[17,"magnetic | magnetic field | field | coil | coils",1434],[18,"surgical | surgical procedure | surgical hub | procedure | hub",1374],[19,"ablation | energy | electrodes | electrode | temperature",1332],[20,"light | fluorescence | wavelength | wavelength band | light source",1319],[21,"interface control module | mappingimagingrecording | mappingimagingrecording system | interface control | plus minus plus",1163],[22,"driving | driving mechanism | mechanism claimed | driving mechanism claimed | element driving",1145],[23,"nontransitory | medium | nontransitory computer | nontransitory computer readable | readable medium",1137],[24,"guide | bone | cutting guide | cutting | patientspecific",812],[25,"lens | optical system | denotes | lt | conditional",710],[26,"collection | sample | sample collection | sampling | swab",584],[27,"electromagnetic radiation | electromagnetic | radiation | exposure | pixel array",559],[28,"adjusted image | eye | adjusted | visual acuity | given pixel",545],[29,"fiber | optical fiber | optical | cladding | core",520],[30,"light | optical | beam | fiber | wavelength",430],[31,"voltage | circuit | transistor | amplifier | node",331],[32,"heart | pacing | electrogram | cardiac | map",321],[33,"bite block | bite | dental | tongue | mouth",318],[34,"nm | peak wavelength | reflectance | tissue | wavelength",314],[35,"conductor | electrosurgical | electrosurgical instrument | dielectric | conductive",244],[36,"ue | broadcast | service | detection components | downlink",241],[37,"audio | featurebased | featurebased voice data | featurebased voice | voice data",239],[38,"clamp arm | ultrasonic blade | ultrasonic surgical | ultrasonic surgical instrument | clamp",200],[39,"surgical module | module | energy module | electrosurgical | module surgical module",186],[40,"medical information | information processing apparatus | information processing | medical information processing | processing apparatus",177],[41,"luminal network | luminal | branch | portion luminal network | portion luminal",173],[42,"steerable catheter | catheter | steerable | steerable catheter assembly | flexible guide tube",161],[43,"cleaning member | cleaning | coupling element | cleaning apparatus | engaging structure",149],[44,"alternately displa ...

# %%
barchart = topic_model.visualize_barchart()
barchart.write_html("/content/drive/MyDrive/Theses/barchart.html")

# %%
barchart
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8b1b51e4-9327-4237-aa6e-e9dcba9e6ea6" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b1b51e4-9327-4237-aa6e-e9dcba9e6ea6")) {                    Plotly.newPlot(                        "8b1b51e4-9327-4237-aa6e-e9dcba9e6ea6",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.21352849295785764,0.21970993823678,0.24266392846401627,0.24331133080874823,0.3064801099919159],"y":["probe  ","ultrasound image  ","transducer  ","ultrasonic  ","ultrasound  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.1843420841627908,0.19317106843384693,0.20068460256954956,0.2180351317131198,0.22245823627773176],"y":["healthcare  ","data  ","patient  ","health  ","user  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.22191317473077024,0.22256750618576032,0.2351563793686588,0.23672869719543466,0.25322277172821084],"y":["pulley  ","staple  ","drive  ","shaft  ","jaw  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.20950121951529443,0.21868734203895562,0.2188185381137787,0.21981762071305988,0.2331616386988602],"y":["needle  ","valve  ","catheter  ","lumen  ","fluid  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.233479266451924,0.25408401440188516,0.25903226547244956,0.290946141256316,0.3128172727525743],"y":["manipulator  ","robot  ","robotic arm  ","arm  ","robotic  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.2130673531867984,0.22197748241823817,0.22721589974693407,0.22871033566612803,0.2309783819761931],"y":["neural  ","learning  ","medical image  ","images  ","training  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.1951342398508912,0.21912368895766793,0.2202893627652738,0.2307382369745128,0.23367643202861024],"y":["anatomical  ","augmented reality  ","augmented  ","virtual  ","reality  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.22712682810369525,0.25965520343469783,0.27283263549245396,0.31612631958251874,0.3365189802216189],"y":["illumination  ","illumination light  ","light  ","endoscope system  ","endoscope  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222222 ...

# %%
topic_model.save('/content/drive/MyDrive/Theses/BERT')
# Out:
# 2025-04-14 13:44:43,997 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.

# %% [markdown]
# ## LLM Representation

# %%
# !pip install -U bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.0->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 100.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.45.5 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install accelerate xformers adjustText
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.5.2)
# Collecting xformers
#   Downloading xformers-0.0.29.post3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting adjustText
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from adjustText) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from adjustText) (1.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->adjustText) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)
# Downloading xformers-0.0.29.post3-cp311-cp311-manylinux_2_28_x86_64.whl (43.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 11.4 MB/s eta 0:00:00
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Installing collected packages: adjustText, xformers
# Successfully installed adjustText-1.3.0 xformers-0.0.29.post3

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.8.40)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (3.4.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (0.5.7)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.14.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.51.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.1.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.13.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.1.31)
# Downloading bertopic-0.17.0-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: bertopic
# Successfully installed bertopic-0.17.0

# %%
import pandas as pd
import numpy as np
from bertopic import BERTopic
import torch
from bertopic.dimensionality import BaseDimensionalityReduction
from bertopic.representation import KeyBERTInspired, TextGeneration
from bertopic.cluster import BaseCluster
import re
import random
import pickle
from torch import bfloat16
import transformers
from torch import cuda
from bertopic.vectorizers import ClassTfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model_id = 'meta-llama/Llama-2-7b-chat-hf'
device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

print(device)
# Out:
# cuda:0

# %%
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)

# %%
#llama2 model
tokenizer = transformers.AutoTokenizer.from_pretrained(model_id)
model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    quantization_config=bnb_config,
    device_map='auto',
)
model.eval()
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear4bit(in_features=11008, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
generator = transformers.pipeline(
    model=model, tokenizer=tokenizer,
    task='text-generation',
    temperature=0.1,
    max_new_tokens=500,
    repetition_penalty=1.1
)
# Out:
# Device set to use cuda:0

# %%
#llama2 system prompt
system_prompt = """
<s>[INST] <<SYS>>
You are a helpful, truthful and honest patent analysis assistant that generates short, meaningful topic labels based on keywords or representative documents. Your labels are concise (2–5 words), human-readable, and summarize the theme of the topic. If the topic is unclear, don't just say something, use a generic label like "Miscellaneous".

<</SYS>>
"""

# %%
example_prompt = """
I have a topic that contains the following documents:
- A surgical robotic system that includes a precisely controlled robotic arm for performing delicate operations with high accuracy and minimal patient intervention.
- A system for controlling the position of the second robotic arm to assist in complex surgical procedures, providing enhanced precision.
- A robotic surgical system featuring a dual-arm configuration for multi-tasking in surgery, with an advanced control mechanism to optimize surgical outcomes.

The topic is described by these keywords: 'robotic arm, surgical robotic system, position control, robotic surgical system, multi-arm, control mechanism, precision'.

Based on the information about the topic above, please create a short label of this topic. Make sure you to only return the label and nothing more.

[/INST] Robotic arm systems for precise surgical control
"""

# %%
main_prompt = """
[INST]
I have a topic that contains the following documents:
[DOCUMENTS]

The topic is described by these keywords: '[KEYWORDS]'.

Based on the information about the topic above, please create a short label of this topic. Make sure you to only return the label and nothing more.
[/INST]
"""

# %%
prompt = system_prompt + example_prompt + main_prompt

# %%
df = pd.read_pickle('/content/drive/MyDrive/Theses/df.pkl')
df
# Out:
#         original_index ApplicationNumber  chunk_id  num_chunks  \
# 0                    0     US20220083465         1          43
# 1                    0     US20220083465         2          43
# 2                    0     US20220083465         3          43
# 3                    0     US20220083465         4          43
# 4                    0     US20220083465         5          43
# ...                ...               ...       ...         ...
# 219710           51621     US20210527046         1           1
# 219711           51622     US20240826061         1           1
# 219712           51623     US20210328898         1           1
# 219713           51624     US20200913236         1           1
# 219714           51625     US20240413363         1           1
#
#                                                     chunk  \
# 0       a minimally invasive system for treating a tar...
# 1       load sensor a joint torque sensor a strain gau...
# 2       system of claim wherein the hifu treatment tra...
# 3       in part by an acoustic fountain reaction assoc...
# 4       data the system of claim further comprising a ...
# ...                                                   ...
# 219710  a dental tool comprising a dental bur having a...
# 219711  a device comprising a diffractive optics senso...
# 219712  an apparatus for electronically producing at l...
# 219713  an integrated value based care return on inves...
# 219714  a surgical robot system as substantially shown...
#
#                                                 embedding  hdbscan_cluster_25  \
# 0       [0.102507465, -0.4690934, -0.16641176, -0.1034...                  -1
# 1       [5.1148196e-05, -0.2560497, -0.21868536, -0.10...                  -1
# 2       [-0.095717534, -0.15502435, -0.14605981, -0.13...                  -1
# 3       [0.07438903, -0.2188163, -0.16725114, -0.08933...                  -1
# 4       [0.03889325, 0.11438014, -0.18144202, 0.072535...                  -1
# ...                                                   ...                 ...
# 219710  [0.20198575, -0.54403746, -0.17521329, -0.2867...                  -1
# 219711  [-0.13728589, -0.725161, -0.2967089, -0.197800...                 294
# 219712  [-0.05236339, -0.28899363, -0.12927833, -0.392...                  -1
# 219713  [-0.10989852, -0.3885529, -0.3383775, 0.009414...                  -1
# 219714  [0.20027116, -0.48158565, -0.31080633, -0.3169...                  -1
#
#         hdbscan_cluster_60  hdbscan_cluster_100
# 0                       10                    2
# 1                       -1                   -1
# 2                       10                    2
# 3                       10                    2
# 4                       -1                   -1
# ...                    ...                  ...
# 219710                  -1                   -1
# 219711                  77                   -1
# 219712                  -1                   -1
# 219713                  -1                   -1
# 219714                  76                   49
#
# [219715 rows x 9 columns]

# %%
model_chunks = df['chunk'].astype(str).tolist()

# %%
Extended_Stopwords = pd.read_csv("/content/drive/MyDrive/Theses/extended_stopwords").to_numpy().flatten().tolist()

# %%
empty_reduction_model = BaseDimensionalityReduction()
empty_cluster_model = BaseCluster()

# %%
vectorizer_model = CountVectorizer(
    stop_words=Extended_Stopwords,
    min_df=2,
    ngram_range=(1, 3)
)

# %%
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# %%
keybert_model = KeyBERTInspired()
llama2 = TextGeneration(generator, prompt=prompt)
representation_model = {
    "KeyBERT": keybert_model,
    "Llama2": llama2,
}

# %%
#pipeline
topic_model2 = BERTopic(
    umap_model=empty_reduction_model,
    hdbscan_model=empty_cluster_model,
    vectorizer_model=vectorizer_model,
    ctfidf_model=ctfidf_model,
    representation_model=representation_model,
    top_n_words=10,
    verbose=True
)

topics, probabilities = topic_model2.fit_transform(model_chunks,y= df['hdbscan_cluster_100'])

topic_model2.fit_transform

topic_model2.visualize_topics()
# Out:
# 2025-04-16 11:37:10,173 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/6867 [00:00<?, ?it/s]
# 2025-04-16 11:47:35,527 - BERTopic - Embedding - Completed ✓
# 2025-04-16 11:47:35,528 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-04-16 11:47:35,530 - BERTopic - Dimensionality - Completed ✓
# 2025-04-16 11:47:36,769 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-04-16 11:47:36,790 - BERTopic - Cluster - Completed ✓
# 2025-04-16 11:47:36,841 - BERTopic - Representation - Fine-tuning topics using representation models.
#  19%|█▊        | 10/54 [02:04<08:57, 12.21s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|██████████| 54/54 [11:20<00:00, 12.60s/it]
# 2025-04-16 12:01:20,482 - BERTopic - Representation - Completed ✓
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="609f44ea-b162-42d1-9d6f-0379c9dad3f8" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("609f44ea-b162-42d1-9d6f-0379c9dad3f8")) {                    Plotly.newPlot(                        "609f44ea-b162-42d1-9d6f-0379c9dad3f8",                        [{"customdata":[[0,"ultrasound | ultrasonic | transducer | ultrasound image | probe",23363],[1,"user | health | patient | data | healthcare",18648],[2,"jaw | shaft | drive | staple | pulley",10358],[3,"fluid | lumen | catheter | valve | needle",9211],[4,"robotic | arm | robotic arm | robot | manipulator",5864],[5,"training | images | medical image | learning | neural",4709],[6,"reality | virtual | augmented | augmented reality | anatomical",3772],[7,"endoscope | endoscope system | light | illumination light | illumination",3042],[8,"endoscope | bending | insertion | operation | portion",2739],[9,"composition | acid | percent | agent | cells",2595],[10,"bone | implant | femoral | knee | joint",2418],[11,"plaque | coronary | vessel | blood | vascular",2342],[12,"dental | tooth | teeth | intraoral | oral",2290],[13,"processing apparatus | medical image | image processing | processing | medical image processing",1788],[14,"cardiac | ecg | heart | arrhythmia | computing systems",1496],[15,"image pickup | pickup | endoscope | board | surface",1459],[16,"canceled | adjusting mechanism | analytic signal | yaw adjusting | yaw adjusting mechanism",1445],[17,"magnetic | magnetic field | field | coil | coils",1434],[18,"surgical | surgical procedure | surgical hub | procedure | hub",1374],[19,"ablation | energy | electrodes | electrode | temperature",1332],[20,"light | fluorescence | wavelength | wavelength band | light source",1319],[21,"interface control module | mappingimagingrecording | mappingimagingrecording system | interface control | plus minus plus",1163],[22,"driving | driving mechanism | mechanism claimed | driving mechanism claimed | element driving",1145],[23,"nontransitory | medium | nontransitory computer | nontransitory computer readable | readable medium",1137],[24,"guide | bone | cutting guide | cutting | patientspecific",812],[25,"lens | optical system | denotes | lt | conditional",710],[26,"collection | sample | sample collection | sampling | swab",584],[27,"electromagnetic radiation | electromagnetic | radiation | exposure | pixel array",559],[28,"adjusted image | eye | adjusted | visual acuity | given pixel",545],[29,"fiber | optical fiber | optical | cladding | core",520],[30,"light | optical | beam | fiber | wavelength",430],[31,"voltage | circuit | transistor | amplifier | node",331],[32,"heart | pacing | electrogram | cardiac | map",321],[33,"bite block | bite | dental | tongue | mouth",318],[34,"nm | peak wavelength | reflectance | tissue | wavelength",314],[35,"conductor | electrosurgical | electrosurgical instrument | dielectric | conductive",244],[36,"ue | broadcast | service | detection components | downlink",241],[37,"audio | featurebased | featurebased voice | featurebased voice data | voice data",239],[38,"clamp arm | ultrasonic blade | ultrasonic surgical | ultrasonic surgical instrument | clamp",200],[39,"surgical module | module | energy module | electrosurgical | module surgical module",186],[40,"medical information | information processing apparatus | information processing | medical information processing | processing apparatus",177],[41,"luminal network | luminal | branch | portion luminal network | portion luminal",173],[42,"steerable catheter | catheter | steerable | steerable catheter assembly | flexible guide tube",161],[43,"cleaning member | cleaning | coupling element | cleaning apparatus | engaging structure",149],[44,"alternately displa ...

# %%
topic_model2.get_topic_info()
# Out:
#     Topic   Count                                               Name  \
# 0      -1  104909                     -1_light_sensor_device_optical
# 1       0   23363  0_ultrasound_ultrasonic_transducer_ultrasound ...
# 2       1   18648                         1_user_health_patient_data
# 3       2   10358                           2_jaw_shaft_drive_staple
# 4       3    9211                       3_fluid_lumen_catheter_valve
# 5       4    5864                    4_robotic_arm_robotic arm_robot
# 6       5    4709           5_training_images_medical image_learning
# 7       6    3772      6_reality_virtual_augmented_augmented reality
# 8       7    3042  7_endoscope_endoscope system_light_illuminatio...
# 9       8    2739            8_endoscope_bending_insertion_operation
# 10      9    2595                   9_composition_acid_percent_agent
# 11     10    2418                       10_bone_implant_femoral_knee
# 12     11    2342                    11_plaque_coronary_vessel_blood
# 13     12    2290                    12_dental_tooth_teeth_intraoral
# 14     13    1788  13_processing apparatus_medical image_image pr...
# 15     14    1496                    14_cardiac_ecg_heart_arrhythmia
# 16     15    1459             15_image pickup_pickup_endoscope_board
# 17     16    1445  16_canceled_adjusting mechanism_analytic signa...
# 18     17    1434              17_magnetic_magnetic field_field_coil
# 19     18    1374  18_surgical_surgical procedure_surgical hub_pr...
# 20     19    1332            19_ablation_energy_electrodes_electrode
# 21     20    1319   20_light_fluorescence_wavelength_wavelength band
# 22     21    1163  21_interface control module_mappingimagingreco...
# 23     22    1145  22_driving_driving mechanism_mechanism claimed...
# 24     23    1137  23_nontransitory_medium_nontransitory computer...
# 25     24     812                24_guide_bone_cutting guide_cutting
# 26     25     710                  25_lens_optical system_denotes_lt
# 27     26     584    26_collection_sample_sample collection_sampling
# 28     27     559  27_electromagnetic radiation_electromagnetic_r...
# 29     28     545       28_adjusted image_eye_adjusted_visual acuity
# 30     29     520            29_fiber_optical fiber_optical_cladding
# 31     30     430                        30_light_optical_beam_fiber
# 32     31     331            31_voltage_circuit_transistor_amplifier
# 33     32     321                32_heart_pacing_electrogram_cardiac
# 34     33     318                   33_bite block_bite_dental_tongue
# 35     34     314           34_nm_peak wavelength_reflectance_tissue
# 36     35     244  35_conductor_electrosurgical_electrosurgical i...
# 37     36     241       36_ue_broadcast_service_detection components
# 38     37     239  37_audio_featurebased_featurebased voice_featu...
# 39     38     200  38_clamp arm_ultrasonic blade_ultrasonic surgi...
# 40     39     186  39_surgical module_module_energy module_electr...
# 41     40     177  40_medical information_information processing ...
# 42     41     173  41_luminal network_luminal_branch_portion lumi...
# 43     42     161  42_steerable catheter_catheter_steerable_steer...
# 44     43     149  43_cleaning member_cleaning_coupling element_c...
# 45     44     148  44_alternately displaying_false color_onmoving...
# 46     45     144               45_endoscope_cannula_handle_cordless
# 47     46     136                   46_ion_ion source_aerosol_vapour
# 48     47     134   47_cyber_sensor observation_concise_analytically
# 49     48     125  48_skeletal portion_portion tool_skeletal_loca...
# 50     49     119  49_flexible tube_flexible tube insertion_stiff...
# 51     50     117  50_prong_guide needle_coil electrode_andor tissue
# 52     51     114  51_iol_intraocular lens_intraocular_postoperative
# 53     52     112  52_signalling_signalling units_measured points...
#
#                                        Representation  \
# 0   [light, sensor, device, optical, surgical, por...
# 1   [ultrasound, ultrasonic, transducer, ultrasoun...
# 2   [user, health, patient, data, healthcare, asso...
# 3   [jaw, shaft, drive, staple, pulley, member, ef...
# 4   [fluid, lumen, catheter, valve, needle, distal...
# 5   [robotic, arm, robotic arm, robot, manipulator...
# 6   [training, images, medical image, learning, ne...
# 7   [reality, virtual, augmented, augmented realit...
# 8   [endoscope, endoscope system, light, illuminat...
# 9   [endoscope, bending, insertion, operation, por...
# 10  [composition, acid, percent, agent, cells, can...
# 11  [bone, implant, femoral, knee, joint, femur, s...
# 12  [plaque, coronary, vessel, blood, vascular, bl...
# 13  [dental, tooth, teeth, intraoral, oral, arch, ...
# 14  [processing apparatus, medical image, image pr...
# 15  [cardiac, ecg, heart, arrhythmia, computing sy...
# 16  [image pickup, pickup, endoscope, board, surfa...
# 17  [canceled, adjusting mechanism, analytic signa...
# 18  [magnetic, magnetic field, field, coil, coils,...
# 19  [surgical, surgical procedure, surgical hub, p...
# 20  [ablation, energy, electrodes, electrode, temp...
# 21  [light, fluorescence, wavelength, wavelength b...
# 22  [interface control module, mappingimagingrecor...
# 23  [driving, driving mechanism, mechanism claimed...
# 24  [nontransitory, medium, nontransitory computer...
# 25  [guide, bone, cutting guide, cutting, patients...
# 26  [lens, optical system, denotes, lt, conditiona...
# 27  [collection, sample, sample collection, sampli...
# 28  [electromagnetic radiation, electromagnetic, r...
# 29  [adjusted image, eye, adjusted, visual acuity,...
# 30  [fiber, optical fiber, optical, cladding, core...
# 31  [light, optical, beam, fiber, wavelength, sour...
# 32  [voltage, circuit, transistor, amplifier, node...
# 33  [heart, pacing, electrogram, cardiac, map, ele...
# 34  [bite block, bite, dental, tongue, mouth, retr...
# 35  [nm, peak wavelength, reflectance, tissue, wav...
# 36  [conductor, electrosurgical, electrosurgical i...
# 37  [ue, broadcast, service, detection components,...
# 38  [audio, featurebased, featurebased voice, feat...
# 39  [clamp arm, ultrasonic blade, ultrasonic surgi...
# 40  [surgical module, module, energy module, elect...
# 41  [medical information, information processing a...
# 42  [luminal network, luminal, branch, portion lum...
# 43  [steerable catheter, catheter, steerable, stee...
# 44  [cleaning member, cleaning, coupling element, ...
# 45  [alternately displaying, false color, onmoving...
# 46  [endoscope, cannula, handle, cordless, reusabl...
# 47  [ion, ion source, aerosol, vapour, aerosol smo...
# 48  [cyber, sensor observation, concise, analytica...
# 49  [skeletal portion, portion tool, skeletal, loc...
# 50  [flexible tube, flexible tube insertion, stiff...
# 51  [prong, guide needle, coil electrode, andor ti...
# 52  [iol, intraocular lens, intraocular, postopera...
# 53  [signalling, signalling units, measured points...
#
#                                               KeyBERT  \
# 0   [imaging, image data, sensor, tracking, device...
# 1   [ultrasound diagnostic apparatus, ultrasound s...
# 2   [patient data, machine learning, computing dev...
# 3   [surgical tool, surgical instrument, shaft ass...
# 4   [catheter, insufflation, medical device, cathe...
# 5   [surgical robotic system, robotic surgical sys...
# 6   [medical image data, training image, medical i...
# 7   [augmented reality device, augmented reality s...
# 8   [image endoscope system, information endoscope...
# 9   [part endoscope, endoscope insertion, endoscop...
# 10  [formulation, pharmaceutical, compound, pharma...
# 11  [femoral component, knee joint, femoral implan...
# 12  [angiographic, angiography image, coronary art...
# 13  [dental impression, model dental, image dental...
# 14  [image processing apparatus, information medic...
# 15  [ecg signals data, ecg signals, ecg data, ecg ...
# 16  [image pickup apparatus, image pickup unit, im...
# 17  [signal analytic, mechanism detects, signal an...
# 18  [magnetic capsule, mri, magnetic tracking, mag...
# 19  [surgical computing system, surgical computing...
# 20  [ablation device, ablation electrode, ablation...
# 21  [light imaging, imaging system, imaging device...
# 22  [catheter control, operation transducers, inte...
# 23  [optical element driving, optical member drivi...
# 24  [procedure nontransitory computer, readable me...
# 25  [orthopaedic surgical instrument, patientspeci...
# 26  [endoscope objective optical, objective lens, ...
# 27  [sample preservation, sample preservation reag...
# 28  [plurality exposure frames, radiation sensed, ...
# 29  [virtual image, visual acuity, vision, percept...
# 30  [distal optical fiber, fiber optics, fiber opt...
# 31  [light optical, illumination source, source li...
# 32  [operational amplifier, amplifier circuit, dif...
# 33  [electrogram signals, electrophysiological map...
# 34  [dental device, mandibular piece, portion mout...
# 35  [wavelength tissue, peak wavelength tissue, bi...
# 36  [electrosurgical instrument, electrosurgical a...
# 37  [radio resource control, data transmission, br...
# 38  [voice data associated, featurebased voice dat...
# 39  [ultrasonic surgical instrument, ultrasonic su...
# 40  [modular surgical system, modular surgical, sy...
# 41  [medical information processing, medical infor...
# 42  [model luminal network, within luminal, portio...
# 43  [steerable guide catheter, steerable catheter ...
# 44  [endoscope cleaning device, apparatus cleaning...
# 45  [image program code, image color values, image...
# 46  [cordless endoscope, endoscope system, endosco...
# 47  [ion source, spectrometry andor ion, spectrome...
# 48  [sensor observations, features sensor, utilizi...
# 49  [skeletal portion xray, skeletal portion view,...
# 50  [apparatus flexible tube, insertion apparatus ...
# 51  [subcutaneously implantable device, subcutaneo...
# 52  [preoperative measurements eye, ophthalmologic...
# 53  [anatomic passageways, passageways patient, pa...
#
#                                                Llama2  \
# 0   [Medical Imaging and Surgical Navigation, , , ...
# 1   [Ultrasound Imaging and Diagnostics, , , , , ,...
# 2       [Healthcare Data Analytics, , , , , , , , , ]
# 3      [Surgical Instrument Design, , , , , , , , , ]
# 4   [Fluid and gas delivery systems, , , , , , , ,...
# 5        [Robotic Surgical Systems, , , , , , , , , ]
# 6   [Trained Medical Image Analysis, , , , , , , ,...
# 7   [Augmented Reality Surgical Navigation, , , , ...
# 8      [Endoscope Image Processing, , , , , , , , , ]
# 9   [Endoscope design and insertion techniques, , ...
# 10  [Compositions for Cancer Imaging and Treatment...
# 11  [Patient-specific joint replacement planning, ...
# 12       [Coronary Plaque Analysis, , , , , , , , , ]
# 13   [Dental Impression Technology, , , , , , , , , ]
# 14       [Medical Image Processing, , , , , , , , , ]
# 15  [Cardiac Arrhythmia Detection and Analysis, , ...
# 16  [Image Pickup Module & Endoscope, , , , , , , ...
# 17  [Adjustable Analytic Signal Processing, , , , ...
# 18  [Magnetic Field Control for Medical Imaging, ,...
# 19   [Surgical System Optimization, , , , , , , , , ]
# 20            [RF Ablation Systems, , , , , , , , , ]
# 21           [Fluorescence Imaging, , , , , , , , , ]
# 22  [Control Interface for Mapping Imaging Recordi...
# 23  [Optical element driving mechanisms, , , , , ,...
# 24  [Intracorporeal Video Analysis, , , , , , , , , ]
# 25         [Tibial osteotomy guide, , , , , , , , , ]
# 26  [Lens and Optical System Design, , , , , , , ,...
# 27       [Sample Collection System, , , , , , , , , ]
# 28  [Electromagnetic Radiation Imaging, , , , , , ...
# 29  [Augmented Reality Eyewear for Enhanced Visual...
# 30  [Optical Fiber Design for Light Scattering, , ...
# 31        [Optical Beam Management, , , , , , , , , ]
# 32    [Voltage offset cancellation, , , , , , , , , ]
# 33   [Cardiac Electrogram Analysis, , , , , , , , , ]
# 34  [Dental Bite Management System, , , , , , , , , ]
# 35   [Near-infrared tissue imaging, , , , , , , , , ]
# 36   [Coaxial Microwave Instrument, , , , , , , , , ]
# 37  [UE Broadcast Service Detection, , , , , , , ,...
# 38         [Audio Feature Analysis, , , , , , , , , ]
# 39  [Ultrasonic Surgical Instrument, , , , , , , ,...
# 40  [Modular Electrosurgical Systems, , , , , , , ...
# 41  [Medical Information Processing, , , , , , , ,...
# 42     [Luminal Network Navigation, , , , , , , , , ]
# 43     [Steerable Catheter Systems, , , , , , , , , ]
# 44      [Endoscope Cleaning System, , , , , , , , , ]
# 45        [Alternate Image Display, , , , , , , , , ]
# 46     [Cordless Endoscope Systems, , , , , , , , , ]
# 47  [Aerosol Ionisation and Spectrometry, , , , , ...
# 48         [Cyber Health Analytics, , , , , , , , , ]
# 49  [Location-based Tool Navigation for Skeletal P...
# 50  [Flexible Tube Insertion Systems, , , , , , , ...
# 51      [Subcutaneous Heart Device, , , , , , , , , ]
# 52  [Intraocular Lens Prediction System, , , , , ,...
# 53  [Signaling and Navigation for Inspection and A...
#
#                                   Representative_Docs
# 0   [a medical system comprising a sensor configur...
# 1   [reference region that correspond to each colo...
# 2   [of claim wherein the machine learning model i...
# 3   [cartridge a surgical instrument comprising an...
# 4   [for the output of cryogen and a lumen extendi...
# 5   [the position of the second robotic and contro...
# 6   [the second image with the estimated segmentat...
# 7   [display screen aligned with one of the anatom...
# 8   [an endoscope system comprising a light source...
# 9   [side of the operating part and is inserted in...
# 10  [a compound of formula i or a salt thereof vie...
# 11  [data comprises at least a coronal mechanical ...
# 12  [value between about and hounsfield units the ...
# 13  [of the user based on at least a starting posi...
# 14  [to acquire the related image information and ...
# 15  [ecg sensors is positioned in on an abdomen of...
# 16  [plane the third principal plane being dispose...
# 17  [speckle exceeds a predetermined distance with...
# 18  [a method for imaging in surgical procedures c...
# 19  [a surgical system configured to improve surgi...
# 20  [neck or a submentum the device of claim where...
# 21  [a medical observation system comprising a lig...
# 22  [user of a manually-operated catheter control ...
# 23  [the driving portion comprises a first driving...
# 24  [a non-transitory computer readable medium con...
# 25  [onto an anterior surface of the proximal end ...
# 26  [an endoscope objective optical system compris...
# 27  [a method of collecting and preserving a biolo...
# 28  [a color image frame depicting the scene to in...
# 29  [a device operable to dynamically adjust user ...
# 30  [with the core wire and the mirror is spaced a...
# 31  [image dataset within the overlapping region t...
# 32  [a circuit for removing a large differential v...
# 33  [a system configured to detect a location of a...
# 34  [a mandibular repositioning device comprising ...
# 35  [a method in a nervous tissue imaging system t...
# 36  [an electrosurgical apparatus for delivering r...
# 37  [sub-range of mbms service ids the server of c...
# 38  [beams configured to receive audio encounter i...
# 39  [an ultrasonic surgical instrument comprising ...
# 40  [a modular surgical system comprising a header...
# 41  [a medical information processing apparatus co...
# 42  [wherein the control circuit further has store...
# 43  [a steerable guide catheter comprising a flexi...
# 44  [away from contact with the imaging element wh...
# 45  [spect image a magnetic resonance imaging mm i...
# 46  [receiving images at the display unit taken wi...
# 47  [wherein said second device comprises an ambie...
# 48  [universal health metrics monitors assign appr...
# 49  [apparatus for performing a procedure using a ...
# 50  [about a central axis the flexible tube sectio...
# 51  [a subcutaneously implantable device comprisin...
# 52  [a non-transitory machine-readable medium comp...
# 53  [canceled a method of continuously registering...

# %%
#topic_model2.save('/content/drive/MyDrive/Theses/BERTv2')
# Out:
# 2025-04-16 11:19:22,585 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.

# %%
llama2_labels = [label[0][0].split("\n")[0] for label in topic_model2.get_topics(full=True)["Llama2"].values()]
topic_model2.set_topic_labels(llama2_labels)

# %%
hierachy_fig2 = topic_model2.visualize_hierarchy(custom_labels=True)
hierachy_fig2.write_html("/content/drive/MyDrive/Theses/hierachy2.html")

# %%
hierachy_fig2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f4ca0f6c-3c6e-4978-9dfe-848d6e910820" class="plotly-graph-div" style="height:995px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4ca0f6c-3c6e-4978-9dfe-848d6e910820")) {                    Plotly.newPlot(                        "f4ca0f6c-3c6e-4978-9dfe-848d6e910820",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9782608808626645,0.9782608808626645,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9100148170451501,0.9100148170451501,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.6517112687694254,0.6517112687694254,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.6942954429574368,0.6942954429574368,0.6517112687694254],"xaxis":"x","y":[-65.0,-65.0,-80.0,-80.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.6942954429574368,0.8684360859280468,0.8684360859280468,0.0],"xaxis":"x","y":[-72.5,-72.5,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8858003541565366,0.8858003541565366,0.8684360859280468],"xaxis":"x","y":[-55.0,-55.0,-83.75,-83.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.8858003541565366,0.9098601490450416,0.9098601490450416,0.0],"xaxis":"x","y":[-69.375,-69.375,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9148483308433106,0.9148483308433106,0.9098601490450416],"xaxis":"x","y":[-45.0,-45.0,-87.1875,-87.1875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9148483308433106,0.9292624964332646,0.9292624964332646,0.0],"xaxis":"x","y":[-66.09375,-66.09375,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9100148170451501,0.9419099481261904,0.9419099481261904,0.9292624964332646],"xaxis":"x","y":[-30.0,-30.0,-90.546875,-90.546875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9782608808626645,1.013020017354009,1.013020017354009,0.9419099481261904],"xaxis":"x","y":[-10.0,-10.0,-60.2734375,-60.2734375],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.7883741354238962,0.7883741354238962,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.8421126789699716,0.8421126789699716,0.7883741354238962],"xaxis":"x","y":[-125.0,-125.0,-140.0,-140.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.8609070071321931,0.8609070071321931,0.0],"xaxis":"x","y":[-155.0,-155.0,-165.0,-165.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.8421126789699716,0.8862561292308161,0.8862561292308161,0.8609070071321931],"xaxis":"x","y":[-132.5,-132.5,-160.0,-160.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.013020017354009,1.154200631618322,1.154200631618322,0.8862561292308161],"xaxis":"x","y":[-35.13671875,-35.13671875,-146.25,-146.25],"yaxis":"y","type":"scatter"},{"hoverinfo ...

# %%
distance_map2 = topic_model2.visualize_topics(custom_labels=True)
distance_map2.write_html("/content/drive/MyDrive/Theses/topics2.html")

# %%
distance_map2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b396f89f-3b5c-496b-8218-053573768a97" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b396f89f-3b5c-496b-8218-053573768a97")) {                    Plotly.newPlot(                        "b396f89f-3b5c-496b-8218-053573768a97",                        [{"customdata":[[0,"Ultrasound Imaging and Diagnostics",23363],[1,"Healthcare Data Analytics",18648],[2,"Surgical Instrument Design",10358],[3,"Fluid and gas delivery systems",9211],[4,"Robotic Surgical Systems",5864],[5,"Trained Medical Image Analysis",4709],[6,"Augmented Reality Surgical Navigation",3772],[7,"Endoscope Image Processing",3042],[8,"Endoscope design and insertion techniques",2739],[9,"Compositions for Cancer Imaging and Treatment",2595],[10,"Patient-specific joint replacement planning",2418],[11,"Coronary Plaque Analysis",2342],[12,"Dental Impression Technology",2290],[13,"Medical Image Processing",1788],[14,"Cardiac Arrhythmia Detection and Analysis",1496],[15,"Image Pickup Module & Endoscope",1459],[16,"Adjustable Analytic Signal Processing",1445],[17,"Magnetic Field Control for Medical Imaging",1434],[18,"Surgical System Optimization",1374],[19,"RF Ablation Systems",1332],[20,"Fluorescence Imaging",1319],[21,"Control Interface for Mapping Imaging Recording",1163],[22,"Optical element driving mechanisms",1145],[23,"Intracorporeal Video Analysis",1137],[24,"Tibial osteotomy guide",812],[25,"Lens and Optical System Design",710],[26,"Sample Collection System",584],[27,"Electromagnetic Radiation Imaging",559],[28,"Augmented Reality Eyewear for Enhanced Visual Acuity",545],[29,"Optical Fiber Design for Light Scattering",520],[30,"Optical Beam Management",430],[31,"Voltage offset cancellation",331],[32,"Cardiac Electrogram Analysis",321],[33,"Dental Bite Management System",318],[34,"Near-infrared tissue imaging",314],[35,"Coaxial Microwave Instrument",244],[36,"UE Broadcast Service Detection",241],[37,"Audio Feature Analysis",239],[38,"Ultrasonic Surgical Instrument",200],[39,"Modular Electrosurgical Systems",186],[40,"Medical Information Processing",177],[41,"Luminal Network Navigation",173],[42,"Steerable Catheter Systems",161],[43,"Endoscope Cleaning System",149],[44,"Alternate Image Display",148],[45,"Cordless Endoscope Systems",144],[46,"Aerosol Ionisation and Spectrometry",136],[47,"Cyber Health Analytics",134],[48,"Location-based Tool Navigation for Skeletal Portion Imaging",125],[49,"Flexible Tube Insertion Systems",119],[50,"Subcutaneous Heart Device",117],[51,"Intraocular Lens Prediction System",114],[52,"Signaling and Navigation for Inspection and Anatomy",112]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[23363,18648,10358,9211,5864,4709,3772,3042,2739,2595,2418,2342,2290,1788,1496,1459,1445,1434,1374,1332,1319,1163,1145,1137,812,710,584,559,545,520,430,331,321,318,314,244,241,239,200,186,177,173,161,149,148,144,136,134,125,119,117,114,112],"sizemode":"area","sizeref":14.601875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-7.0453,-5.44509,14.327942,11.623758,14.572207,1.506507,2.1330311,10.777171,10.2235775,11.30168,13.829469,3.8645809,14.056806,1.4486071,3.7986,10.710045,-4.994219,2.491256,1.6908007,3.1779675,-1.4434464,14.45622,-2.148504,-5.137897,13.829386,10.813173,11.434738,-1.3096199,2.4704232,-2.219049,-1.9035642,0.14323007,3.9020298,14.120278,-1.3501076,3.2898428,0.14270324,-6.9625616,14.333098,1.6317898,-5.5022793,2.427067,11.833249,10.09901,1.6298673,10.408885,11.209305,-5.390948,2.2196577,11.832684,3.2677484,2. ...

# %%
r_umap_embeddings = np.load('/content/drive/MyDrive/Theses/umap_embeddings_50_3d.npy')

# %%
topic_model2.visualize_documents(titles, reduced_embeddings=r_umap_embeddings, hide_annotations=True, hide_document_hover=False, custom_labels=True)

# %%
details_df = pd.read_csv('/content/drive/MyDrive/Theses/final_patent_text.csv', usecols=['ApplicationNumber', 'ProbablePatentAssignee', 'Year'])
details_df
# Out:
#       ApplicationNumber  ProbablePatentAssignee  Year
# 0         US20220083465      PETAL SURGICAL INC  2021
# 1         US20180497284  BIORA THERAPEUTICS INC  2017
# 2         US20190467784  BIORA THERAPEUTICS INC  2016
# 3         US20170465360  BIORA THERAPEUTICS INC  2016
# 4         US20210295221        VUZE MEDICAL LTD  2018
# ...                 ...                     ...   ...
# 51621     US20210527046       DENTLYTEC GPL LTD  2015
# 51622     US20240826061  BIORA THERAPEUTICS INC  2016
# 51623     US20210328898    SMART REPORTING GMBH  2015
# 51624     US20200913236     MY MEDICAL HUB CORP  2019
# 51625     US20240413363      GLOBUS MEDICAL INC  2016
#
# [51626 rows x 3 columns]

# %%
df = df.merge(details_df[['ApplicationNumber', 'Year', 'ProbablePatentAssignee']], on='ApplicationNumber', how='left')

# %%
final_topic_df = topic_model2.get_document_info(model_chunks)

# %%
final_topic_df['ApplicationNumber'] = df['ApplicationNumber'].values

# %%
final_topic_df['Year'] = df['Year'].values

# %%
final_topic_df['ProbablePatentAssignee'] = df['ProbablePatentAssignee'].values

# %%
final_topic_df
# Out:
#                                                  Document  Topic  \
# 0       a minimally invasive system for treating a tar...      0
# 1       load sensor a joint torque sensor a strain gau...     -1
# 2       system of claim wherein the hifu treatment tra...      0
# 3       in part by an acoustic fountain reaction assoc...      0
# 4       data the system of claim further comprising a ...     -1
# ...                                                   ...    ...
# 219710  a dental tool comprising a dental bur having a...     -1
# 219711  a device comprising a diffractive optics senso...     -1
# 219712  an apparatus for electronically producing at l...     -1
# 219713  an integrated value based care return on inves...     -1
# 219714  a surgical robot system as substantially shown...      4
#
#                                                      Name  \
# 0       0_ultrasound_ultrasonic_transducer_ultrasound ...
# 1                          -1_light_sensor_device_optical
# 2       0_ultrasound_ultrasonic_transducer_ultrasound ...
# 3       0_ultrasound_ultrasonic_transducer_ultrasound ...
# 4                          -1_light_sensor_device_optical
# ...                                                   ...
# 219710                     -1_light_sensor_device_optical
# 219711                     -1_light_sensor_device_optical
# 219712                     -1_light_sensor_device_optical
# 219713                     -1_light_sensor_device_optical
# 219714                    4_robotic_arm_robotic arm_robot
#
#                                      CustomName  \
# 0            Ultrasound Imaging and Diagnostics
# 1       Medical Imaging and Surgical Navigation
# 2            Ultrasound Imaging and Diagnostics
# 3            Ultrasound Imaging and Diagnostics
# 4       Medical Imaging and Surgical Navigation
# ...                                         ...
# 219710  Medical Imaging and Surgical Navigation
# 219711  Medical Imaging and Surgical Navigation
# 219712  Medical Imaging and Surgical Navigation
# 219713  Medical Imaging and Surgical Navigation
# 219714                 Robotic Surgical Systems
#
#                                            Representation  \
# 0       [ultrasound, ultrasonic, transducer, ultrasoun...
# 1       [light, sensor, device, optical, surgical, por...
# 2       [ultrasound, ultrasonic, transducer, ultrasoun...
# 3       [ultrasound, ultrasonic, transducer, ultrasoun...
# 4       [light, sensor, device, optical, surgical, por...
# ...                                                   ...
# 219710  [light, sensor, device, optical, surgical, por...
# 219711  [light, sensor, device, optical, surgical, por...
# 219712  [light, sensor, device, optical, surgical, por...
# 219713  [light, sensor, device, optical, surgical, por...
# 219714  [robotic, arm, robotic arm, robot, manipulator...
#
#                                                   KeyBERT  \
# 0       [ultrasound diagnostic apparatus, ultrasound s...
# 1       [imaging, image data, sensor, tracking, device...
# 2       [ultrasound diagnostic apparatus, ultrasound s...
# 3       [ultrasound diagnostic apparatus, ultrasound s...
# 4       [imaging, image data, sensor, tracking, device...
# ...                                                   ...
# 219710  [imaging, image data, sensor, tracking, device...
# 219711  [imaging, image data, sensor, tracking, device...
# 219712  [imaging, image data, sensor, tracking, device...
# 219713  [imaging, image data, sensor, tracking, device...
# 219714  [surgical robotic system, robotic surgical sys...
#
#                                                    Llama2  \
# 0       [Ultrasound Imaging and Diagnostics, , , , , ,...
# 1       [Medical Imaging and Surgical Navigation, , , ...
# 2       [Ultrasound Imaging and Diagnostics, , , , , ,...
# 3       [Ultrasound Imaging and Diagnostics, , , , , ,...
# 4       [Medical Imaging and Surgical Navigation, , , ...
# ...                                                   ...
# 219710  [Medical Imaging and Surgical Navigation, , , ...
# 219711  [Medical Imaging and Surgical Navigation, , , ...
# 219712  [Medical Imaging and Surgical Navigation, , , ...
# 219713  [Medical Imaging and Surgical Navigation, , , ...
# 219714       [Robotic Surgical Systems, , , , , , , , , ]
#
#                                       Representative_Docs  \
# 0       [reference region that correspond to each colo...
# 1       [a medical system comprising a sensor configur...
# 2       [reference region that correspond to each colo...
# 3       [reference region that correspond to each colo...
# 4       [a medical system comprising a sensor configur...
# ...                                                   ...
# 219710  [a medical system comprising a sensor configur...
# 219711  [a medical system comprising a sensor configur...
# 219712  [a medical system comprising a sensor configur...
# 219713  [a medical system comprising a sensor configur...
# 219714  [the position of the second robotic and contro...
#
#                                               Top_n_words  \
# 0       ultrasound - ultrasonic - transducer - ultraso...
# 1       light - sensor - device - optical - surgical -...
# 2       ultrasound - ultrasonic - transducer - ultraso...
# 3       ultrasound - ultrasonic - transducer - ultraso...
# 4       light - sensor - device - optical - surgical -...
# ...                                                   ...
# 219710  light - sensor - device - optical - surgical -...
# 219711  light - sensor - device - optical - surgical -...
# 219712  light - sensor - device - optical - surgical -...
# 219713  light - sensor - device - optical - surgical -...
# 219714  robotic - arm - robotic arm - robot - manipula...
#
#         Representative_document ApplicationNumber  Year  \
# 0                         False     US20220083465  2021
# 1                         False     US20220083465  2021
# 2                         False     US20220083465  2021
# 3                         False     US20220083465  2021
# 4                         False     US20220083465  2021
# ...                         ...               ...   ...
# 219710                    False     US20210527046  2015
# 219711                    False     US20240826061  2016
# 219712                    False     US20210328898  2015
# 219713                    False     US20200913236  2019
# 219714                    False     US20240413363  2016
#
#         ProbablePatentAssignee
# 0           PETAL SURGICAL INC
# 1           PETAL SURGICAL INC
# 2           PETAL SURGICAL INC
# 3           PETAL SURGICAL INC
# 4           PETAL SURGICAL INC
# ...                        ...
# 219710       DENTLYTEC GPL LTD
# 219711  BIORA THERAPEUTICS INC
# 219712    SMART REPORTING GMBH
# 219713     MY MEDICAL HUB CORP
# 219714      GLOBUS MEDICAL INC
#
# [219715 rows x 13 columns]

# %%
final_topic_df.to_csv("/content/drive/MyDrive/Theses/final_topic2_df.csv", index=False)

# %%
#new prompts
system_prompt = """
<s>[INST] <<SYS>>
You are a helpful, truthful and honest patent analysis assistant that summarize the topics a ProbablePatentAssignee has. You are an expert in analyzing patent topics for medical devices, especially in the field of endoscopy. Your goal is to interpret the topics generated from patents and identify what types of products or innovations the companies are working on.
This should be in a concise and human-readable language. If it is unclear, don't just say something, but say something like "Miscellaneous".
<</SYS>>
"""

# %%
example_prompt = """
I have a list of patent topics for a single Company:
1. Imaging system with enhanced resolution for internal organ visualization.
2. Robotic system for performing minimally invasive surgeries with precise control.
3. Endoscopic device with integrated AI for detecting anomalies during procedures.
4.rhinolaryngoscope

Based on these topics, please identify what type of product or innovation the assignee is likely developing. Provide a concise and human-readable description.
Make sure you to only return a short precise summarization of topics and analysis.
[/INST] Rhinolaryngoscope with assisted AI system
"""

# %%
main_prompt = """
[INST]
I have a [ProbablePatentAssignee] with the following patent topics:
[Llama2]
[Llama2]

Based on these topics, please identify what type of product, products or innovation the assignee is likely developing. Provide a concise and human-readable description.
Make sure you to only return a short precise summarization of topics and analysis.
[/INST]
"""

# %%
prompt = system_prompt + example_prompt + main_prompt

# %%
final_topic_df = pd.read_csv("/content/drive/MyDrive/Theses/final_topic2_df.csv")

# %%
company = "OLYMPUS CORP"

filtered_df = final_topic_df[final_topic_df["ProbablePatentAssignee"] == company]
topic_summary = (
    filtered_df
    .groupby(["ProbablePatentAssignee", "Topic"])
    .agg({
        "Llama2": "first",
        "Top_n_words": "first",
        "ApplicationNumber": "nunique"
    })
    .rename(columns={"ApplicationNumber": "ApplicationNoCount"})
    .reset_index()
)
#prompts
prompt_parts = [f"### Company: {company}\n"]
for _, row in topic_summary.iterrows():
    prompt_parts.append(
        f"Topic {row['Topic']} ({row['ApplicationNoCount']} chunks): {row['Llama2']}\n"
        f"Keywords: {row['Top_n_words']}\n"
    )

main_prompt = "\n".join(prompt_parts)

final_prompt = f"""
Company: {company}
Based on the following patent topics, please summarize the type of product(s) or innovation the company is likely developing. Provide a concise, human-readable description that connects these topics to potential products or technological areas.

{main_prompt}

Summarize the above into a concise and human-readable description of the company’s products or innovations, focusing on the connection between the topics and the company's technology.
"""

response = generator(final_prompt, max_length=500, temperature=0.7, top_p=0.9)[0]['generated_text']
print(f"Analysis for {company}:\n{response}")
# Out:
# Both `max_new_tokens` (=500) and `max_length`(=500) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Analysis for OLYMPUS CORP:
#
# Company: OLYMPUS CORP
# Based on the following patent topics, please summarize the type of product(s) or innovation the company is likely developing. Provide a concise, human-readable description that connects these topics to potential products or technological areas.
#
# ### Company: OLYMPUS CORP
#
# Topic -1 (1315 chunks): ['Medical Imaging and Surgical Navigation', '', '', '', '', '', '', '', '', '']
# Keywords: light - sensor - device - optical - surgical - portion - distal - system - configured - position
#
# Topic 0 (116 chunks): ['Ultrasound Imaging and Diagnostics', '', '', '', '', '', '', '', '', '']
# Keywords: ultrasound - ultrasonic - transducer - ultrasound image - probe - ultrasound probe - acoustic - ultrasound imaging - ultrasound transducer - wave
#
# Topic 1 (16 chunks): ['Healthcare Data Analytics', '', '', '', '', '', '', '', '', '']
# Keywords: user - health - patient - data - healthcare - associated - information - clinical - record - server
#
# Topic 2 (107 chunks): ['Surgical Instrument Design', '', '', '', '', '', '', '', '', '']
# Keywords: jaw - shaft - drive - staple - pulley - member - effector - cartridge - gear - assembly
#
# Topic 3 (79 chunks): ['Fluid and gas delivery systems', '', '', '', '', '', '', '', '', '']
# Keywords: fluid - lumen - catheter - valve - needle - distal - tube - proximal - cannula - port
#
# Topic 4 (27 chunks): ['Robotic Surgical Systems', '', '', '', '', '', '', '', '', '']
# Keywords: robotic - arm - robotic arm - robot - manipulator - joint - surgical - robotic system - tool - force
#
# Topic 5 (11 chunks): ['Trained Medical Image Analysis', '', '', '', '', '', '', '', '', '']
# Keywords: training - images - medical image - learning - neural - neural network - network - medical images - machine learning - image
#
# Topic 6 (5 chunks): ['Augmented Reality Surgical Navigation', '', '', '', '', '', '', '', '', '']
# Keywords: reality - virtual - augmented - augmented reality - anatomical - tracking - coordinate - display - registration - ar
#
# Topic 7 (398 chunks): ['Endoscope Image Processing', '', '', '', '', '', '', '', '', '']
# Keywords: endoscope - endoscope system - light - illumination light - illumination - endoscope apparatus - endoscopic - observation - light source - endoscope image
#
# Topic 8 (309 chunks): ['Endoscope design and insertion techniques', '', '', '', '', '', '', '', '', '']
# Keywords: endoscope - bending - insertion - operation - portion - elevator - wire - section - insertion portion - portion endoscope
#
# Topic 9 (3 chunks): ['Compositions for Cancer Imaging and Treatment', '', '', '', '', '', '', '', '', '']
# Keywords: composition - acid - percent - agent - cells - cancer - compound - cell - ch - claims
#
# Topic 13 (107 chunks): ['Medical Image Processing', '', '', '', '', '', '', '', '', '']
# Keywords: processing apparatus - medical image - image processing - processing - medical image processing - image processing apparatus - information processing - information processing apparatus - image - information
#
# Topic 15 (224 chunks): ['Image Pickup Module & Endoscope', '', '', '', '', '', '', '', '', '']
# Keywords: image pickup - pickup - endoscope - board - surface - substrate - principal surface - wiring - principal - resin
#
# Topic 16 (47 chunks): ['Adjustable Analytic Signal Processing', '', '', '', '', '', '', '', '', '']
# Keywords: canceled - adjusting mechanism - analytic signal - yaw adjusting - yaw adjusting mechanism - filtering tool - analytic - canceled canceled - pitch adjusting mechanism - pitch adjusting
#
# Topic 17 (16 chunks): ['Magnetic Field Control for Medical Imaging', '', '', '', '', '', '', '', '', '']
# Keywords: magnetic - magnetic field - field - coil - coils - magnet - magnetic sensor - electromagnetic - capsule - field generation
#
# Topic 18 (9 chunks): ['Surgical System Optimization', '', '', '', '', '', '', '', '', '']
# Keywords: surgical - surgical procedure - surgical hub - procedure - hub - surgical device - surgical data - operating room - surgical system - plurality surgical
#
# Topic 19 (6 chunks): ['RF Ablation Systems', '', '', '', '', '', '', '', '', '']
# Keywords: ablation - energy - electrodes - electrode - temperature - radiofrequency - tissue - electric current - rf - electric
#
# Topic 20 (111 chunks): ['Fluorescence Imaging', '', '', '', '', '', '', '', '', '']
# Keywords: light - fluorescence - wavelength - wavelength band - light source - band - illumination - source - excitation light - excitation
#
# Topic 21 (92 chunks): ['Control Interface for Mapping Imaging Recording', '', '', '', '', '', '', '', '', '']
# Keywords: interface control module - mappingimagingrecording - mappingimagingrecording system - interface control - plus minus plus - minus plus minus - minus plus - cloth - haptic feedback module - tennis
#
# Topic 22 (28 chunks): ['Optical element driving mechanisms', '', '', '', '', '', '', '', '', '']
# Keywords: driving - driving mechanism - mechanism claimed - driving mechanism claimed - element driving - optical element - optical element driving - element driving mechanism - driving assembly - fixed portion
#
# Topic 23 (7 chunks): ['Intracorporeal Video Analysis', '', '', '', '', '', '', '', '', '']
# Keywords: nontransitory - medium - nontransitory computer - nontransitory computer readable - readable medium - computer readable medium - readable - computer readable - nontransitory computerreadable - computerreadable
#
# Topic 25 (96 chunks): ['Lens and Optical System Design', '', '', '', '', '', '', '', '', '']
# Keywords: lens - optical system - denotes - lt - conditional - lens group - conditional expression - focal length - objective optical system - objective optical
#
# Topic 28 (2 chunks): ['Augmented Reality Eyewear for Enhanced Visual Acuity', '', '', '', '', '', '', '', '', '']
# Keywords: adjusted image - eye - adjusted - visual acuity - given pixel - acuity - given - wearer - pupil - virtual image
#
# Topic 29 (27 chunks): ['Optical Fiber Design for Light Scattering', '', '', '', '', '', '', '', '', '']
# Keywords: fiber - optical fiber - optical - cladding - core - beamshaping - light - optical probe - lightscattering - cores
#
# Topic 30 (30 chunks): ['Optical Beam Management', '', '', '', '', '', '', '', '', '']
# Keywords: light - optical - beam - fiber - wavelength - source - light source - optical fiber - oct - illumination
#
# Topic 31 (12 chunks): ['Voltage offset cancellation', '', '', '', '', '', '', '', '', '']
# Keywords: voltage - circuit - transistor - amplifier - node - output - terminal - clock - signal - clock signal
#
# Topic 34 (1 chunks): ['Near-infrared tissue imaging', '', '', '', '', '', '', '', '', '']
# Keywords: nm - peak wavelength - reflectance - tissue - wavelength - excitation - light - excitation light - nm nm - peak
#
# Topic 35 (15 chunks): ['Coaxial Microwave Instrument', '', '', '', '', '', '', '', '', '']
# Keywords: conductor - electrosurgical - electrosurgical instrument - dielectric - conductive - outer conductor - inner conductor - coaxial - microwave - radiating
#
# Topic 36 (3 chunks): ['UE Broadcast Service Detection', '', '', '', '', '', '', '', '', '']
# Keywords: ue - broadcast - service - detection components - downlink - codebook - priority - rom - services - ues
#
# Topic 40 (2 chunks): ['Medical Information Processing', '', '', '', '', '', '', '', '', '']
# Keywords: medical information - information processing apparatus - information processing - medical information processing - processing apparatus - processing circuitry - information - medical examination - examination - apparatus processing circuitry
#
# Topic 42 (1 chunks): ['Steerable Catheter Systems', '', '', '', '', '', '', '', '', '']
# Keywords: steerable catheter - catheter - steerable - steerable catheter assembly - flexible guide tube - followers - catheter assembly - steerable guide catheter - steerable guide - handle
#
# Topic 44 (4 chunks): ['Alternate Image Display', '', '', '', '', '', '', '', '', '']
# Keywords: alternately displaying - false color - onmovinggantry - maximum image color - partial data - false color false - color false - color false color - frequency alternately displaying - frequency alternately
#
# Topic 45 (1 chunks): ['Cordless Endoscope Systems', '', '', '', '', '', '', '', '', '']
# Keywords: endoscope - cannula - handle - cordless - reusable portion - reusable - working channel - cordless endoscope - insert housing - inspection accessory
#
# Topic 49 (30 chunks): ['Flexible Tube Insertion Systems', '', '', '', '', '', '', '', '', '']
# Keywords: flexible tube - flexible tube insertion - stiffness - tube insertion - tube insertion apparatus - insertion apparatus - flexible - insertion section - insertion - variable stiffness
#
#
# Summarize the above into a concise and human-readable description of the company’s products or innovations, focusing on the connection between the topics and the company's technology.
#  analysis - machine learning - deep learning - neural network - feature extraction - pattern recognition - classification - segmentation
#
# Based on the provided patent topics, it is likely that Olympus Corp is developing products related to medical imaging and surgical navigation, particularly in the areas of ultrasound imaging and surgical instrument design. The company may also be working on fluid and gas delivery systems, as well as robotic surgical systems. Additionally, they may be involved in trained medical image analysis using machine learning and deep learning techniques.
#
# Here are some possible products or technological areas that Olympus Corp might be developing based on these patent topics:
#
# * Ultrasound imaging systems for diagnostic purposes, including handheld devices and stationary machines
# * Surgical navigation systems that use optical sensors and cameras to provide real-time feedback during procedures
# * Optical sensors and cameras for use in medical imaging and surgical navigation applications
# * Fluid and gas delivery systems for use in minimally invasive surgeries, such as catheters and ports
# * Robotic surgical systems that include a robotic arm and associated instruments for performing procedures
# * Trained machine learning models for medical image analysis, including feature extraction and pattern recognition
# * Deep learning models for medical image analysis, including segmentation and classification tasks
# * Software for analyzing and processing medical images, including image enhancement and restoration tools
#
# These are just a few examples of the types of products and technologies that Olympus Corp might be developing based on their patent topics. The actual focus of the company's R&D efforts could be broader or more specific than what is suggested here.

# %%
company = "AMBU A S"

filtered_df = final_topic_df[final_topic_df["ProbablePatentAssignee"] == company]
topic_summary = (
    filtered_df
    .groupby(["ProbablePatentAssignee", "Topic"])
    .agg({
        "Llama2": "first",
        "Top_n_words": "first",
        "ApplicationNumber": "nunique"
    })
    .rename(columns={"ApplicationNumber": "ApplicationNoCount"})
    .reset_index()
)
#prompts
prompt_parts = [f"### Company: {company}\n"]
for _, row in topic_summary.iterrows():
    prompt_parts.append(
        f"Topic {row['Topic']} ({row['ApplicationNoCount']} chunks): {row['Llama2']}\n"
        f"Keywords: {row['Top_n_words']}\n"
    )

main_prompt = "\n".join(prompt_parts)

final_prompt = f"""
Company: {company}
Based on the following patent topics, please summarize the type of product(s) or innovation the company is likely developing. Provide a concise, human-readable description that connects these topics to potential products or technological areas.

{main_prompt}

Summarize the above into a concise and human-readable description of the company’s products or innovations, focusing on the connection between the topics and the company's technology.
"""

response = generator(final_prompt, max_length=500, temperature=0.7, top_p=0.9)[0]['generated_text']
print(f"Analysis for {company}:\n{response}")
# Out:
# Both `max_new_tokens` (=500) and `max_length`(=500) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Analysis for AMBU A S:
#
# Company: AMBU A S
# Based on the following patent topics, please summarize the type of product(s) or innovation the company is likely developing. Provide a concise, human-readable description that connects these topics to potential products or technological areas.
#
# ### Company: AMBU A S
#
# Topic -1 (119 chunks): ['Medical Imaging and Surgical Navigation', '', '', '', '', '', '', '', '', '']
# Keywords: light - sensor - device - optical - surgical - portion - distal - system - configured - position
#
# Topic 1 (2 chunks): ['Healthcare Data Analytics', '', '', '', '', '', '', '', '', '']
# Keywords: user - health - patient - data - healthcare - associated - information - clinical - record - server
#
# Topic 2 (12 chunks): ['Surgical Instrument Design', '', '', '', '', '', '', '', '', '']
# Keywords: jaw - shaft - drive - staple - pulley - member - effector - cartridge - gear - assembly
#
# Topic 3 (9 chunks): ['Fluid and gas delivery systems', '', '', '', '', '', '', '', '', '']
# Keywords: fluid - lumen - catheter - valve - needle - distal - tube - proximal - cannula - port
#
# Topic 7 (8 chunks): ['Endoscope Image Processing', '', '', '', '', '', '', '', '', '']
# Keywords: endoscope - endoscope system - light - illumination light - illumination - endoscope apparatus - endoscopic - observation - light source - endoscope image
#
# Topic 8 (53 chunks): ['Endoscope design and insertion techniques', '', '', '', '', '', '', '', '', '']
# Keywords: endoscope - bending - insertion - operation - portion - elevator - wire - section - insertion portion - portion endoscope
#
# Topic 13 (2 chunks): ['Medical Image Processing', '', '', '', '', '', '', '', '', '']
# Keywords: processing apparatus - medical image - image processing - processing - medical image processing - image processing apparatus - information processing - information processing apparatus - image - information
#
# Topic 15 (7 chunks): ['Image Pickup Module & Endoscope', '', '', '', '', '', '', '', '', '']
# Keywords: image pickup - pickup - endoscope - board - surface - substrate - principal surface - wiring - principal - resin
#
# Topic 16 (1 chunks): ['Adjustable Analytic Signal Processing', '', '', '', '', '', '', '', '', '']
# Keywords: canceled - adjusting mechanism - analytic signal - yaw adjusting - yaw adjusting mechanism - filtering tool - analytic - canceled canceled - pitch adjusting mechanism - pitch adjusting
#
# Topic 20 (1 chunks): ['Fluorescence Imaging', '', '', '', '', '', '', '', '', '']
# Keywords: light - fluorescence - wavelength - wavelength band - light source - band - illumination - source - excitation light - excitation
#
# Topic 21 (7 chunks): ['Control Interface for Mapping Imaging Recording', '', '', '', '', '', '', '', '', '']
# Keywords: interface control module - mappingimagingrecording - mappingimagingrecording system - interface control - plus minus plus - minus plus minus - minus plus - cloth - haptic feedback module - tennis
#
# Topic 25 (1 chunks): ['Lens and Optical System Design', '', '', '', '', '', '', '', '', '']
# Keywords: lens - optical system - denotes - lt - conditional - lens group - conditional expression - focal length - objective optical system - objective optical
#
# Topic 26 (3 chunks): ['Sample Collection System', '', '', '', '', '', '', '', '', '']
# Keywords: collection - sample - sample collection - sampling - swab - collection vessel - sampling device - sample collection vessel - collector - container
#
# Topic 44 (1 chunks): ['Alternate Image Display', '', '', '', '', '', '', '', '', '']
# Keywords: alternately displaying - false color - onmovinggantry - maximum image color - partial data - false color false - color false - color false color - frequency alternately displaying - frequency alternately
#
# Topic 45 (2 chunks): ['Cordless Endoscope Systems', '', '', '', '', '', '', '', '', '']
# Keywords: endoscope - cannula - handle - cordless - reusable portion - reusable - working channel - cordless endoscope - insert housing - inspection accessory
#
#
# Summarize the above into a concise and human-readable description of the company’s products or innovations, focusing on the connection between the topics and the company's technology.
#  image processing method
#
# Topic 14 (1 chunk): ['Patient specific implants', '', '', '', '', '', '', '', '', '']
# Keywords: patient - specific - implant - customized - implant design - patient specific implant - customized implant design - personalized - individualized - patient specific - implant fabrication
#
# Topic 16 (1 chunk): ['Minimally invasive surgery', '', '', '', '', '', '', '', '', '']
# Keywords: minimally invasive surgery - surgical procedure - minimally invasive technique - surgical approach - minimally invasive approach - minimal access surgery - minimal access technique - laparoscopic - thoracoscopic - robotic - computer-assisted
#
# Based on the patent topics provided, it appears that AMBU A/S is primarily focused on developing products and technologies related to medical imaging and surgery, specifically in the areas of:
#
# * Medical Imaging and Surgical Navigation: This area of focus includes the development of devices and systems for visualizing internal body structures during surgical procedures, such as endoscopes and surgical navigation systems.
# * Healthcare Data Analytics: This area of focus includes the development of software and systems for analyzing and managing healthcare data, such as electronic health records and clinical trial data.
# * Surgical Instrument Design: This area of focus includes the development of surgical instruments and tools, such as staple cartridges and surgical forceps.
# * Fluid and Gas Delivery Systems: This area of focus includes the development of systems for delivering fluids and gases to patients during medical procedures, such as catheters and ventilation systems.
# * Endoscope Image Processing: This area of focus includes the development of technology for enhancing and manipulating images obtained through endoscopy, such as image enhancement and virtual reality applications.
# * Endoscope Design and Insertion Techniques: This area of focus includes the development of endoscopes and related technologies for improved insertion and operation, such as bending and elevator mechanisms.
# * Minimally Invasive Surgery: This area of focus includes the development of technologies for performing surgical procedures with reduced invasion, such as laparoscopic and thorac

# %%
company = "CILAG GMBH INT"

filtered_df = final_topic_df[final_topic_df["ProbablePatentAssignee"] == company]
topic_summary = (
    filtered_df
    .groupby(["ProbablePatentAssignee", "Topic"])
    .agg({
        "Llama2": "first",
        "Top_n_words": "first",
        "ApplicationNumber": "nunique"
    })
    .rename(columns={"ApplicationNumber": "ApplicationNoCount"})
    .reset_index()
)
#prompts
prompt_parts = [f"### Company: {company}\n"]
for _, row in topic_summary.iterrows():
    prompt_parts.append(
        f"Topic {row['Topic']} ({row['ApplicationNoCount']} chunks): {row['Llama2']}\n"
        f"Keywords: {row['Top_n_words']}\n"
    )

main_prompt = "\n".join(prompt_parts)

final_prompt = f"""
Company: {company}
Based on the following patent topics, please summarize the type of product(s) or innovation the company is likely developing. Provide a concise, human-readable description that connects these topics to potential products or technological areas.

{main_prompt}

Summarize the above into a concise and human-readable description of the company’s products or innovations, focusing on the connection between the topics and the company's technology.
"""

response = generator(final_prompt, max_length=500, temperature=0.7, top_p=0.9)[0]['generated_text']
print(f"Analysis for {company}:\n{response}")
# Out:
# Both `max_new_tokens` (=500) and `max_length`(=500) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Analysis for CILAG GMBH INT:
#
# Company: CILAG GMBH INT
# Based on the following patent topics, please summarize the type of product(s) or innovation the company is likely developing. Provide a concise, human-readable description that connects these topics to potential products or technological areas.
#
# ### Company: CILAG GMBH INT
#
# Topic -1 (966 chunks): ['Medical Imaging and Surgical Navigation', '', '', '', '', '', '', '', '', '']
# Keywords: light - sensor - device - optical - surgical - portion - distal - system - configured - position
#
# Topic 0 (47 chunks): ['Ultrasound Imaging and Diagnostics', '', '', '', '', '', '', '', '', '']
# Keywords: ultrasound - ultrasonic - transducer - ultrasound image - probe - ultrasound probe - acoustic - ultrasound imaging - ultrasound transducer - wave
#
# Topic 1 (31 chunks): ['Healthcare Data Analytics', '', '', '', '', '', '', '', '', '']
# Keywords: user - health - patient - data - healthcare - associated - information - clinical - record - server
#
# Topic 2 (513 chunks): ['Surgical Instrument Design', '', '', '', '', '', '', '', '', '']
# Keywords: jaw - shaft - drive - staple - pulley - member - effector - cartridge - gear - assembly
#
# Topic 3 (24 chunks): ['Fluid and gas delivery systems', '', '', '', '', '', '', '', '', '']
# Keywords: fluid - lumen - catheter - valve - needle - distal - tube - proximal - cannula - port
#
# Topic 4 (116 chunks): ['Robotic Surgical Systems', '', '', '', '', '', '', '', '', '']
# Keywords: robotic - arm - robotic arm - robot - manipulator - joint - surgical - robotic system - tool - force
#
# Topic 6 (52 chunks): ['Augmented Reality Surgical Navigation', '', '', '', '', '', '', '', '', '']
# Keywords: reality - virtual - augmented - augmented reality - anatomical - tracking - coordinate - display - registration - ar
#
# Topic 7 (25 chunks): ['Endoscope Image Processing', '', '', '', '', '', '', '', '', '']
# Keywords: endoscope - endoscope system - light - illumination light - illumination - endoscope apparatus - endoscopic - observation - light source - endoscope image
#
# Topic 9 (1 chunks): ['Compositions for Cancer Imaging and Treatment', '', '', '', '', '', '', '', '', '']
# Keywords: composition - acid - percent - agent - cells - cancer - compound - cell - ch - claims
#
# Topic 10 (1 chunks): ['Patient-specific joint replacement planning', '', '', '', '', '', '', '', '', '']
# Keywords: bone - implant - femoral - knee - joint - femur - spinal - ligament - tibial - tibia
#
# Topic 16 (35 chunks): ['Adjustable Analytic Signal Processing', '', '', '', '', '', '', '', '', '']
# Keywords: canceled - adjusting mechanism - analytic signal - yaw adjusting - yaw adjusting mechanism - filtering tool - analytic - canceled canceled - pitch adjusting mechanism - pitch adjusting
#
# Topic 17 (1 chunks): ['Magnetic Field Control for Medical Imaging', '', '', '', '', '', '', '', '', '']
# Keywords: magnetic - magnetic field - field - coil - coils - magnet - magnetic sensor - electromagnetic - capsule - field generation
#
# Topic 18 (161 chunks): ['Surgical System Optimization', '', '', '', '', '', '', '', '', '']
# Keywords: surgical - surgical procedure - surgical hub - procedure - hub - surgical device - surgical data - operating room - surgical system - plurality surgical
#
# Topic 19 (10 chunks): ['RF Ablation Systems', '', '', '', '', '', '', '', '', '']
# Keywords: ablation - energy - electrodes - electrode - temperature - radiofrequency - tissue - electric current - rf - electric
#
# Topic 20 (4 chunks): ['Fluorescence Imaging', '', '', '', '', '', '', '', '', '']
# Keywords: light - fluorescence - wavelength - wavelength band - light source - band - illumination - source - excitation light - excitation
#
# Topic 21 (46 chunks): ['Control Interface for Mapping Imaging Recording', '', '', '', '', '', '', '', '', '']
# Keywords: interface control module - mappingimagingrecording - mappingimagingrecording system - interface control - plus minus plus - minus plus minus - minus plus - cloth - haptic feedback module - tennis
#
# Topic 23 (12 chunks): ['Intracorporeal Video Analysis', '', '', '', '', '', '', '', '', '']
# Keywords: nontransitory - medium - nontransitory computer - nontransitory computer readable - readable medium - computer readable medium - readable - computer readable - nontransitory computerreadable - computerreadable
#
# Topic 27 (131 chunks): ['Electromagnetic Radiation Imaging', '', '', '', '', '', '', '', '', '']
# Keywords: electromagnetic radiation - electromagnetic - radiation - exposure - pixel array - pulses electromagnetic radiation - pulses electromagnetic - exposure frame - emitter - nm
#
# Topic 30 (5 chunks): ['Optical Beam Management', '', '', '', '', '', '', '', '', '']
# Keywords: light - optical - beam - fiber - wavelength - source - light source - optical fiber - oct - illumination
#
# Topic 31 (10 chunks): ['Voltage offset cancellation', '', '', '', '', '', '', '', '', '']
# Keywords: voltage - circuit - transistor - amplifier - node - output - terminal - clock - signal - clock signal
#
# Topic 34 (1 chunks): ['Near-infrared tissue imaging', '', '', '', '', '', '', '', '', '']
# Keywords: nm - peak wavelength - reflectance - tissue - wavelength - excitation - light - excitation light - nm nm - peak
#
# Topic 35 (1 chunks): ['Coaxial Microwave Instrument', '', '', '', '', '', '', '', '', '']
# Keywords: conductor - electrosurgical - electrosurgical instrument - dielectric - conductive - outer conductor - inner conductor - coaxial - microwave - radiating
#
# Topic 38 (49 chunks): ['Ultrasonic Surgical Instrument', '', '', '', '', '', '', '', '', '']
# Keywords: clamp arm - ultrasonic blade - ultrasonic surgical - ultrasonic surgical instrument - clamp - waveguide - ultrasonic - cantilever electrode - acoustic waveguide - blade
#
# Topic 39 (44 chunks): ['Modular Electrosurgical Systems', '', '', '', '', '', '', '', '', '']
# Keywords: surgical module - module - energy module - electrosurgical - module surgical module - module surgical - modular surgical system - modular surgical - header module - energy
#
#
# Summarize the above into a concise and human-readable description of the company’s products or innovations, focusing on the connection between the topics and the company's technology.
#  display - navigation - computer - graphics - user interface - display device - image processing - augmented reality - surgery
#
# Based on the patent topics provided, it is likely that CILAG GMBH INT is developing products related to medical imaging and surgical navigation, specifically in the fields of ultrasound imaging and robotic surgical systems. The company may be working on designing and optimizing sensors and devices for these applications, as well as creating software and algorithms for image processing and analysis. Additionally, they may be exploring the use of augmented reality technology for improved surgical navigation and visualization.

# %%
company = "CILAG GMBH INT"

filtered_df = final_topic_df[final_topic_df["ProbablePatentAssignee"] == company]
topic_summary = (
    filtered_df
    .groupby(["ProbablePatentAssignee", "Topic"])
    .agg({
        "Llama2": "first",
        "Top_n_words": "first",
        "ApplicationNumber": "nunique"
    })
    .rename(columns={"ApplicationNumber": "ApplicationNoCount"})
    .reset_index()
)
#prompts
prompt_parts = [f"### Company: {company}\n"]
for _, row in topic_summary.iterrows():
    prompt_parts.append(
        f"Topic {row['Topic']} ({row['ApplicationNoCount']} chunks): {row['Llama2']}\n"
        f"Keywords: {row['Top_n_words']}\n"
    )

main_prompt = "\n".join(prompt_parts)

final_prompt = f"""
Company: {company}
Based on the following patent topics, please summarize the type of product(s) or innovation the company is likely developing. Provide a concise, human-readable description that connects these topics to potential products or technological areas.

{main_prompt}

Summarize the above into a concise and human-readable description of the company’s products or innovations, focusing on the connection between the topics and the company's technology.
"""

response = generator(final_prompt, max_length=500, temperature=0.7, top_p=0.9)[0]['generated_text']
print(f"Analysis for {company}:\n{response}")
# Out:
# Both `max_new_tokens` (=500) and `max_length`(=500) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Analysis for CILAG GMBH INT:
#
# Company: CILAG GMBH INT
# Based on the following patent topics, please summarize the type of product(s) or innovation the company is likely developing. Provide a concise, human-readable description that connects these topics to potential products or technological areas.
#
# ### Company: CILAG GMBH INT
#
# Topic -1 (966 chunks): ['Medical Imaging and Surgical Navigation', '', '', '', '', '', '', '', '', '']
# Keywords: light - sensor - device - optical - surgical - portion - distal - system - configured - position
#
# Topic 0 (47 chunks): ['Ultrasound Imaging and Diagnostics', '', '', '', '', '', '', '', '', '']
# Keywords: ultrasound - ultrasonic - transducer - ultrasound image - probe - ultrasound probe - acoustic - ultrasound imaging - ultrasound transducer - wave
#
# Topic 1 (31 chunks): ['Healthcare Data Analytics', '', '', '', '', '', '', '', '', '']
# Keywords: user - health - patient - data - healthcare - associated - information - clinical - record - server
#
# Topic 2 (513 chunks): ['Surgical Instrument Design', '', '', '', '', '', '', '', '', '']
# Keywords: jaw - shaft - drive - staple - pulley - member - effector - cartridge - gear - assembly
#
# Topic 3 (24 chunks): ['Fluid and gas delivery systems', '', '', '', '', '', '', '', '', '']
# Keywords: fluid - lumen - catheter - valve - needle - distal - tube - proximal - cannula - port
#
# Topic 4 (116 chunks): ['Robotic Surgical Systems', '', '', '', '', '', '', '', '', '']
# Keywords: robotic - arm - robotic arm - robot - manipulator - joint - surgical - robotic system - tool - force
#
# Topic 6 (52 chunks): ['Augmented Reality Surgical Navigation', '', '', '', '', '', '', '', '', '']
# Keywords: reality - virtual - augmented - augmented reality - anatomical - tracking - coordinate - display - registration - ar
#
# Topic 7 (25 chunks): ['Endoscope Image Processing', '', '', '', '', '', '', '', '', '']
# Keywords: endoscope - endoscope system - light - illumination light - illumination - endoscope apparatus - endoscopic - observation - light source - endoscope image
#
# Topic 9 (1 chunks): ['Compositions for Cancer Imaging and Treatment', '', '', '', '', '', '', '', '', '']
# Keywords: composition - acid - percent - agent - cells - cancer - compound - cell - ch - claims
#
# Topic 10 (1 chunks): ['Patient-specific joint replacement planning', '', '', '', '', '', '', '', '', '']
# Keywords: bone - implant - femoral - knee - joint - femur - spinal - ligament - tibial - tibia
#
# Topic 16 (35 chunks): ['Adjustable Analytic Signal Processing', '', '', '', '', '', '', '', '', '']
# Keywords: canceled - adjusting mechanism - analytic signal - yaw adjusting - yaw adjusting mechanism - filtering tool - analytic - canceled canceled - pitch adjusting mechanism - pitch adjusting
#
# Topic 17 (1 chunks): ['Magnetic Field Control for Medical Imaging', '', '', '', '', '', '', '', '', '']
# Keywords: magnetic - magnetic field - field - coil - coils - magnet - magnetic sensor - electromagnetic - capsule - field generation
#
# Topic 18 (161 chunks): ['Surgical System Optimization', '', '', '', '', '', '', '', '', '']
# Keywords: surgical - surgical procedure - surgical hub - procedure - hub - surgical device - surgical data - operating room - surgical system - plurality surgical
#
# Topic 19 (10 chunks): ['RF Ablation Systems', '', '', '', '', '', '', '', '', '']
# Keywords: ablation - energy - electrodes - electrode - temperature - radiofrequency - tissue - electric current - rf - electric
#
# Topic 20 (4 chunks): ['Fluorescence Imaging', '', '', '', '', '', '', '', '', '']
# Keywords: light - fluorescence - wavelength - wavelength band - light source - band - illumination - source - excitation light - excitation
#
# Topic 21 (46 chunks): ['Control Interface for Mapping Imaging Recording', '', '', '', '', '', '', '', '', '']
# Keywords: interface control module - mappingimagingrecording - mappingimagingrecording system - interface control - plus minus plus - minus plus minus - minus plus - cloth - haptic feedback module - tennis
#
# Topic 23 (12 chunks): ['Intracorporeal Video Analysis', '', '', '', '', '', '', '', '', '']
# Keywords: nontransitory - medium - nontransitory computer - nontransitory computer readable - readable medium - computer readable medium - readable - computer readable - nontransitory computerreadable - computerreadable
#
# Topic 27 (131 chunks): ['Electromagnetic Radiation Imaging', '', '', '', '', '', '', '', '', '']
# Keywords: electromagnetic radiation - electromagnetic - radiation - exposure - pixel array - pulses electromagnetic radiation - pulses electromagnetic - exposure frame - emitter - nm
#
# Topic 30 (5 chunks): ['Optical Beam Management', '', '', '', '', '', '', '', '', '']
# Keywords: light - optical - beam - fiber - wavelength - source - light source - optical fiber - oct - illumination
#
# Topic 31 (10 chunks): ['Voltage offset cancellation', '', '', '', '', '', '', '', '', '']
# Keywords: voltage - circuit - transistor - amplifier - node - output - terminal - clock - signal - clock signal
#
# Topic 34 (1 chunks): ['Near-infrared tissue imaging', '', '', '', '', '', '', '', '', '']
# Keywords: nm - peak wavelength - reflectance - tissue - wavelength - excitation - light - excitation light - nm nm - peak
#
# Topic 35 (1 chunks): ['Coaxial Microwave Instrument', '', '', '', '', '', '', '', '', '']
# Keywords: conductor - electrosurgical - electrosurgical instrument - dielectric - conductive - outer conductor - inner conductor - coaxial - microwave - radiating
#
# Topic 38 (49 chunks): ['Ultrasonic Surgical Instrument', '', '', '', '', '', '', '', '', '']
# Keywords: clamp arm - ultrasonic blade - ultrasonic surgical - ultrasonic surgical instrument - clamp - waveguide - ultrasonic - cantilever electrode - acoustic waveguide - blade
#
# Topic 39 (44 chunks): ['Modular Electrosurgical Systems', '', '', '', '', '', '', '', '', '']
# Keywords: surgical module - module - energy module - electrosurgical - module surgical module - module surgical - modular surgical system - modular surgical - header module - energy
#
#
# Summarize the above into a concise and human-readable description of the company’s products or innovations, focusing on the connection between the topics and the company's technology.
#  augmented - display - user - interface - navigation - device - tracking - camera - system
#
# Topic 7 (80 chunks): ['Image-guided Therapy', '', '', '', '', '', '', '', '', '']
# Keywords: image - therapy - guided - imaging - treatment - modality - procedure - patient - monitor - display
#
# Based on the provided patent topics, it is likely that CILAG GMBH INT is developing products or technologies related to medical imaging and surgical navigation, particularly in the fields of minimally invasive surgery and robotic-assisted surgery. The company may be working on designing and manufacturing surgical instruments with advanced sensors and actuators for precision surgery, as well as developing new technologies for image-guided therapy and augmented reality surgical navigation. Additionally, they may be involved in creating software solutions for data analytics and management in the healthcare industry.
